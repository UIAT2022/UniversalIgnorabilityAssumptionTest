# %% [markdown]
# # Mixed - Scenario 1~4

# %%
import pandas as pd
import numpy as np
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
from rpy2.robjects import pandas2ri
from rpy2.robjects.conversion import localconverter

import rpy2.robjects as robjects
import rpy2.robjects.packages as rpackages
from rpy2.robjects import numpy2ri
from rpy2.robjects.vectors import StrVector

from statsmodels.stats.anova import anova_lm 
import statsmodels.formula.api as smf

required_packages = ['base', 'forecast', 'CondIndTests','RCIT'] # list of required R packages 
if all(rpackages.isinstalled(x) for x in required_packages):
    check_packages = True # True if packages are already installed 
else:
   check_packages = False # False if packages are not installed 
if check_packages == False: # Not installed? Then install.
    utils = rpackages.importr('utils')
    utils.chooseCRANmirror(ind=1)
    packages_to_install = [x for x in required_packages if not rpackages.isinstalled(x)]
    if len(packages_to_install) > 0:
        utils.install_packages(StrVector(packages_to_install))
    check_packages = True

# %%
r = robjects.r
base = importr('base')
forecast = importr('forecast')
graphics = importr('graphics')
grdevices = importr('grDevices')
condindtests = importr('CondIndTests')
RCIT = importr('RCIT')
pcalg = importr('pcalg')

# %%
def IgnorTest(cause=None, effect=None, explorer=None, covariate=None, level=0.05, dtype="continuous"): #inputs are arrays, dtypes are continuous/binary/mixed
    tmp_cause=pd.DataFrame({'A': cause})
    tmp_effect=pd.DataFrame({'Y': effect})
    tmp_explorer=pd.DataFrame({'V': explorer})
    tmp_covariate = pd.DataFrame(covariate)
    dim_covariate = tmp_covariate.shape[1]
    
    if dtype=="continuous":
        if dim_covariate==0:
            tmp_conditioning=tmp_cause
        else:
            tmp_conditioning=pd.concat([tmp_cause,tmp_covariate],axis=1)

        with localconverter(ro.default_converter + pandas2ri.converter):
            r_from_pd_conditioning = ro.conversion.py2rpy(tmp_conditioning)
        with localconverter(ro.default_converter + pandas2ri.converter):
            r_from_pd_effect = ro.conversion.py2rpy(tmp_effect)
        with localconverter(ro.default_converter + pandas2ri.converter):
            r_from_pd_explorer = ro.conversion.py2rpy(tmp_explorer)
            
        sample_size = r.unlist(r.dim(r_from_pd_conditioning))[0]
        dim = r.unlist(r.dim(r_from_pd_conditioning))[1]
            
        r_from_pd_explorer=r.unlist(r_from_pd_explorer)    
        r_from_pd_effect=r.unlist(r_from_pd_effect)   
        r_from_pd_conditioning=r.unlist(r_from_pd_conditioning)   
        r_from_pd_conditioning=r.matrix(r_from_pd_conditioning,sample_size,dim)
        
        #test=r.CondIndTest(r_from_pd_explorer,r_from_pd_effect,r_from_pd_conditioning, method = "KCI")
        #pvalue=r.unlist(test)[3]
        
        test=r.RCoT(r_from_pd_explorer,r_from_pd_effect,r_from_pd_conditioning,seed=2)
        pvalue=r.unlist(test)[0]
        print(pvalue)
            
    elif dtype=="mixed":
        dat_mixed=pd.concat([tmp_effect,tmp_explorer,tmp_cause,tmp_covariate],axis=1)
        dat_mixed.columns = ['col1','col2','col3','col4']
        
        mod_restriced = smf.ols('col1 ~ col3*col4 ', data = dat_mixed).fit()
        mod_unrestriced = smf.ols('col1 ~ col2*col3*col4', data = dat_mixed).fit()
        anovaResults = anova_lm(mod_restriced, mod_unrestriced)
        pvalue=anovaResults.iloc[1,5]
        print(pvalue)

    else:
        raise ValueError("dtype is not valid.")
        
    if(pvalue<=level):
        print("The Ignorability Assumption is not satisfied.")
    else:
        print("The Ignorability Assumption is satisfied.")

    return pvalue

# %%
UIAT.py

# %%
import uiat

# %%
n = 1000 #changeable
c1 = 1
c2 = 1 
c3 = 1 #changeable
c4 = 1
c5 = 1
r1 = r2 = r3 = r4 = 1 #changeable
import scipy.stats as stats

#Figure 1
np.random.seed(1)

COUNT1=0 #기각 횟수
for i in range(3):

    U = np.random.normal(0,1,n) #common cause of X1 and X2
    e1 = np.random.normal(0,1,n)
    e2 = np.random.normal(0,1,n)
    ey = np.random.normal(0,1,n)
    
    X1 = r1*U+e1
    X2 = r2*U+e2
    Y = c1*X1+ey
    
    if i==1:
        f1_cor12=stats.pearsonr(X1, X2)[0]
        
    UIAT=uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X2,dtype="continuous")
    pvalue = UIAT.test()
    if pvalue<=0.05:
        COUNT1 = COUNT1+1
# Out:
# 0.27766323332439335
# The Ignorability Assumption is satisfied.
# 0.4989722898028902
# The Ignorability Assumption is satisfied.
# 0.2978939489606358
# The Ignorability Assumption is satisfied.

# %% [markdown]
# ### Scenario 1

# %%
#실제 ATE 찾아지는 상황 (but, 실제 causal effect = 0) <1종 오류>
import time

np.random.seed(1)

COUNT1 = 0
for i in range(1):
    
    n = 1000 
    k0_co = 0.8
    k1_co = 1
    k0_at = 0.8
    k1_at = 1
    k0_nt = 0.8
    k1_nt = 1

    a0 = -2 #changeable
    a1 = 0

    X = np.random.binomial(1,0.5,size=n)

    mu_Z = 1/(1+np.exp(1-2*X))
    Z = np.random.binomial(1,mu_Z,size=n)

    p_at = np.exp(-2.5+3.5*X)/(1+np.exp(-2.5+3.5*X)+np.exp(-2.5+3.5*X))
    p_nt = np.exp(-2.5+3.5*X)/(1+np.exp(-2.5+3.5*X)+np.exp(-2.5+3.5*X))
    p_co = 1/(1+np.exp(-2.5+3.5*X)+np.exp(-2.5+3.5*X))

    C=[]
    for j in range(n):
        C.append(np.random.choice(["co","at","nt"], size=1, replace=True, p=[p_at[j],p_nt[j],p_co[j]])[0])
    C=np.array(C)

    A = np.repeat(0,n)
    A[C=="at"] = 1
    A[(C=="co")*(Z==1)] = 1

    Y = np.random.normal(0,1,n)
    for k in range(n):

        if C[k]=="co":
            mu_y = k0_co+k1_co*X[k]+(a0+a1*X[k])*A[k]
            Y[k] = np.random.normal(mu_y,1,1)[0]
        elif C[k] == "at":
            mu_y = k0_at+k1_at*X[k]
            Y[k] = np.random.normal(mu_y,1,1)[0]
        else:
            mu_y = k0_nt+k1_nt*X[k]
            Y[k] = np.random.normal(mu_y,1,1)[0]
            
    #data = pd.DataFrame({"col1":Y,"col2":Z,"col3":A,"col4":C,"col5":X})
    #data.loc[data["col4"]=="nt","col4"] = 0 
    #data.loc[data["col4"]=="co","col4"] = 1
    #data.loc[data["col4"]=="at","col4"] = 2 
    start_time=time.time()
    pvalue = IgnorTest(cause=A, effect=Y, explorer=Z, covariate=X, level=0.05, dtype="mixed")
    print(time.time()-start_time)
    if pvalue<=0.05:
        COUNT1 = COUNT1+1
# Out:
# 4.262348594337282e-08
# The Ignorability Assumption is not satisfied.
# 0.010004520416259766

# %%
COUNT1
# Out:
# 999

# %% [markdown]
# ### Scenario 2

# %%
# 2종 오류 (confounder인 C가 안 찾아짐.)

np.random.seed(1)

COUNT2 = 0
for i in range(1000):
    
    n = 1000 
    k0_co = 0.3
    k1_co = 1
    k0_at = 0.8
    k1_at = 1
    k0_nt = 0.3
    k1_nt = 1

    a0 = -2 #changeable
    a1 = 0

    X = np.random.binomial(1,0.5,size=n)

    mu_Z = 1/(1+np.exp(1-2*X))
    Z = np.random.binomial(1,mu_Z,size=n)

    p_at = np.exp(-2.5+3.5*X)/(1+np.exp(-2.5+3.5*X)+np.exp(-2.5+3.5*X))
    p_nt = np.exp(-2.5+3.5*X)/(1+np.exp(-2.5+3.5*X)+np.exp(-2.5+3.5*X))
    p_co = 1/(1+np.exp(-2.5+3.5*X)+np.exp(-2.5+3.5*X))

    C=[]
    for j in range(n):
        C.append(np.random.choice(["co","at","nt"], size=1, replace=True, p=[p_at[j],p_nt[j],p_co[j]])[0])
    C=np.array(C)

    A = np.repeat(0,n)
    A[C=="at"] = 1
    A[(C=="co")*(Z==1)] = 1

    Y = np.random.normal(0,1,n)
    for k in range(n):

        if C[k]=="co":
            mu_y = k0_co+k1_co*X[k]+(a0+a1*X[k])*A[k]
            Y[k] = np.random.normal(mu_y,1,1)[0]
        elif C[k] == "at":
            mu_y = k0_at+k1_at*X[k]
            Y[k] = np.random.normal(mu_y,1,1)[0]
        else:
            mu_y = k0_nt+k1_nt*X[k]
            Y[k] = np.random.normal(mu_y,1,1)[0]
            
    #data = pd.DataFrame({"col1":Y,"col2":Z,"col3":A,"col4":C,"col5":X})
    #data.loc[data["col4"]=="nt","col4"] = 0 
    #data.loc[data["col4"]=="co","col4"] = 1
    #data.loc[data["col4"]=="at","col4"] = 2 
    
    pvalue = IgnorTest(cause=A, effect=Y, explorer=Z, covariate=X, level=0.05, dtype="mixed")
    if pvalue<=0.01:
        COUNT2 = COUNT2+1
# Out:
# 8.683126104351939e-12
# The Ignorability Assumption is not satisfied.
# 1.54037646506326e-17
# The Ignorability Assumption is not satisfied.
# 3.188395872156527e-09
# The Ignorability Assumption is not satisfied.
# 1.368714755154423e-12
# The Ignorability Assumption is not satisfied.
# 1.1258324965457155e-18
# The Ignorability Assumption is not satisfied.
# 3.2676321800335454e-07
# The Ignorability Assumption is not satisfied.
# 3.710047742763449e-10
# The Ignorability Assumption is not satisfied.
# 3.323845517162924e-15
# The Ignorability Assumption is not satisfied.
# 4.44260338736169e-16
# The Ignorability Assumption is not satisfied.
# 5.204818448208334e-12
# The Ignorability Assumption is not satisfied.
# 6.736964755443751e-15
# The Ignorability Assumption is not satisfied.
# 1.6155878707927935e-06
# The Ignorability Assumption is not satisfied.
# 1.2526221519900518e-12
# The Ignorability Assumption is not satisfied.
# 1.1094588546110155e-18
# The Ignorability Assumption is not satisfied.
# 2.403790063679607e-15
# The Ignorability Assumption is not satisfied.
# 2.58691220672318e-16
# The Ignorability Assumption is not satisfied.
# 6.606352572369728e-14
# The Ignorability Assumption is not satisfied.
# 4.472158646109261e-14
# The Ignorability Assumption is not satisfied.
# 1.0703384336619847e-16
# The Ignorability Assumption is not satisfied.
# 3.3257775859267157e-15
# The Ignorability Assumption is not satisfied.
# 7.047232480228391e-12
# The Ignorability Assumption is not satisfied.
# 2.8544938258624984e-17
# The Ignorability Assumption is not satisfied.
# 2.385638421802012e-09
# The Ignorability Assumption is not satisfied.
# 2.8315238912324868e-14
# The Ignorability Assumption is not satisfied.
# 3.2260298777303814e-15
# The Ignorability Assumption is not satisfied.
# 3.376547219152291e-10
# The Ignorability Assumption is not satisfied.
# 1.0614175742913565e-14
# The Ignorability Assumption is not satisfied.
# 1.2111433516934385e-09
# The Ignorability Assumption is not satisfied.
# 2.140276980172791e-17
# The Ignorability Assumption is not satisfied.
# 2.3698849178559655e-10
# The Ignorability Assumption is not satisfied.
# 8.103957124495368e-14
# The Ignorability Assumption is not satisfied.
# 2.1063832668967394e-13
# The Ignorability Assumption is not satisfied.
# 9.051390626197928e-16
# The Ignorability Assumption is not satisfied.
# 1.214976727902765e-13
# The Ignorability Assumption is not satisfied.
# 1.3752997390403977e-18
# The Ignorability Assumption is not satisfied.
# 1.3416608279850304e-13
# The Ignorability Assumption is not satisfied.
# 4.935772780558802e-16
# The Ignorability Assumption is not satisfied.
# 9.405272175424945e-15
# The Ignorability Assumption is not satisfied.
# 3.016932982476167e-10
# The Ignorability Assumption is not satisfied.
# 1.0232047797696187e-14
# The Ignorability Assumption is not satisfied.
# 2.2355974694681692e-15
# The Ignorability Assumption is not satisfied.
# 3.842870658036783e-12
# The Ignorability Assumption is not satisfied.
# 3.4820757649994195e-11
# The Ignorability Assumption is not satisfied.
# 8.027798279894593e-10
# The Ignorability Assumption is not satisfied.
# 1.4823365914700688e-19
# The Ignorability Assumption is not satisfied.
# 4.396693976066477e-06
# The Ignorability Assumption is not satisfied.
# 1.0200758806128707e-12
# The Ignorability Assumption is not satisfied.
# 6.414799371005899e-10
# The Ignorability Assumption is not satisfied.
# 6.511050606958386e-08
# The Ignorability Assumption is not satisfied.
# 2.2450174635920732e-14
# The Ignorability Assumption is not satisfied.
# 5.229041015365444e-14
# The Ignorability Assumption is not satisfied.
# 1.1606678346060521e-13
# The Ignorability Assumption is not satisfied.
# 7.427626626183864e-11
# The Ignorability Assumption is not satisfied.
# 4.473014256815801e-11
# The Ignorability Assumption is not satisfied.
# 2.990491370599404e-13
# The Ignorability Assumption is not satisfied.
# 1.4484077313301653e-11
# The Ignorability Assumption is not satisfied.
# 2.0489308292793347e-11
# The Ignorability Assumption is not satisfied.
# 4.934350733350604e-10
# The Ignorability Assumption is not satisfied.
# 5.116792118517798e-13
# The Ignorability Assumption is not satisfied.
# 1.4811476068489445e-08
# The Ignorability Assumption is not satisfied.
# 1.689271851038135e-11
# The Ignorability Assumption is not satisfied.
# 5.057042010283543e-10
# The Ignorability Assumption is not satisfied.
# 3.775054528765018e-17
# The Ignorability Assumption is not satisfied.
# 3.137660946151324e-10
# The Ignorability Assumption is not satisfied.
# 2.092379459936424e-15
# The Ignorability Assumption is not satisfied.
# 1.6771166180115019e-15
# The Ignorability Assumption is not satisfied.
# 2.0490225281378638e-10
# The Ignorability Assumption is not satisfied.
# 1.181298517738578e-10
# The Ignorability Assumption is not satisfied.
# 5.086486709839324e-15
# The Ignorability Assumption is not satisfied.
# 1.1414318298277251e-07
# The Ignorability Assumption is not satisfied.
# 7.970123262160343e-11
# The Ignorability Assumption is not satisfied.
# 6.745292759873076e-11
# The Ignorability Assumption is not satisfied.
# 2.3682694994078907e-15
# The Ignorability Assumption is not satisfied.
# 3.787401313303435e-10
# The Ignorability Assumption is not satisfied.
# 1.5561788120591448e-10
# The Ignorability Assumption is not satisfied.
# 5.584044545645119e-16
# The Ignorability Assumption is not satisfied.
# 1.9857628435939386e-16
# The Ignorability Assumption is not satisfied.
# 1.3320337494692939e-17
# The Ignorability Assumption is not satisfied.
# 9.456553889619033e-14
# The Ignorability Assumption is not satisfied.
# 2.6600910817417044e-09
# The Ignorability Assumption is not satisfied.
# 1.4543753617985975e-18
# The Ignorability Assumption is not satisfied.
# 3.172178836040946e-15
# The Ignorability Assumption is not satisfied.
# 2.9364162556457524e-15
# The Ignorability Assumption is not satisfied.
# 1.1421376747599665e-11
# The Ignorability Assumption is not satisfied.
# 1.5464657592181058e-16
# The Ignorability Assumption is not satisfied.
# 3.0884948751283134e-16
# The Ignorability Assumption is not satisfied.
# 1.5469532587251384e-14
# The Ignorability Assumption is not satisfied.
# 1.1067058434133746e-16
# The Ignorability Assumption is not satisfied.
# 9.707800798566695e-08
# The Ignorability Assumption is not satisfied.
# 3.901010972857967e-08
# The Ignorability Assumption is not satisfied.
# 3.503999076487248e-13
# The Ignorability Assumption is not satisfied.
# 2.392993971753972e-15
# The Ignorability Assumption is not satisfied.
# 1.4845883625740855e-10
# The Ignorability Assumption is not satisfied.
# 1.4157323986940137e-15
# The Ignorability Assumption is not satisfied.
# 7.828392430483278e-08
# The Ignorability Assumption is not satisfied.
# 2.520211960796172e-07
# The Ignorability Assumption is not satisfied.
# 2.158890803412654e-13
# The Ignorability Assumption is not satisfied.
# 1.6001691879468486e-11
# The Ignorability Assumption is not satisfied.
# 6.458243525718942e-14
# The Ignorability Assumption is not satisfied.
# 3.347536577857753e-11
# The Ignorability Assumption is not satisfied.
# 8.972576606881292e-09
# The Ignorability Assumption is not satisfied.
# 9.658938417187714e-13
# The Ignorability Assumption is not satisfied.
# 4.543971989870998e-14
# The Ignorability Assumption is not satisfied.
# 1.6093228270959653e-15
# The Ignorability Assumption is not satisfied.
# 1.823356972073899e-11
# The Ignorability Assumption is not satisfied.
# 4.0937744319401045e-20
# The Ignorability Assumption is not satisfied.
# 2.225360667352279e-15
# The Ignorability Assumption is not satisfied.
# 2.8265784141165736e-09
# The Ignorability Assumption is not satisfied.
# 5.489398731145634e-15
# The Ignorability Assumption is not satisfied.
# 1.3288166104217789e-08
# The Ignorability Assumption is not satisfied.
# 1.1943480298463897e-09
# The Ignorability Assumption is not satisfied.
# 1.2503688261900566e-08
# The Ignorability Assumption is not satisfied.
# 7.326549008906246e-12
# The Ignorability Assumption is not satisfied.
# 1.6316325736972445e-12
# The Ignorability Assumption is not satisfied.
# 9.232939014953377e-07
# The Ignorability Assumption is not satisfied.
# 2.017821284768422e-09
# The Ignorability Assumption is not satisfied.
# 2.7297810286001942e-14
# The Ignorability Assumption is not satisfied.
# 1.0239507235019804e-09
# The Ignorability Assumption is not satisfied.
# 3.9985704024994653e-10
# The Ignorability Assumption is not satisfied.
# 2.3682493788955466e-06
# The Ignorability Assumption is not satisfied.
# 1.7909245546017523e-10
# The Ignorability Assumption is not satisfied.
# 4.491343141261252e-14
# The Ignorability Assumption is not satisfied.
# 1.1950423130047151e-16
# The Ignorability Assumption is not satisfied.
# 2.410222734919746e-16
# The Ignorability Assumption is not satisfied.
# 3.9018359915774314e-08
# The Ignorability Assumption is not satisfied.
# 2.2755513068529913e-12
# The Ignorability Assumption is not satisfied.
# 2.422994760940401e-15
# The Ignorability Assumption is not satisfied.
# 3.0388882167494995e-10
# The Ignorability Assumption is not satisfied.
# 2.4808198249531284e-11
# The Ignorability Assumption is not satisfied.
# 1.693346257715239e-14
# The Ignorability Assumption is not satisfied.
# 9.662647407844452e-09
# The Ignorability Assumption is not satisfied.
# 8.980734438721328e-16
# The Ignorability Assumption is not satisfied.
# 1.2836981256312604e-13
# The Ignorability Assumption is not satisfied.
# 5.363878330809932e-13
# The Ignorability Assumption is not satisfied.
# 1.84820368006285e-09
# The Ignorability Assumption is not satisfied.
# 2.3565869410592603e-14
# The Ignorability Assumption is not satisfied.
# 3.289925983631341e-10
# The Ignorability Assumption is not satisfied.
# 1.330281606537914e-10
# The Ignorability Assumption is not satisfied.
# 4.7784196764831704e-17
# The Ignorability Assumption is not satisfied.
# 1.9296130917057745e-08
# The Ignorability Assumption is not satisfied.
# 1.3799070918818724e-12
# The Ignorability Assumption is not satisfied.
# 3.565576568174227e-14
# The Ignorability Assumption is not satisfied.
# 1.5575625860781903e-13
# The Ignorability Assumption is not satisfied.
# 2.3748172558891027e-22
# The Ignorability Assumption is not satisfied.
# 1.5671186088687322e-06
# The Ignorability Assumption is not satisfied.
# 1.7359001288756564e-16
# The Ignorability Assumption is not satisfied.
# 3.30252985074514e-11
# The Ignorability Assumption is not satisfied.
# 7.613203797572199e-10
# The Ignorability Assumption is not satisfied.
# 4.7982790918676175e-09
# The Ignorability Assumption is not satisfied.
# 6.251669461001881e-13
# The Ignorability Assumption is not satisfied.
# 2.200516096658589e-18
# The Ignorability Assumption is not satisfied.
# 6.502974734358888e-11
# The Ignorability Assumption is not satisfied.
# 2.0242221965466543e-16
# The Ignorability Assumption is not satisfied.
# 2.1340604910400763e-13
# The Ignorability Assumption is not satisfied.
# 1.0013690195839544e-12
# The Ignorability Assumption is not satisfied.
# 1.8825826000336632e-11
# The Ignorability Assumption is not satisfied.
# 5.4637465825564945e-12
# The Ignorability Assumption is not satisfied.
# 1.0668907816399084e-19
# The Ignorability Assumption is not satisfied.
# 7.892707855850781e-11
# The Ignorability Assumption is not satisfied.
# 2.224705758743281e-18
# The Ignorability Assumption is not satisfied.
# 1.7181699663963453e-12
# The Ignorability Assumption is not satisfied.
# 9.332729010300315e-10
# The Ignorability Assumption is not satisfied.
# 2.973909670218123e-09
# The Ignorability Assumption is not satisfied.
# 4.906981085207975e-15
# The Ignorability Assumption is not satisfied.
# 1.159983970420211e-12
# The Ignorability Assumption is not satisfied.
# 2.554726539387266e-14
# The Ignorability Assumption is not satisfied.
# 1.3232916843594331e-07
# The Ignorability Assumption is not satisfied.
# 2.856014651805609e-13
# The Ignorability Assumption is not satisfied.
# 1.499757681315745e-12
# The Ignorability Assumption is not satisfied.
# 7.081864111495434e-17
# The Ignorability Assumption is not satisfied.
# 1.813353823754456e-11
# The Ignorability Assumption is not satisfied.
# 1.6471806116029525e-17
# The Ignorability Assumption is not satisfied.
# 3.1490788216114965e-18
# The Ignorability Assumption is not satisfied.
# 3.4378941052879637e-10
# The Ignorability Assumption is not satisfied.
# 1.594805033607589e-07
# The Ignorability Assumption is not satisfied.
# 3.4538883479362325e-11
# The Ignorability Assumption is not satisfied.
# 1.5309160836363925e-09
# The Ignorability Assumption is not satisfied.
# 1.928303452267697e-09
# The Ignorability Assumption is not satisfied.
# 1.3546120266686017e-09
# The Ignorability Assumption is not satisfied.
# 3.368482015403641e-10
# The Ignorability Assumption is not satisfied.
# 8.381803396056174e-18
# The Ignorability Assumption is not satisfied.
# 4.944643704656289e-16
# The Ignorability Assumption is not satisfied.
# 1.3121344272456097e-13
# The Ignorability Assumption is not satisfied.
# 2.3451004150606894e-09
# The Ignorability Assumption is not satisfied.
# 6.509349154681958e-10
# The Ignorability Assumption is not satisfied.
# 4.5746942560909717e-14
# The Ignorability Assumption is not satisfied.
# 4.2385890871453914e-14
# The Ignorability Assumption is not satisfied.
# 1.4099721634269733e-10
# The Ignorability Assumption is not satisfied.
# 1.2315561624878692e-14
# The Ignorability Assumption is not satisfied.
# 9.150788629622243e-16
# The Ignorability Assumption is not satisfied.
# 1.0456869271611447e-12
# The Ignorability Assumption is not satisfied.
# 6.349476607226637e-11
# The Ignorability Assumption is not satisfied.
# 6.068987459696546e-11
# The Ignorability Assumption is not satisfied.
# 4.33846795304156e-21
# The Ignorability Assumption is not satisfied.
# 5.473271604297341e-12
# The Ignorability Assumption is not satisfied.
# 8.383817763155078e-15
# The Ignorability Assumption is not satisfied.
# 5.2893339911072415e-18
# The Ignorability Assumption is not satisfied.
# 4.658785446204082e-11
# The Ignorability Assumption is not satisfied.
# 4.336174909990596e-12
# The Ignorability Assumption is not satisfied.
# 7.582587708236797e-22
# The Ignorability Assumption is not satisfied.
# 2.6222689366917445e-18
# The Ignorability Assumption is not satisfied.
# 4.874290925471387e-10
# The Ignorability Assumption is not satisfied.
# 4.5751377340813034e-14
# The Ignorability Assumption is not satisfied.
# 3.0216483900740323e-17
# The Ignorability Assumption is not satisfied.
# 2.2259945386483943e-11
# The Ignorability Assumption is not satisfied.
# 2.0008209803371583e-11
# The Ignorability Assumption is not satisfied.
# 1.7122472717871735e-09
# The Ignorability Assumption is not satisfied.
# 2.5688206915178844e-11
# The Ignorability Assumption is not satisfied.
# 2.5721513662543548e-12
# The Ignorability Assumption is not satisfied.
# 2.817472808935122e-12
# The Ignorability Assumption is not satisfied.
# 4.296651571653911e-12
# The Ignorability Assumption is not satisfied.
# 9.826639062976259e-10
# The Ignorability Assumption is not satisfied.
# 8.708669627456971e-19
# The Ignorability Assumption is not satisfied.
# 4.58368879381179e-12
# The Ignorability Assumption is not satisfied.
# 2.7174899454374928e-18
# The Ignorability Assumption is not satisfied.
# 2.2669493756457964e-10
# The Ignorability Assumption is not satisfied.
# 1.9203146330209642e-09
# The Ignorability Assumption is not satisfied.
# 3.221442669885305e-20
# The Ignorability Assumption is not satisfied.
# 8.221985829658869e-14
# The Ignorability Assumption is not satisfied.
# 7.635222561985795e-14
# The Ignorability Assumption is not satisfied.
# 1.4379394690705811e-13
# The Ignorability Assumption is not satisfied.
# 1.6889169540011873e-15
# The Ignorability Assumption is not satisfied.
# 1.1561069438632642e-11
# The Ignorability Assumption is not satisfied.
# 5.78383103131058e-20
# The Ignorability Assumption is not satisfied.
# 3.394706618265052e-07
# The Ignorability Assumption is not satisfied.
# 1.5384604129393354e-18
# The Ignorability Assumption is not satisfied.
# 3.3885397441136554e-12
# The Ignorability Assumption is not satisfied.
# 5.3428075760482924e-11
# The Ignorability Assumption is not satisfied.
# 2.7760423680009297e-12
# The Ignorability Assumption is not satisfied.
# 2.9678631370221837e-15
# The Ignorability Assumption is not satisfied.
# 7.605022898266589e-10
# The Ignorability Assumption is not satisfied.
# 4.809966552878988e-12
# The Ignorability Assumption is not satisfied.
# 2.1089282767102696e-12
# The Ignorability Assumption is not satisfied.
# 1.5157745343143398e-15
# The Ignorability Assumption is not satisfied.
# 9.818455991787609e-11
# The Ignorability Assumption is not satisfied.
# 1.6908037841722858e-13
# The Ignorability Assumption is not satisfied.
# 2.641475753791284e-15
# The Ignorability Assumption is not satisfied.
# 5.870234129505908e-14
# The Ignorability Assumption is not satisfied.
# 2.340020149832358e-13
# The Ignorability Assumption is not satisfied.
# 3.019249253324448e-14
# The Ignorability Assumption is not satisfied.
# 6.676324369288534e-20
# The Ignorability Assumption is not satisfied.
# 1.846272366451122e-13
# The Ignorability Assumption is not satisfied.
# 1.386432272680451e-12
# The Ignorability Assumption is not satisfied.
# 1.4156853210258462e-11
# The Ignorability Assumption is not satisfied.
# 1.3684377819253962e-08
# The Ignorability Assumption is not satisfied.
# 3.3838775195650187e-14
# The Ignorability Assumption is not satisfied.
# 1.850780845425864e-13
# The Ignorability Assumption is not satisfied.
# 1.6726137808183002e-13
# The Ignorability Assumption is not satisfied.
# 1.2996345996828498e-12
# The Ignorability Assumption is not satisfied.
# 1.1506797643012442e-15
# The Ignorability Assumption is not satisfied.
# 6.148134399296571e-11
# The Ignorability Assumption is not satisfied.
# 1.1052294479230836e-09
# The Ignorability Assumption is not satisfied.
# 1.4863876046498863e-15
# The Ignorability Assumption is not satisfied.
# 2.5733047023067487e-23
# The Ignorability Assumption is not satisfied.
# 3.939225146426455e-14
# The Ignorability Assumption is not satisfied.
# 3.336717128937233e-12
# The Ignorability Assumption is not satisfied.
# 1.749254436408538e-14
# The Ignorability Assumption is not satisfied.
# 2.852204906756885e-18
# The Ignorability Assumption is not satisfied.
# 3.1176895566428217e-12
# The Ignorability Assumption is not satisfied.
# 3.1703942412279566e-11
# The Ignorability Assumption is not satisfied.
# 5.73460613319917e-12
# The Ignorability Assumption is not satisfied.
# 2.9547260732355227e-14
# The Ignorability Assumption is not satisfied.
# 4.31969695569924e-16
# The Ignorability Assumption is not satisfied.
# 1.0025677745401638e-09
# The Ignorability Assumption is not satisfied.
# 1.3094391010821685e-08
# The Ignorability Assumption is not satisfied.
# 7.509148669274458e-09
# The Ignorability Assumption is not satisfied.
# 1.1006927348562646e-11
# The Ignorability Assumption is not satisfied.
# 4.628322284312054e-16
# The Ignorability Assumption is not satisfied.
# 8.89164437700789e-09
# The Ignorability Assumption is not satisfied.
# 1.0709152544991414e-10
# The Ignorability Assumption is not satisfied.
# 2.9276454779119767e-08
# The Ignorability Assumption is not satisfied.
# 2.643791048149736e-13
# The Ignorability Assumption is not satisfied.
# 1.893421390932144e-13
# The Ignorability Assumption is not satisfied.
# 2.854041067855154e-07
# The Ignorability Assumption is not satisfied.
# 1.4092805242440286e-13
# The Ignorability Assumption is not satisfied.
# 8.971475372654293e-15
# The Ignorability Assumption is not satisfied.
# 3.79915926950661e-09
# The Ignorability Assumption is not satisfied.
# 4.771164929901802e-12
# The Ignorability Assumption is not satisfied.
# 1.907083821492381e-14
# The Ignorability Assumption is not satisfied.
# 8.292252781790476e-16
# The Ignorability Assumption is not satisfied.
# 4.015679087800276e-15
# The Ignorability Assumption is not satisfied.
# 2.7062964330541563e-11
# The Ignorability Assumption is not satisfied.
# 8.533111799611237e-10
# The Ignorability Assumption is not satisfied.
# 2.9512397844347796e-10
# The Ignorability Assumption is not satisfied.
# 1.2637020507201616e-14
# The Ignorability Assumption is not satisfied.
# 1.3438128108193221e-15
# The Ignorability Assumption is not satisfied.
# 3.060600426496891e-17
# The Ignorability Assumption is not satisfied.
# 1.5002455100778201e-12
# The Ignorability Assumption is not satisfied.
# 2.829891483007835e-06
# The Ignorability Assumption is not satisfied.
# 1.2239754119683784e-07
# The Ignorability Assumption is not satisfied.
# 1.9157689085105518e-16
# The Ignorability Assumption is not satisfied.
# 6.643005338387892e-08
# The Ignorability Assumption is not satisfied.
# 3.9331006641704644e-13
# The Ignorability Assumption is not satisfied.
# 2.17457258588115e-16
# The Ignorability Assumption is not satisfied.
# 1.3317449860806355e-14
# The Ignorability Assumption is not satisfied.
# 6.469238336284114e-08
# The Ignorability Assumption is not satisfied.
# 2.741689966197571e-12
# The Ignorability Assumption is not satisfied.
# 1.5909350859467777e-10
# The Ignorability Assumption is not satisfied.
# 1.984876655874757e-13
# The Ignorability Assumption is not satisfied.
# 6.352157254337359e-17
# The Ignorability Assumption is not satisfied.
# 4.220169236154142e-15
# The Ignorability Assumption is not satisfied.
# 3.456761180045642e-17
# The Ignorability Assumption is not satisfied.
# 1.9946075810625586e-09
# The Ignorability Assumption is not satisfied.
# 1.1728811677289146e-12
# The Ignorability Assumption is not satisfied.
# 7.445746875885148e-13
# The Ignorability Assumption is not satisfied.
# 7.254702925949008e-15
# The Ignorability Assumption is not satisfied.
# 1.440196018980293e-14
# The Ignorability Assumption is not satisfied.
# 1.5267210615765936e-12
# The Ignorability Assumption is not satisfied.
# 1.2477841497539046e-14
# The Ignorability Assumption is not satisfied.
# 1.1511463716554417e-05
# The Ignorability Assumption is not satisfied.
# 5.8799733630886916e-09
# The Ignorability Assumption is not satisfied.
# 1.181332184159757e-12
# The Ignorability Assumption is not satisfied.
# 3.096545211811653e-15
# The Ignorability Assumption is not satisfied.
# 1.022952753810935e-13
# The Ignorability Assumption is not satisfied.
# 2.429857640851272e-11
# The Ignorability Assumption is not satisfied.
# 6.05150206040069e-09
# The Ignorability Assumption is not satisfied.
# 4.5208297709184635e-13
# The Ignorability Assumption is not satisfied.
# 5.615290426218103e-13
# The Ignorability Assumption is not satisfied.
# 7.917770895577105e-09
# The Ignorability Assumption is not satisfied.
# 7.968189510643361e-10
# The Ignorability Assumption is not satisfied.
# 4.0109766151145893e-13
# The Ignorability Assumption is not satisfied.
# 2.157780558792779e-12
# The Ignorability Assumption is not satisfied.
# 3.5383814568314414e-13
# The Ignorability Assumption is not satisfied.
# 2.271773608567739e-13
# The Ignorability Assumption is not satisfied.
# 3.144767236943252e-08
# The Ignorability Assumption is not satisfied.
# 4.377683682363259e-09
# The Ignorability Assumption is not satisfied.
# 3.0713559936848903e-13
# The Ignorability Assumption is not satisfied.
# 2.0879218813342748e-13
# The Ignorability Assumption is not satisfied.
# 9.384127940932702e-14
# The Ignorability Assumption is not satisfied.
# 2.2366259437470664e-16
# The Ignorability Assumption is not satisfied.
# 5.822337443779356e-11
# The Ignorability Assumption is not satisfied.
# 4.601966519077347e-19
# The Ignorability Assumption is not satisfied.
# 1.3024460483541302e-08
# The Ignorability Assumption is not satisfied.
# 3.0982234836551767e-16
# The Ignorability Assumption is not satisfied.
# 9.008775447739063e-18
# The Ignorability Assumption is not satisfied.
# 1.1043511286370653e-09
# The Ignorability Assumption is not satisfied.
# 3.8921718560829895e-10
# The Ignorability Assumption is not satisfied.
# 2.1064228448389546e-07
# The Ignorability Assumption is not satisfied.
# 3.891233604158994e-10
# The Ignorability Assumption is not satisfied.
# 9.491586401875912e-15
# The Ignorability Assumption is not satisfied.
# 8.330378329979054e-10
# The Ignorability Assumption is not satisfied.
# 1.1976732420248893e-14
# The Ignorability Assumption is not satisfied.
# 1.39030274233281e-14
# The Ignorability Assumption is not satisfied.
# 3.619712375068419e-14
# The Ignorability Assumption is not satisfied.
# 4.49828884000143e-12
# The Ignorability Assumption is not satisfied.
# 4.109838939075097e-12
# The Ignorability Assumption is not satisfied.
# 6.721022919868219e-07
# The Ignorability Assumption is not satisfied.
# 2.5502410176687033e-08
# The Ignorability Assumption is not satisfied.
# 8.366701822970524e-10
# The Ignorability Assumption is not satisfied.
# 2.66619602412081e-19
# The Ignorability Assumption is not satisfied.
# 3.18828805435218e-16
# The Ignorability Assumption is not satisfied.
# 2.8309542621695857e-14
# The Ignorability Assumption is not satisfied.
# 1.085203023467507e-13
# The Ignorability Assumption is not satisfied.
# 3.967339203710333e-13
# The Ignorability Assumption is not satisfied.
# 4.914376021523981e-19
# The Ignorability Assumption is not satisfied.
# 2.4076577307318426e-17
# The Ignorability Assumption is not satisfied.
# 1.8621774144068362e-05
# The Ignorability Assumption is not satisfied.
# 1.4607480925458617e-15
# The Ignorability Assumption is not satisfied.
# 2.7197202076465367e-08
# The Ignorability Assumption is not satisfied.
# 4.207801872092711e-11
# The Ignorability Assumption is not satisfied.
# 4.1175084462647533e-13
# The Ignorability Assumption is not satisfied.
# 1.6127930503244696e-09
# The Ignorability Assumption is not satisfied.
# 1.451008240441041e-13
# The Ignorability Assumption is not satisfied.
# 1.8004312135752992e-07
# The Ignorability Assumption is not satisfied.
# 1.8940180934502335e-13
# The Ignorability Assumption is not satisfied.
# 8.12255127846673e-14
# The Ignorability Assumption is not satisfied.
# 2.0490684954953948e-13
# The Ignorability Assumption is not satisfied.
# 1.6971555756744387e-14
# The Ignorability Assumption is not satisfied.
# 3.7761654176432207e-16
# The Ignorability Assumption is not satisfied.
# 5.461241480717264e-15
# The Ignorability Assumption is not satisfied.
# 3.9165659612792396e-12
# The Ignorability Assumption is not satisfied.
# 2.2559622694717863e-11
# The Ignorability Assumption is not satisfied.
# 2.0726500789393554e-19
# The Ignorability Assumption is not satisfied.
# 4.750323343433752e-09
# The Ignorability Assumption is not satisfied.
# 1.0070810070436057e-11
# The Ignorability Assumption is not satisfied.
# 1.0291663634923902e-14
# The Ignorability Assumption is not satisfied.
# 2.5641563184707535e-13
# The Ignorability Assumption is not satisfied.
# 1.5611819589498057e-10
# The Ignorability Assumption is not satisfied.
# 1.0031382846276998e-17
# The Ignorability Assumption is not satisfied.
# 1.9205399535503974e-08
# The Ignorability Assumption is not satisfied.
# 2.377131710350583e-13
# The Ignorability Assumption is not satisfied.
# 7.345271840070342e-14
# The Ignorability Assumption is not satisfied.
# 5.491304466722381e-08
# The Ignorability Assumption is not satisfied.
# 2.8938637492380634e-11
# The Ignorability Assumption is not satisfied.
# 1.711219196367149e-10
# The Ignorability Assumption is not satisfied.
# 1.5172851858822498e-13
# The Ignorability Assumption is not satisfied.
# 1.8723391427163726e-13
# The Ignorability Assumption is not satisfied.
# 9.245428230124615e-12
# The Ignorability Assumption is not satisfied.
# 9.603472499977631e-09
# The Ignorability Assumption is not satisfied.
# 3.2977130645205274e-18
# The Ignorability Assumption is not satisfied.
# 1.738666252560523e-14
# The Ignorability Assumption is not satisfied.
# 2.991324622483073e-14
# The Ignorability Assumption is not satisfied.
# 8.036819687928885e-10
# The Ignorability Assumption is not satisfied.
# 3.287401144814127e-09
# The Ignorability Assumption is not satisfied.
# 9.689287787264506e-14
# The Ignorability Assumption is not satisfied.
# 1.6780629894447002e-10
# The Ignorability Assumption is not satisfied.
# 1.0010516928420687e-07
# The Ignorability Assumption is not satisfied.
# 4.2851724658737403e-14
# The Ignorability Assumption is not satisfied.
# 3.383861565428237e-12
# The Ignorability Assumption is not satisfied.
# 9.050054947316561e-14
# The Ignorability Assumption is not satisfied.
# 1.1768445931958905e-11
# The Ignorability Assumption is not satisfied.
# 2.55438670886171e-08
# The Ignorability Assumption is not satisfied.
# 6.792672124559548e-13
# The Ignorability Assumption is not satisfied.
# 8.399567032957044e-19
# The Ignorability Assumption is not satisfied.
# 7.402752700582566e-15
# The Ignorability Assumption is not satisfied.
# 6.892965270154564e-21
# The Ignorability Assumption is not satisfied.
# 3.751811784722819e-14
# The Ignorability Assumption is not satisfied.
# 6.4207269876819245e-12
# The Ignorability Assumption is not satisfied.
# 8.376949029026047e-15
# The Ignorability Assumption is not satisfied.
# 1.185518578650273e-10
# The Ignorability Assumption is not satisfied.
# 1.294336617464146e-08
# The Ignorability Assumption is not satisfied.
# 1.31362999175751e-13
# The Ignorability Assumption is not satisfied.
# 1.71224933631264e-08
# The Ignorability Assumption is not satisfied.
# 5.93501026894076e-20
# The Ignorability Assumption is not satisfied.
# 1.3516040680830417e-14
# The Ignorability Assumption is not satisfied.
# 2.0749456170590064e-12
# The Ignorability Assumption is not satisfied.
# 5.30475908558193e-15
# The Ignorability Assumption is not satisfied.
# 2.150964721577991e-11
# The Ignorability Assumption is not satisfied.
# 6.950544998784648e-16
# The Ignorability Assumption is not satisfied.
# 2.285336940465634e-23
# The Ignorability Assumption is not satisfied.
# 4.668193295942736e-10
# The Ignorability Assumption is not satisfied.
# 3.3393543428276334e-10
# The Ignorability Assumption is not satisfied.
# 5.0945224839948236e-12
# The Ignorability Assumption is not satisfied.
# 1.54680311690027e-12
# The Ignorability Assumption is not satisfied.
# 7.873428918327115e-10
# The Ignorability Assumption is not satisfied.
# 3.8902915039275794e-13
# The Ignorability Assumption is not satisfied.
# 2.1928593031173368e-17
# The Ignorability Assumption is not satisfied.
# 2.892028024526766e-15
# The Ignorability Assumption is not satisfied.
# 2.7582770095262574e-13
# The Ignorability Assumption is not satisfied.
# 1.3745559265121068e-09
# The Ignorability Assumption is not satisfied.
# 5.0724781025151965e-15
# The Ignorability Assumption is not satisfied.
# 9.056892214927617e-10
# The Ignorability Assumption is not satisfied.
# 1.9524770828201917e-08
# The Ignorability Assumption is not satisfied.
# 4.5346608515870246e-09
# The Ignorability Assumption is not satisfied.
# 1.0525662638053502e-06
# The Ignorability Assumption is not satisfied.
# 9.690361182534712e-12
# The Ignorability Assumption is not satisfied.
# 6.904894146283948e-11
# The Ignorability Assumption is not satisfied.
# 8.203294612322746e-14
# The Ignorability Assumption is not satisfied.
# 6.386789979346227e-17
# The Ignorability Assumption is not satisfied.
# 2.2182627482085383e-09
# The Ignorability Assumption is not satisfied.
# 5.218091882646138e-11
# The Ignorability Assumption is not satisfied.
# 1.6339312045264314e-12
# The Ignorability Assumption is not satisfied.
# 2.8247419556436403e-14
# The Ignorability Assumption is not satisfied.
# 2.1162984559826507e-13
# The Ignorability Assumption is not satisfied.
# 1.1780996588580742e-12
# The Ignorability Assumption is not satisfied.
# 1.779743178293866e-15
# The Ignorability Assumption is not satisfied.
# 1.90849780558523e-15
# The Ignorability Assumption is not satisfied.
# 4.352856335064461e-15
# The Ignorability Assumption is not satisfied.
# 1.9081503927275396e-16
# The Ignorability Assumption is not satisfied.
# 3.538711599258616e-10
# The Ignorability Assumption is not satisfied.
# 1.005224552231101e-09
# The Ignorability Assumption is not satisfied.
# 5.135000742550339e-10
# The Ignorability Assumption is not satisfied.
# 1.2173100163531734e-06
# The Ignorability Assumption is not satisfied.
# 2.1863942978040294e-15
# The Ignorability Assumption is not satisfied.
# 8.823067686484126e-11
# The Ignorability Assumption is not satisfied.
# 4.448527988430752e-10
# The Ignorability Assumption is not satisfied.
# 8.416424212292404e-09
# The Ignorability Assumption is not satisfied.
# 3.5000067308272213e-07
# The Ignorability Assumption is not satisfied.
# 1.9898037177489606e-11
# The Ignorability Assumption is not satisfied.
# 1.5534360136376524e-08
# The Ignorability Assumption is not satisfied.
# 4.2794691952131417e-19
# The Ignorability Assumption is not satisfied.
# 1.7306590214137676e-11
# The Ignorability Assumption is not satisfied.
# 5.840372528876428e-12
# The Ignorability Assumption is not satisfied.
# 2.9302423276305248e-12
# The Ignorability Assumption is not satisfied.
# 5.13633658264287e-11
# The Ignorability Assumption is not satisfied.
# 3.2488354831970787e-15
# The Ignorability Assumption is not satisfied.
# 2.5999464447485723e-14
# The Ignorability Assumption is not satisfied.
# 5.955399326446853e-17
# The Ignorability Assumption is not satisfied.
# 3.0647265281557327e-18
# The Ignorability Assumption is not satisfied.
# 4.880391960608304e-21
# The Ignorability Assumption is not satisfied.
# 1.3217172954389633e-12
# The Ignorability Assumption is not satisfied.
# 4.489669502144301e-17
# The Ignorability Assumption is not satisfied.
# 4.8204668483712553e-17
# The Ignorability Assumption is not satisfied.
# 4.0530925845584934e-11
# The Ignorability Assumption is not satisfied.
# 2.376889348182656e-15
# The Ignorability Assumption is not satisfied.
# 3.221775854724983e-15
# The Ignorability Assumption is not satisfied.
# 5.354473672562409e-09
# The Ignorability Assumption is not satisfied.
# 2.800681604845525e-08
# The Ignorability Assumption is not satisfied.
# 2.4504743868084384e-11
# The Ignorability Assumption is not satisfied.
# 4.435412859724988e-14
# The Ignorability Assumption is not satisfied.
# 5.291545099637987e-10
# The Ignorability Assumption is not satisfied.
# 5.91894436257974e-11
# The Ignorability Assumption is not satisfied.
# 1.0887582039543736e-21
# The Ignorability Assumption is not satisfied.
# 2.7429449998057047e-12
# The Ignorability Assumption is not satisfied.
# 4.220469153204228e-16
# The Ignorability Assumption is not satisfied.
# 3.876784113788694e-10
# The Ignorability Assumption is not satisfied.
# 4.2452027219478467e-13
# The Ignorability Assumption is not satisfied.
# 2.7786167605408592e-08
# The Ignorability Assumption is not satisfied.
# 3.607580664605319e-07
# The Ignorability Assumption is not satisfied.
# 1.1127504774418696e-14
# The Ignorability Assumption is not satisfied.
# 1.3967480156111997e-09
# The Ignorability Assumption is not satisfied.
# 1.9973850241629042e-15
# The Ignorability Assumption is not satisfied.
# 1.1385015022640744e-09
# The Ignorability Assumption is not satisfied.
# 1.1928798727988124e-16
# The Ignorability Assumption is not satisfied.
# 1.0543130400699546e-13
# The Ignorability Assumption is not satisfied.
# 2.5739554568320944e-17
# The Ignorability Assumption is not satisfied.
# 1.5519856718670787e-10
# The Ignorability Assumption is not satisfied.
# 1.1463759657946593e-07
# The Ignorability Assumption is not satisfied.
# 1.780401338322906e-14
# The Ignorability Assumption is not satisfied.
# 3.8718423344069697e-10
# The Ignorability Assumption is not satisfied.
# 8.581963404150151e-15
# The Ignorability Assumption is not satisfied.
# 2.5687962777994444e-11
# The Ignorability Assumption is not satisfied.
# 1.353717557019731e-11
# The Ignorability Assumption is not satisfied.
# 3.3740876069090013e-16
# The Ignorability Assumption is not satisfied.
# 6.059141084602244e-12
# The Ignorability Assumption is not satisfied.
# 1.5810450886135508e-10
# The Ignorability Assumption is not satisfied.
# 1.9808292124809977e-11
# The Ignorability Assumption is not satisfied.
# 2.3646899612994667e-18
# The Ignorability Assumption is not satisfied.
# 4.66144547383741e-20
# The Ignorability Assumption is not satisfied.
# 1.8389575439855495e-10
# The Ignorability Assumption is not satisfied.
# 1.3605615416194843e-16
# The Ignorability Assumption is not satisfied.
# 6.991940117131717e-08
# The Ignorability Assumption is not satisfied.
# 2.4344572022464585e-18
# The Ignorability Assumption is not satisfied.
# 3.878978773890802e-10
# The Ignorability Assumption is not satisfied.
# 7.431583017421462e-11
# The Ignorability Assumption is not satisfied.
# 1.314599983973351e-16
# The Ignorability Assumption is not satisfied.
# 3.1563845666001695e-13
# The Ignorability Assumption is not satisfied.
# 2.8271884628245736e-10
# The Ignorability Assumption is not satisfied.
# 3.9980578755785795e-15
# The Ignorability Assumption is not satisfied.
# 1.5878011100087621e-09
# The Ignorability Assumption is not satisfied.
# 9.539191898339797e-17
# The Ignorability Assumption is not satisfied.
# 5.496229115005114e-10
# The Ignorability Assumption is not satisfied.
# 7.308294913689624e-12
# The Ignorability Assumption is not satisfied.
# 5.702050169470868e-11
# The Ignorability Assumption is not satisfied.
# 9.435179815445319e-11
# The Ignorability Assumption is not satisfied.
# 1.1950491131071234e-11
# The Ignorability Assumption is not satisfied.
# 4.150989673953365e-11
# The Ignorability Assumption is not satisfied.
# 2.529953567323229e-11
# The Ignorability Assumption is not satisfied.
# 1.5188662370232312e-13
# The Ignorability Assumption is not satisfied.
# 1.1815548572234722e-11
# The Ignorability Assumption is not satisfied.
# 1.0423558017922048e-07
# The Ignorability Assumption is not satisfied.
# 5.98493087286217e-17
# The Ignorability Assumption is not satisfied.
# 2.3410288947129002e-11
# The Ignorability Assumption is not satisfied.
# 1.6004117189199698e-09
# The Ignorability Assumption is not satisfied.
# 7.485511666826928e-16
# The Ignorability Assumption is not satisfied.
# 3.608054254066678e-11
# The Ignorability Assumption is not satisfied.
# 9.343262002946738e-14
# The Ignorability Assumption is not satisfied.
# 7.289994687481384e-12
# The Ignorability Assumption is not satisfied.
# 1.616810803596691e-13
# The Ignorability Assumption is not satisfied.
# 1.3871666974228985e-15
# The Ignorability Assumption is not satisfied.
# 5.123151925616676e-15
# The Ignorability Assumption is not satisfied.
# 4.105068902152737e-08
# The Ignorability Assumption is not satisfied.
# 1.033908912932984e-08
# The Ignorability Assumption is not satisfied.
# 5.430177392176063e-13
# The Ignorability Assumption is not satisfied.
# 4.334026818950415e-07
# The Ignorability Assumption is not satisfied.
# 4.1970242928040295e-13
# The Ignorability Assumption is not satisfied.
# 3.885463549663473e-08
# The Ignorability Assumption is not satisfied.
# 8.264443984334893e-12
# The Ignorability Assumption is not satisfied.
# 1.0441974412783797e-14
# The Ignorability Assumption is not satisfied.
# 1.2359579688391824e-14
# The Ignorability Assumption is not satisfied.
# 2.5862746740423163e-08
# The Ignorability Assumption is not satisfied.
# 2.5907137128221716e-13
# The Ignorability Assumption is not satisfied.
# 3.66221263089484e-12
# The Ignorability Assumption is not satisfied.
# 4.1759850018832974e-11
# The Ignorability Assumption is not satisfied.
# 2.3232525684689596e-10
# The Ignorability Assumption is not satisfied.
# 3.8414078839034494e-11
# The Ignorability Assumption is not satisfied.
# 2.576402058063047e-10
# The Ignorability Assumption is not satisfied.
# 1.3330428910669674e-12
# The Ignorability Assumption is not satisfied.
# 1.7863889933643636e-08
# The Ignorability Assumption is not satisfied.
# 9.708545687925923e-16
# The Ignorability Assumption is not satisfied.
# 2.14593804132013e-11
# The Ignorability Assumption is not satisfied.
# 1.9187371188942012e-11
# The Ignorability Assumption is not satisfied.
# 1.567958717713458e-11
# The Ignorability Assumption is not satisfied.
# 3.91061393327627e-10
# The Ignorability Assumption is not satisfied.
# 8.94268003797019e-13
# The Ignorability Assumption is not satisfied.
# 1.9925725665253868e-10
# The Ignorability Assumption is not satisfied.
# 8.630044550042911e-10
# The Ignorability Assumption is not satisfied.
# 1.8423057209063265e-21
# The Ignorability Assumption is not satisfied.
# 6.655749343811286e-13
# The Ignorability Assumption is not satisfied.
# 2.3883870301100986e-09
# The Ignorability Assumption is not satisfied.
# 1.2007571083208546e-23
# The Ignorability Assumption is not satisfied.
# 1.5582781981495514e-11
# The Ignorability Assumption is not satisfied.
# 1.618173625569131e-18
# The Ignorability Assumption is not satisfied.
# 2.0952871496171707e-13
# The Ignorability Assumption is not satisfied.
# 2.8687789312281354e-19
# The Ignorability Assumption is not satisfied.
# 5.765903891656238e-10
# The Ignorability Assumption is not satisfied.
# 9.283168947714916e-11
# The Ignorability Assumption is not satisfied.
# 1.690453335933235e-08
# The Ignorability Assumption is not satisfied.
# 2.3750615451132245e-16
# The Ignorability Assumption is not satisfied.
# 3.2049490022270556e-12
# The Ignorability Assumption is not satisfied.
# 3.121016861733092e-11
# The Ignorability Assumption is not satisfied.
# 6.265388024744354e-15
# The Ignorability Assumption is not satisfied.
# 1.847456330731023e-11
# The Ignorability Assumption is not satisfied.
# 1.0513948647721593e-12
# The Ignorability Assumption is not satisfied.
# 3.273756579661766e-14
# The Ignorability Assumption is not satisfied.
# 2.7627093134771883e-06
# The Ignorability Assumption is not satisfied.
# 2.512354591225243e-13
# The Ignorability Assumption is not satisfied.
# 5.65289621764993e-17
# The Ignorability Assumption is not satisfied.
# 1.777366399112151e-14
# The Ignorability Assumption is not satisfied.
# 3.907325705652265e-12
# The Ignorability Assumption is not satisfied.
# 6.403403222816853e-11
# The Ignorability Assumption is not satisfied.
# 1.7002867931657762e-16
# The Ignorability Assumption is not satisfied.
# 8.887001042317388e-13
# The Ignorability Assumption is not satisfied.
# 8.560538105333175e-12
# The Ignorability Assumption is not satisfied.
# 3.3682750858360014e-11
# The Ignorability Assumption is not satisfied.
# 5.559609141357779e-12
# The Ignorability Assumption is not satisfied.
# 2.3197937176762994e-20
# The Ignorability Assumption is not satisfied.
# 2.447390692710065e-13
# The Ignorability Assumption is not satisfied.
# 3.7544791816085657e-10
# The Ignorability Assumption is not satisfied.
# 1.180815394394413e-15
# The Ignorability Assumption is not satisfied.
# 5.01629643221701e-10
# The Ignorability Assumption is not satisfied.
# 1.2201917229981647e-10
# The Ignorability Assumption is not satisfied.
# 3.5385700135601676e-13
# The Ignorability Assumption is not satisfied.
# 5.249978015158856e-12
# The Ignorability Assumption is not satisfied.
# 1.8994451076391476e-20
# The Ignorability Assumption is not satisfied.
# 4.388859970358558e-16
# The Ignorability Assumption is not satisfied.
# 7.977242695304527e-08
# The Ignorability Assumption is not satisfied.
# 1.7743995572278253e-22
# The Ignorability Assumption is not satisfied.
# 7.188537303193407e-09
# The Ignorability Assumption is not satisfied.
# 1.2188685559365417e-07
# The Ignorability Assumption is not satisfied.
# 2.6749550287714735e-08
# The Ignorability Assumption is not satisfied.
# 3.7173113281257314e-14
# The Ignorability Assumption is not satisfied.
# 1.5316053015069395e-10
# The Ignorability Assumption is not satisfied.
# 7.453394648230557e-13
# The Ignorability Assumption is not satisfied.
# 5.247923719956576e-17
# The Ignorability Assumption is not satisfied.
# 3.199281756820008e-14
# The Ignorability Assumption is not satisfied.
# 5.995207849722808e-12
# The Ignorability Assumption is not satisfied.
# 2.5271494065439767e-12
# The Ignorability Assumption is not satisfied.
# 1.68845707277009e-16
# The Ignorability Assumption is not satisfied.
# 4.06288936964329e-11
# The Ignorability Assumption is not satisfied.
# 9.385539467048603e-14
# The Ignorability Assumption is not satisfied.
# 1.0935196194415316e-12
# The Ignorability Assumption is not satisfied.
# 7.173290739581644e-08
# The Ignorability Assumption is not satisfied.
# 1.2938619535025884e-10
# The Ignorability Assumption is not satisfied.
# 7.123461185142775e-10
# The Ignorability Assumption is not satisfied.
# 2.1854615340713024e-10
# The Ignorability Assumption is not satisfied.
# 9.219337377948072e-11
# The Ignorability Assumption is not satisfied.
# 2.7341199291391778e-14
# The Ignorability Assumption is not satisfied.
# 2.1446946866846855e-13
# The Ignorability Assumption is not satisfied.
# 2.6107193373849258e-15
# The Ignorability Assumption is not satisfied.
# 3.258487822199013e-11
# The Ignorability Assumption is not satisfied.
# 2.2486716039439474e-10
# The Ignorability Assumption is not satisfied.
# 7.0475570182249855e-12
# The Ignorability Assumption is not satisfied.
# 3.5585928181813125e-14
# The Ignorability Assumption is not satisfied.
# 1.3923373370294616e-15
# The Ignorability Assumption is not satisfied.
# 4.611313669452317e-12
# The Ignorability Assumption is not satisfied.
# 6.040458107268405e-12
# The Ignorability Assumption is not satisfied.
# 2.1439313326180633e-12
# The Ignorability Assumption is not satisfied.
# 9.523585340272573e-23
# The Ignorability Assumption is not satisfied.
# 1.7413542405562866e-15
# The Ignorability Assumption is not satisfied.
# 2.520388494445543e-14
# The Ignorability Assumption is not satisfied.
# 6.447247993825803e-08
# The Ignorability Assumption is not satisfied.
# 2.567172510796713e-12
# The Ignorability Assumption is not satisfied.
# 4.785750023675911e-15
# The Ignorability Assumption is not satisfied.
# 5.368920004601059e-13
# The Ignorability Assumption is not satisfied.
# 3.4452381019556255e-12
# The Ignorability Assumption is not satisfied.
# 7.581424500671669e-18
# The Ignorability Assumption is not satisfied.
# 1.1384299811808524e-15
# The Ignorability Assumption is not satisfied.
# 6.504428102016452e-11
# The Ignorability Assumption is not satisfied.
# 1.9394619100799367e-14
# The Ignorability Assumption is not satisfied.
# 1.3072651130299694e-14
# The Ignorability Assumption is not satisfied.
# 1.0252876228036791e-19
# The Ignorability Assumption is not satisfied.
# 3.04824283252707e-15
# The Ignorability Assumption is not satisfied.
# 6.115428310904455e-13
# The Ignorability Assumption is not satisfied.
# 3.466675617513255e-11
# The Ignorability Assumption is not satisfied.
# 3.534456095421986e-12
# The Ignorability Assumption is not satisfied.
# 1.4356447520348652e-14
# The Ignorability Assumption is not satisfied.
# 7.53954425198776e-13
# The Ignorability Assumption is not satisfied.
# 1.481235212421814e-18
# The Ignorability Assumption is not satisfied.
# 3.7358829409763e-10
# The Ignorability Assumption is not satisfied.
# 7.522704788182852e-15
# The Ignorability Assumption is not satisfied.
# 1.764526543431882e-10
# The Ignorability Assumption is not satisfied.
# 5.344932841487723e-13
# The Ignorability Assumption is not satisfied.
# 1.3536343611138074e-15
# The Ignorability Assumption is not satisfied.
# 7.670036123052586e-15
# The Ignorability Assumption is not satisfied.
# 1.3825234377200716e-11
# The Ignorability Assumption is not satisfied.
# 3.180295023020816e-13
# The Ignorability Assumption is not satisfied.
# 8.08263370156934e-18
# The Ignorability Assumption is not satisfied.
# 9.315679022429846e-12
# The Ignorability Assumption is not satisfied.
# 1.0810510272827401e-12
# The Ignorability Assumption is not satisfied.
# 3.75483301769662e-10
# The Ignorability Assumption is not satisfied.
# 6.2257831805566435e-12
# The Ignorability Assumption is not satisfied.
# 6.535827595300079e-10
# The Ignorability Assumption is not satisfied.
# 3.470642524966944e-10
# The Ignorability Assumption is not satisfied.
# 6.546424865503214e-10
# The Ignorability Assumption is not satisfied.
# 6.577771246660093e-14
# The Ignorability Assumption is not satisfied.
# 4.756911835115864e-08
# The Ignorability Assumption is not satisfied.
# 4.302540238942889e-12
# The Ignorability Assumption is not satisfied.
# 3.601411113381917e-14
# The Ignorability Assumption is not satisfied.
# 7.859949337239404e-13
# The Ignorability Assumption is not satisfied.
# 4.771904486270736e-18
# The Ignorability Assumption is not satisfied.
# 2.62911638342135e-12
# The Ignorability Assumption is not satisfied.
# 1.2854500396424804e-15
# The Ignorability Assumption is not satisfied.
# 2.0491125880143703e-17
# The Ignorability Assumption is not satisfied.
# 7.433161693514942e-08
# The Ignorability Assumption is not satisfied.
# 1.301607421845734e-15
# The Ignorability Assumption is not satisfied.
# 3.55664251715184e-17
# The Ignorability Assumption is not satisfied.
# 2.4099547978957e-10
# The Ignorability Assumption is not satisfied.
# 1.4407951199898336e-17
# The Ignorability Assumption is not satisfied.
# 9.205938312733447e-15
# The Ignorability Assumption is not satisfied.
# 6.2642631821602055e-12
# The Ignorability Assumption is not satisfied.
# 7.148623488617819e-10
# The Ignorability Assumption is not satisfied.
# 1.3096389202991347e-14
# The Ignorability Assumption is not satisfied.
# 3.4704553867679257e-12
# The Ignorability Assumption is not satisfied.
# 1.9648336961788184e-16
# The Ignorability Assumption is not satisfied.
# 1.2002427043700436e-13
# The Ignorability Assumption is not satisfied.
# 2.8646115142671286e-08
# The Ignorability Assumption is not satisfied.
# 3.3004881417096263e-16
# The Ignorability Assumption is not satisfied.
# 2.5451951125191555e-08
# The Ignorability Assumption is not satisfied.
# 1.8499291391620588e-13
# The Ignorability Assumption is not satisfied.
# 3.0379533696197183e-13
# The Ignorability Assumption is not satisfied.
# 8.59333574731908e-12
# ...
# The Ignorability Assumption is not satisfied.
# 7.118418213445725e-21
# The Ignorability Assumption is not satisfied.
# 8.400326757953412e-12
# The Ignorability Assumption is not satisfied.
# 5.950817230340827e-11
# The Ignorability Assumption is not satisfied.
# 1.2491120296300809e-09
# The Ignorability Assumption is not satisfied.
# 3.2982057811301174e-18
# The Ignorability Assumption is not satisfied.
# 1.8002746756063227e-16
# The Ignorability Assumption is not satisfied.
# 4.052038362603043e-09
# The Ignorability Assumption is not satisfied.
# 1.345831537716683e-13
# The Ignorability Assumption is not satisfied.
# 2.1308174727413416e-17
# The Ignorability Assumption is not satisfied.
# 2.2385862672509e-18
# The Ignorability Assumption is not satisfied.
# 1.858108072605871e-13
# The Ignorability Assumption is not satisfied.
# 1.2088764480186349e-11
# The Ignorability Assumption is not satisfied.
# 5.8022189861183294e-11
# The Ignorability Assumption is not satisfied.
# 1.2953595968233434e-08
# The Ignorability Assumption is not satisfied.
# 8.730301039935515e-09
# The Ignorability Assumption is not satisfied.
# 2.202584364877411e-14
# The Ignorability Assumption is not satisfied.
# 1.8548082735092812e-09
# The Ignorability Assumption is not satisfied.
# 1.2923143663385212e-13
# The Ignorability Assumption is not satisfied.
# 7.311003731869846e-11
# The Ignorability Assumption is not satisfied.
# 7.215208669429544e-15
# The Ignorability Assumption is not satisfied.
# 9.518820721177968e-13
# The Ignorability Assumption is not satisfied.
# 3.898175801781626e-09
# The Ignorability Assumption is not satisfied.
# 8.091262882582377e-07
# The Ignorability Assumption is not satisfied.
# 1.431452574250336e-09
# The Ignorability Assumption is not satisfied.
# 4.4202399834583803e-11
# The Ignorability Assumption is not satisfied.
# 6.223228297446525e-11
# The Ignorability Assumption is not satisfied.
# 3.539617572485884e-09
# The Ignorability Assumption is not satisfied.
# 4.759202619928795e-15
# The Ignorability Assumption is not satisfied.
# 4.2488743390999106e-13
# The Ignorability Assumption is not satisfied.
# 1.697869411170632e-15
# The Ignorability Assumption is not satisfied.
# 4.719727602849175e-20
# The Ignorability Assumption is not satisfied.
# 2.3226265307505773e-10
# The Ignorability Assumption is not satisfied.
# 1.0083486633228178e-12
# The Ignorability Assumption is not satisfied.
# 9.351421511264239e-12
# The Ignorability Assumption is not satisfied.
# 8.902549934340772e-10
# The Ignorability Assumption is not satisfied.
# 5.619400721972569e-11
# The Ignorability Assumption is not satisfied.
# 1.351979555794224e-14
# The Ignorability Assumption is not satisfied.
# 6.308313500327745e-10
# The Ignorability Assumption is not satisfied.
# 1.6590575743184033e-09
# The Ignorability Assumption is not satisfied.
# 2.9882826130312725e-08
# The Ignorability Assumption is not satisfied.
# 2.1439006960867948e-07
# The Ignorability Assumption is not satisfied.
# 1.2899229927945245e-10
# The Ignorability Assumption is not satisfied.
# 6.687213949676267e-10
# The Ignorability Assumption is not satisfied.
# 1.603904285694363e-15
# The Ignorability Assumption is not satisfied.
# 2.962161218826002e-13
# The Ignorability Assumption is not satisfied.
# 5.242085530171436e-10
# The Ignorability Assumption is not satisfied.
# 3.2527482838395933e-18
# The Ignorability Assumption is not satisfied.
# 1.075829493796857e-13
# The Ignorability Assumption is not satisfied.
# 4.509747516303885e-15
# The Ignorability Assumption is not satisfied.
# 8.910421699536249e-17
# The Ignorability Assumption is not satisfied.
# 3.2987543853713448e-12
# The Ignorability Assumption is not satisfied.
# 1.2490248098825974e-15
# The Ignorability Assumption is not satisfied.
# 2.0955031875120533e-09
# The Ignorability Assumption is not satisfied.
# 3.8248935557747847e-16
# The Ignorability Assumption is not satisfied.
# 2.0497260110795706e-17
# The Ignorability Assumption is not satisfied.
# 2.1569595435304208e-23
# The Ignorability Assumption is not satisfied.
# 9.478933459574532e-14
# The Ignorability Assumption is not satisfied.
# 2.218944561515209e-09
# The Ignorability Assumption is not satisfied.
# 1.3796698525127074e-15
# The Ignorability Assumption is not satisfied.
# 6.011066323225064e-11
# The Ignorability Assumption is not satisfied.
# 8.611508562925977e-13
# The Ignorability Assumption is not satisfied.
# 2.696689066973757e-08
# The Ignorability Assumption is not satisfied.
# 9.781588059394279e-12
# The Ignorability Assumption is not satisfied.
# 1.300290077388806e-11
# The Ignorability Assumption is not satisfied.
# 5.494236924334974e-10
# The Ignorability Assumption is not satisfied.
# 1.4030379723625622e-08
# The Ignorability Assumption is not satisfied.
# 5.213713795447013e-10
# The Ignorability Assumption is not satisfied.
# 1.8749610525184606e-10
# The Ignorability Assumption is not satisfied.
# 1.0230119626116455e-11
# The Ignorability Assumption is not satisfied.
# 4.472735050502284e-18
# The Ignorability Assumption is not satisfied.
# 3.360950292011733e-14
# The Ignorability Assumption is not satisfied.
# 5.550367528472468e-16
# The Ignorability Assumption is not satisfied.
# 4.180977516491366e-16
# The Ignorability Assumption is not satisfied.
# 8.569865056403441e-09
# The Ignorability Assumption is not satisfied.
# 2.4307842065352586e-12
# The Ignorability Assumption is not satisfied.
# 1.8489034497177337e-10
# The Ignorability Assumption is not satisfied.
# 1.5703246089120497e-16
# The Ignorability Assumption is not satisfied.
# 7.258413684301036e-12
# The Ignorability Assumption is not satisfied.
# 2.8040349514915655e-12
# The Ignorability Assumption is not satisfied.
# 2.9602103169344084e-07
# The Ignorability Assumption is not satisfied.
# 1.2725070287760785e-19
# The Ignorability Assumption is not satisfied.
# 1.4455873272499139e-13
# The Ignorability Assumption is not satisfied.
# 4.7838414288695895e-08
# The Ignorability Assumption is not satisfied.
# 3.5675471842455238e-12
# The Ignorability Assumption is not satisfied.
# 3.78253541298985e-17
# The Ignorability Assumption is not satisfied.
# 7.972104285576441e-16
# The Ignorability Assumption is not satisfied.
# 2.4685145288187966e-14
# The Ignorability Assumption is not satisfied.
# 2.0611229504762097e-14
# The Ignorability Assumption is not satisfied.
# 6.20246495326455e-16
# The Ignorability Assumption is not satisfied.
# 5.22336478834452e-12
# The Ignorability Assumption is not satisfied.
# 2.0583389647666776e-09
# The Ignorability Assumption is not satisfied.
# 5.951715583521529e-10
# The Ignorability Assumption is not satisfied.
# 7.388003929453394e-17
# The Ignorability Assumption is not satisfied.
# 5.930223967869077e-09
# The Ignorability Assumption is not satisfied.
# 2.250883376875471e-06
# The Ignorability Assumption is not satisfied.
# 7.01613936402981e-11
# The Ignorability Assumption is not satisfied.
# 3.136833071840222e-18
# The Ignorability Assumption is not satisfied.
# 2.1914594317975815e-05
# The Ignorability Assumption is not satisfied.
# 7.546344530952318e-09
# The Ignorability Assumption is not satisfied.
# 2.7470769648578465e-09
# The Ignorability Assumption is not satisfied.
# 1.3888994589067582e-11
# The Ignorability Assumption is not satisfied.
# 1.6807073341169603e-15
# The Ignorability Assumption is not satisfied.
# 6.981389353431624e-14
# The Ignorability Assumption is not satisfied.
# 8.00856097456066e-15
# The Ignorability Assumption is not satisfied.
# 5.267938330996506e-15
# The Ignorability Assumption is not satisfied.
# 1.14614856437517e-23
# The Ignorability Assumption is not satisfied.
# 5.311789878005499e-12
# The Ignorability Assumption is not satisfied.
# 4.600623212741253e-19
# The Ignorability Assumption is not satisfied.
# 1.6597964178341531e-12
# The Ignorability Assumption is not satisfied.
# 2.3574039267845814e-14
# The Ignorability Assumption is not satisfied.
# 1.0905322156139524e-12
# The Ignorability Assumption is not satisfied.
# 2.1079494175812193e-14
# The Ignorability Assumption is not satisfied.
# 3.129696159680951e-11
# The Ignorability Assumption is not satisfied.
# 1.1791748852664619e-11
# The Ignorability Assumption is not satisfied.
# 1.7038852801098238e-09
# The Ignorability Assumption is not satisfied.
# 1.060315516084353e-12
# The Ignorability Assumption is not satisfied.
# 4.42271066695667e-11
# The Ignorability Assumption is not satisfied.
# 1.1753559418481035e-15
# The Ignorability Assumption is not satisfied.
# 5.40031717826208e-09
# The Ignorability Assumption is not satisfied.
# 1.3551627419850287e-15
# The Ignorability Assumption is not satisfied.
# 2.9009281721513553e-15
# The Ignorability Assumption is not satisfied.
# 1.2900146769680076e-12
# The Ignorability Assumption is not satisfied.
# 2.532478802417777e-11
# The Ignorability Assumption is not satisfied.
# 3.668615622955831e-14
# The Ignorability Assumption is not satisfied.
# 1.3120972748099922e-18
# The Ignorability Assumption is not satisfied.
# 3.423675699615623e-16
# The Ignorability Assumption is not satisfied.
# 1.272985262172687e-11
# The Ignorability Assumption is not satisfied.
# 9.149896869393578e-15
# The Ignorability Assumption is not satisfied.
# 6.700570251527368e-11
# The Ignorability Assumption is not satisfied.
# 2.2097742695103848e-08
# The Ignorability Assumption is not satisfied.
# 9.83592977251053e-11
# The Ignorability Assumption is not satisfied.
# 3.993918691799172e-10
# The Ignorability Assumption is not satisfied.
# 3.464470322703901e-12
# The Ignorability Assumption is not satisfied.
# 9.785833355228582e-11
# The Ignorability Assumption is not satisfied.
# 6.847030104963733e-17
# The Ignorability Assumption is not satisfied.
# 2.6461629547747915e-10
# The Ignorability Assumption is not satisfied.
# 6.349776689048038e-11
# The Ignorability Assumption is not satisfied.
# 3.1928303006172806e-11
# The Ignorability Assumption is not satisfied.
# 4.100152505649325e-09
# The Ignorability Assumption is not satisfied.
# 1.4209189290992807e-13
# The Ignorability Assumption is not satisfied.
# 4.1494969895954845e-17
# The Ignorability Assumption is not satisfied.
# 2.5030753830741914e-10
# The Ignorability Assumption is not satisfied.
# 1.7068583879315844e-17
# The Ignorability Assumption is not satisfied.
# 3.516585722966478e-09
# The Ignorability Assumption is not satisfied.
# 2.2896170480564186e-11
# The Ignorability Assumption is not satisfied.
# 6.9130102528853785e-15
# The Ignorability Assumption is not satisfied.
# 7.358556737306314e-15
# The Ignorability Assumption is not satisfied.
# 2.3480871584876113e-16
# The Ignorability Assumption is not satisfied.
# 8.105096376514815e-15
# The Ignorability Assumption is not satisfied.
# 2.1759206335979082e-13
# The Ignorability Assumption is not satisfied.
# 1.016492679656124e-16
# The Ignorability Assumption is not satisfied.
# 1.2028142196136062e-07
# The Ignorability Assumption is not satisfied.
# 6.657522552792093e-13
# The Ignorability Assumption is not satisfied.
# 6.199104014453307e-18
# The Ignorability Assumption is not satisfied.
# 2.490837627215436e-14
# The Ignorability Assumption is not satisfied.
# 9.773698305954943e-09
# The Ignorability Assumption is not satisfied.
# 2.885622942495681e-06
# The Ignorability Assumption is not satisfied.
# 1.818705111654881e-11
# The Ignorability Assumption is not satisfied.
# 2.4721446448082924e-18
# The Ignorability Assumption is not satisfied.
# 1.159792516156828e-09
# The Ignorability Assumption is not satisfied.
# 4.5203493571327216e-11
# The Ignorability Assumption is not satisfied.
# 5.404149899616282e-10
# The Ignorability Assumption is not satisfied.
# 3.880405288497839e-09
# The Ignorability Assumption is not satisfied.
# 4.764126857563319e-16
# The Ignorability Assumption is not satisfied.
# 2.6188224483456415e-18
# The Ignorability Assumption is not satisfied.
# 1.0366467326864265e-13
# The Ignorability Assumption is not satisfied.
# 1.8625311857612025e-21
# The Ignorability Assumption is not satisfied.
# 3.2948679567141217e-10
# The Ignorability Assumption is not satisfied.
# 2.1486533338373008e-15
# The Ignorability Assumption is not satisfied.
# 3.0152313404623826e-14
# The Ignorability Assumption is not satisfied.
# 1.7027271113327998e-12
# The Ignorability Assumption is not satisfied.
# 3.344410989086436e-11
# The Ignorability Assumption is not satisfied.
# 1.2057247281920278e-09
# The Ignorability Assumption is not satisfied.
# 6.902739647731994e-13
# The Ignorability Assumption is not satisfied.
# 7.466735948514139e-21
# The Ignorability Assumption is not satisfied.
# 2.6216418602749193e-09
# The Ignorability Assumption is not satisfied.
# 5.633956368336591e-12
# The Ignorability Assumption is not satisfied.
# 7.837466599778175e-12
# The Ignorability Assumption is not satisfied.
# 5.447330214515737e-07
# The Ignorability Assumption is not satisfied.
# 4.737897953515423e-10
# The Ignorability Assumption is not satisfied.
# 1.2802602084596225e-12
# The Ignorability Assumption is not satisfied.
# 1.7942763508850886e-07
# The Ignorability Assumption is not satisfied.
# 5.5479706257541265e-11
# The Ignorability Assumption is not satisfied.
# 6.084424201605112e-06
# The Ignorability Assumption is not satisfied.
# 1.358317953282985e-07
# The Ignorability Assumption is not satisfied.
# 1.4653468072275124e-08
# The Ignorability Assumption is not satisfied.
# 1.2330349718652494e-10
# The Ignorability Assumption is not satisfied.
# 3.396672455945164e-11
# The Ignorability Assumption is not satisfied.
# 1.2567160377075086e-10
# The Ignorability Assumption is not satisfied.
# 3.487676911870941e-10
# The Ignorability Assumption is not satisfied.
# 6.419235442262329e-18
# The Ignorability Assumption is not satisfied.
# 1.0080897696606508e-11
# The Ignorability Assumption is not satisfied.
# 1.5677172538745375e-10
# The Ignorability Assumption is not satisfied.
# 7.755619580338175e-10
# The Ignorability Assumption is not satisfied.
# 6.126137704174966e-14
# The Ignorability Assumption is not satisfied.
# 6.014995455608828e-13
# The Ignorability Assumption is not satisfied.
# 1.4178749338055447e-10
# The Ignorability Assumption is not satisfied.
# 2.081501747365935e-12
# The Ignorability Assumption is not satisfied.
# 8.355873084286265e-14
# The Ignorability Assumption is not satisfied.
# 3.1216941681253677e-14
# The Ignorability Assumption is not satisfied.
# 1.3286717433878512e-10
# The Ignorability Assumption is not satisfied.
# 4.2291801941883777e-13
# The Ignorability Assumption is not satisfied.
# 2.0599348478437034e-11
# The Ignorability Assumption is not satisfied.
# 3.376769598750568e-12
# The Ignorability Assumption is not satisfied.
# 1.0069690907309596e-12
# The Ignorability Assumption is not satisfied.
# 5.281165880166396e-12
# The Ignorability Assumption is not satisfied.
# 5.479731351792777e-14
# The Ignorability Assumption is not satisfied.
# 6.326269887090097e-09
# The Ignorability Assumption is not satisfied.
# 6.501636803768956e-11
# The Ignorability Assumption is not satisfied.
# 1.9397498857690464e-11
# The Ignorability Assumption is not satisfied.
# 1.4344407751571966e-12
# The Ignorability Assumption is not satisfied.
# 2.86558427818672e-14
# The Ignorability Assumption is not satisfied.
# 1.7506285439994594e-15
# The Ignorability Assumption is not satisfied.
# 7.21183337961701e-11
# The Ignorability Assumption is not satisfied.
# 2.7247337528331435e-14
# The Ignorability Assumption is not satisfied.
# 2.9977360652867945e-09
# The Ignorability Assumption is not satisfied.
# 1.2227367041099494e-13
# The Ignorability Assumption is not satisfied.
# 5.766061883878524e-14
# The Ignorability Assumption is not satisfied.
# 3.195380391512058e-08
# The Ignorability Assumption is not satisfied.
# 8.998367373756637e-17
# The Ignorability Assumption is not satisfied.
# 7.1169730008935096e-12
# The Ignorability Assumption is not satisfied.
# 3.551543106785719e-09
# The Ignorability Assumption is not satisfied.
# 2.8853873046865484e-11
# The Ignorability Assumption is not satisfied.
# 1.1252018692292508e-13
# The Ignorability Assumption is not satisfied.
# 1.2760903706853451e-20
# The Ignorability Assumption is not satisfied.
# 4.7984282200862826e-12
# The Ignorability Assumption is not satisfied.
# 9.342809063857668e-12
# The Ignorability Assumption is not satisfied.
# 5.299016880974974e-10
# The Ignorability Assumption is not satisfied.
# 1.4586820558861808e-10
# The Ignorability Assumption is not satisfied.
# 9.34798216379389e-16
# The Ignorability Assumption is not satisfied.
# 9.140902941250595e-13
# The Ignorability Assumption is not satisfied.
# 4.567609460416682e-12
# The Ignorability Assumption is not satisfied.
# 1.97868974249088e-10
# The Ignorability Assumption is not satisfied.

# %%
COUNT2
# Out:
# 1000

# %% [markdown]
# ### Scenario 3

# %%
# 2종 오류 (confounder인 C가 안 찾아짐.)

np.random.seed(1)

COUNT3 = 0
for i in range(1000):
    
    n = 1000 
    k0_co = 0.3
    k1_co = 1
    k0_at = 0.8
    k1_at = 0
    k0_nt = 0.3
    k1_nt = 1

    a0 = -2 #changeable
    a1 = -1

    X = np.random.binomial(1,0.5,size=n)

    mu_Z = 1/(1+np.exp(1-2*X))
    Z = np.random.binomial(1,mu_Z,size=n)

    p_at = np.exp(-2.5+3.5*X)/(1+np.exp(-2.5+3.5*X)+np.exp(-2.5+3.5*X))
    p_nt = np.exp(-2.5+3.5*X)/(1+np.exp(-2.5+3.5*X)+np.exp(-2.5+3.5*X))
    p_co = 1/(1+np.exp(-2.5+3.5*X)+np.exp(-2.5+3.5*X))

    C=[]
    for j in range(n):
        C.append(np.random.choice(["co","at","nt"], size=1, replace=True, p=[p_at[j],p_nt[j],p_co[j]])[0])
    C=np.array(C)

    A = np.repeat(0,n)
    A[C=="at"] = 1
    A[(C=="co")*(Z==1)] = 1

    Y = np.random.normal(0,1,n)
    for k in range(n):

        if C[k]=="co":
            mu_y = k0_co+k1_co*X[k]+(a0+a1*X[k])*A[k]
            Y[k] = np.random.normal(mu_y,1,1)[0]
        elif C[k] == "at":
            mu_y = k0_at+k1_at*X[k]
            Y[k] = np.random.normal(mu_y,1,1)[0]
        else:
            mu_y = k0_nt+k1_nt*X[k]
            Y[k] = np.random.normal(mu_y,1,1)[0]
            
    #data = pd.DataFrame({"col1":Y,"col2":Z,"col3":A,"col4":C,"col5":X})
    #data.loc[data["col4"]=="nt","col4"] = 0 
    #data.loc[data["col4"]=="co","col4"] = 1
    #data.loc[data["col4"]=="at","col4"] = 2 
    
    pvalue = IgnorTest(cause=A, effect=Y, explorer=Z, covariate=X, level=0.05, dtype="mixed")
    if pvalue<=0.05:
        COUNT3 = COUNT3+1
# Out:
# 8.683126104351939e-12
# The Ignorability Assumption is not satisfied.
# 1.54037646506326e-17
# The Ignorability Assumption is not satisfied.
# 3.1883958721572183e-09
# The Ignorability Assumption is not satisfied.
# 1.3687147551545835e-12
# The Ignorability Assumption is not satisfied.
# 1.1258324965457795e-18
# The Ignorability Assumption is not satisfied.
# 3.2676321800335454e-07
# The Ignorability Assumption is not satisfied.
# 3.710047742763449e-10
# The Ignorability Assumption is not satisfied.
# 3.323845517162924e-15
# The Ignorability Assumption is not satisfied.
# 4.442603387360144e-16
# The Ignorability Assumption is not satisfied.
# 5.204818448207724e-12
# The Ignorability Assumption is not satisfied.
# 6.736964755443751e-15
# The Ignorability Assumption is not satisfied.
# 1.6155878707929714e-06
# The Ignorability Assumption is not satisfied.
# 1.2526221519901941e-12
# The Ignorability Assumption is not satisfied.
# 1.1094588546110785e-18
# The Ignorability Assumption is not satisfied.
# 2.403790063679607e-15
# The Ignorability Assumption is not satisfied.
# 2.58691220672318e-16
# The Ignorability Assumption is not satisfied.
# 6.606352572368976e-14
# The Ignorability Assumption is not satisfied.
# 4.4721586461102934e-14
# The Ignorability Assumption is not satisfied.
# 1.0703384336619847e-16
# The Ignorability Assumption is not satisfied.
# 3.3257775859263142e-15
# The Ignorability Assumption is not satisfied.
# 7.047232480228391e-12
# The Ignorability Assumption is not satisfied.
# 2.854493825863168e-17
# The Ignorability Assumption is not satisfied.
# 2.385638421802012e-09
# The Ignorability Assumption is not satisfied.
# 2.8315238912324868e-14
# The Ignorability Assumption is not satisfied.
# 3.2260298777303814e-15
# The Ignorability Assumption is not satisfied.
# 3.376547219152639e-10
# The Ignorability Assumption is not satisfied.
# 1.0614175742913565e-14
# The Ignorability Assumption is not satisfied.
# 1.2111433516934385e-09
# The Ignorability Assumption is not satisfied.
# 2.140276980172791e-17
# The Ignorability Assumption is not satisfied.
# 2.3698849178557044e-10
# The Ignorability Assumption is not satisfied.
# 8.103957124495368e-14
# The Ignorability Assumption is not satisfied.
# 2.106383266897106e-13
# The Ignorability Assumption is not satisfied.
# 9.051390626197928e-16
# The Ignorability Assumption is not satisfied.
# 1.2149767279027e-13
# The Ignorability Assumption is not satisfied.
# 1.3752997390403977e-18
# The Ignorability Assumption is not satisfied.
# 1.3416608279850304e-13
# The Ignorability Assumption is not satisfied.
# 4.935772780558802e-16
# The Ignorability Assumption is not satisfied.
# 9.405272175424945e-15
# The Ignorability Assumption is not satisfied.
# 3.016932982476167e-10
# The Ignorability Assumption is not satisfied.
# 1.0232047797696187e-14
# The Ignorability Assumption is not satisfied.
# 2.2355974694681692e-15
# The Ignorability Assumption is not satisfied.
# 3.842870658036783e-12
# The Ignorability Assumption is not satisfied.
# 3.4820757649997905e-11
# The Ignorability Assumption is not satisfied.
# 8.027798279894593e-10
# The Ignorability Assumption is not satisfied.
# 1.4823365914699003e-19
# The Ignorability Assumption is not satisfied.
# 4.396693976066024e-06
# The Ignorability Assumption is not satisfied.
# 1.0200758806128707e-12
# The Ignorability Assumption is not satisfied.
# 6.414799371005899e-10
# The Ignorability Assumption is not satisfied.
# 6.511050606958386e-08
# The Ignorability Assumption is not satisfied.
# 2.2450174635920732e-14
# The Ignorability Assumption is not satisfied.
# 5.229041015365444e-14
# The Ignorability Assumption is not satisfied.
# 1.1606678346060521e-13
# The Ignorability Assumption is not satisfied.
# 7.427626626183864e-11
# The Ignorability Assumption is not satisfied.
# 4.4730142568148e-11
# The Ignorability Assumption is not satisfied.
# 2.990491370599404e-13
# The Ignorability Assumption is not satisfied.
# 1.4484077313304175e-11
# The Ignorability Assumption is not satisfied.
# 2.048930829279684e-11
# The Ignorability Assumption is not satisfied.
# 4.934350733350604e-10
# The Ignorability Assumption is not satisfied.
# 5.116792118516653e-13
# The Ignorability Assumption is not satisfied.
# 1.4811476068489445e-08
# The Ignorability Assumption is not satisfied.
# 1.689271851037745e-11
# The Ignorability Assumption is not satisfied.
# 5.057042010283543e-10
# The Ignorability Assumption is not satisfied.
# 3.775054528765018e-17
# The Ignorability Assumption is not satisfied.
# 3.1376609461518593e-10
# The Ignorability Assumption is not satisfied.
# 2.092379459936424e-15
# The Ignorability Assumption is not satisfied.
# 1.6771166180114066e-15
# The Ignorability Assumption is not satisfied.
# 2.0490225281378638e-10
# The Ignorability Assumption is not satisfied.
# 1.181298517738645e-10
# The Ignorability Assumption is not satisfied.
# 5.086486709840481e-15
# The Ignorability Assumption is not satisfied.
# 1.1414318298277251e-07
# The Ignorability Assumption is not satisfied.
# 7.970123262160343e-11
# The Ignorability Assumption is not satisfied.
# 6.745292759873076e-11
# The Ignorability Assumption is not satisfied.
# 2.3682694994081936e-15
# The Ignorability Assumption is not satisfied.
# 3.787401313303435e-10
# The Ignorability Assumption is not satisfied.
# 1.5561788120591448e-10
# The Ignorability Assumption is not satisfied.
# 5.584044545645119e-16
# The Ignorability Assumption is not satisfied.
# 1.9857628435937268e-16
# The Ignorability Assumption is not satisfied.
# 1.3320337494694643e-17
# The Ignorability Assumption is not satisfied.
# 9.456553889620042e-14
# The Ignorability Assumption is not satisfied.
# 2.660091081741109e-09
# The Ignorability Assumption is not satisfied.
# 1.4543753617984322e-18
# The Ignorability Assumption is not satisfied.
# 3.1721788360402023e-15
# The Ignorability Assumption is not satisfied.
# 2.9364162556457524e-15
# The Ignorability Assumption is not satisfied.
# 1.1421376747599665e-11
# The Ignorability Assumption is not satisfied.
# 1.5464657592179408e-16
# The Ignorability Assumption is not satisfied.
# 3.0884948751283134e-16
# The Ignorability Assumption is not satisfied.
# 1.5469532587251384e-14
# The Ignorability Assumption is not satisfied.
# 1.1067058434133746e-16
# The Ignorability Assumption is not satisfied.
# 9.707800798568696e-08
# The Ignorability Assumption is not satisfied.
# 3.901010972857967e-08
# The Ignorability Assumption is not satisfied.
# 3.503999076487248e-13
# The Ignorability Assumption is not satisfied.
# 2.392993971754244e-15
# The Ignorability Assumption is not satisfied.
# 1.4845883625740855e-10
# The Ignorability Assumption is not satisfied.
# 1.4157323986941646e-15
# The Ignorability Assumption is not satisfied.
# 7.828392430482527e-08
# The Ignorability Assumption is not satisfied.
# 2.520211960796172e-07
# The Ignorability Assumption is not satisfied.
# 2.158890803412654e-13
# The Ignorability Assumption is not satisfied.
# 1.6001691879468486e-11
# The Ignorability Assumption is not satisfied.
# 6.458243525718942e-14
# The Ignorability Assumption is not satisfied.
# 3.347536577857753e-11
# The Ignorability Assumption is not satisfied.
# 8.972576606881801e-09
# The Ignorability Assumption is not satisfied.
# 9.658938417187714e-13
# The Ignorability Assumption is not satisfied.
# 4.543971989870998e-14
# The Ignorability Assumption is not satisfied.
# 1.6093228270959653e-15
# The Ignorability Assumption is not satisfied.
# 1.823356972073698e-11
# The Ignorability Assumption is not satisfied.
# 4.0937744319408604e-20
# The Ignorability Assumption is not satisfied.
# 2.2253606673526583e-15
# The Ignorability Assumption is not satisfied.
# 2.8265784141162725e-09
# The Ignorability Assumption is not satisfied.
# 5.489398731145088e-15
# The Ignorability Assumption is not satisfied.
# 1.3288166104217789e-08
# The Ignorability Assumption is not satisfied.
# 1.1943480298465212e-09
# The Ignorability Assumption is not satisfied.
# 1.2503688261901944e-08
# The Ignorability Assumption is not satisfied.
# 7.326549008906246e-12
# The Ignorability Assumption is not satisfied.
# 1.6316325736972445e-12
# The Ignorability Assumption is not satisfied.
# 9.23293901495541e-07
# The Ignorability Assumption is not satisfied.
# 2.017821284768422e-09
# The Ignorability Assumption is not satisfied.
# 2.7297810286003687e-14
# The Ignorability Assumption is not satisfied.
# 1.0239507235018677e-09
# The Ignorability Assumption is not satisfied.
# 3.9985704024989964e-10
# The Ignorability Assumption is not satisfied.
# 2.3682493788960683e-06
# The Ignorability Assumption is not satisfied.
# 1.7909245546017523e-10
# The Ignorability Assumption is not satisfied.
# 4.4913431412617466e-14
# The Ignorability Assumption is not satisfied.
# 1.1950423130047746e-16
# The Ignorability Assumption is not satisfied.
# 2.410222734919883e-16
# The Ignorability Assumption is not satisfied.
# 3.901835991577182e-08
# The Ignorability Assumption is not satisfied.
# 2.275551306852854e-12
# The Ignorability Assumption is not satisfied.
# 2.422994760940246e-15
# The Ignorability Assumption is not satisfied.
# 3.038888216749165e-10
# The Ignorability Assumption is not satisfied.
# 2.480819824952705e-11
# The Ignorability Assumption is not satisfied.
# 1.693346257715239e-14
# The Ignorability Assumption is not satisfied.
# 9.662647407844452e-09
# The Ignorability Assumption is not satisfied.
# 8.980734438720817e-16
# The Ignorability Assumption is not satisfied.
# 1.2836981256312604e-13
# The Ignorability Assumption is not satisfied.
# 5.363878330809932e-13
# The Ignorability Assumption is not satisfied.
# 1.8482036800626595e-09
# The Ignorability Assumption is not satisfied.
# 2.3565869410595282e-14
# The Ignorability Assumption is not satisfied.
# 3.289925983631341e-10
# The Ignorability Assumption is not satisfied.
# 1.330281606537914e-10
# The Ignorability Assumption is not satisfied.
# 4.778419676482627e-17
# The Ignorability Assumption is not satisfied.
# 1.9296130917057745e-08
# The Ignorability Assumption is not satisfied.
# 1.3799070918818724e-12
# The Ignorability Assumption is not satisfied.
# 3.5655765681746325e-14
# The Ignorability Assumption is not satisfied.
# 1.5575625860781903e-13
# The Ignorability Assumption is not satisfied.
# 2.3748172558894064e-22
# The Ignorability Assumption is not satisfied.
# 1.5671186088685511e-06
# The Ignorability Assumption is not satisfied.
# 1.7359001288756564e-16
# The Ignorability Assumption is not satisfied.
# 3.30252985074514e-11
# The Ignorability Assumption is not satisfied.
# 7.613203797573875e-10
# The Ignorability Assumption is not satisfied.
# 4.7982790918681295e-09
# The Ignorability Assumption is not satisfied.
# 6.251669461000815e-13
# The Ignorability Assumption is not satisfied.
# 2.2005160966588392e-18
# The Ignorability Assumption is not satisfied.
# 6.502974734358888e-11
# The Ignorability Assumption is not satisfied.
# 2.02422219654641e-16
# The Ignorability Assumption is not satisfied.
# 2.1340604910398262e-13
# The Ignorability Assumption is not satisfied.
# 1.001369019584072e-12
# The Ignorability Assumption is not satisfied.
# 1.8825826000334422e-11
# The Ignorability Assumption is not satisfied.
# 5.463746582555912e-12
# The Ignorability Assumption is not satisfied.
# 1.0668907816399084e-19
# The Ignorability Assumption is not satisfied.
# 7.892707855850781e-11
# The Ignorability Assumption is not satisfied.
# 2.224705758743281e-18
# The Ignorability Assumption is not satisfied.
# 1.7181699663963453e-12
# The Ignorability Assumption is not satisfied.
# 9.332729010299254e-10
# The Ignorability Assumption is not satisfied.
# 2.9739096702177955e-09
# The Ignorability Assumption is not satisfied.
# 4.906981085206859e-15
# The Ignorability Assumption is not satisfied.
# 1.1599839704202771e-12
# The Ignorability Assumption is not satisfied.
# 2.5547265393875655e-14
# The Ignorability Assumption is not satisfied.
# 1.3232916843594331e-07
# The Ignorability Assumption is not satisfied.
# 2.856014651805609e-13
# The Ignorability Assumption is not satisfied.
# 1.499757681315745e-12
# The Ignorability Assumption is not satisfied.
# 7.081864111494982e-17
# The Ignorability Assumption is not satisfied.
# 1.813353823754456e-11
# The Ignorability Assumption is not satisfied.
# 1.6471806116029525e-17
# The Ignorability Assumption is not satisfied.
# 3.1490788216114965e-18
# The Ignorability Assumption is not satisfied.
# 3.4378941052879637e-10
# The Ignorability Assumption is not satisfied.
# 1.594805033607589e-07
# The Ignorability Assumption is not satisfied.
# 3.453888347936428e-11
# The Ignorability Assumption is not satisfied.
# 1.530916083636561e-09
# The Ignorability Assumption is not satisfied.
# 1.928303452267697e-09
# The Ignorability Assumption is not satisfied.
# 1.3546120266686017e-09
# The Ignorability Assumption is not satisfied.
# 3.368482015403294e-10
# The Ignorability Assumption is not satisfied.
# 8.381803396057187e-18
# The Ignorability Assumption is not satisfied.
# 4.944643704656886e-16
# The Ignorability Assumption is not satisfied.
# 1.3121344272456097e-13
# The Ignorability Assumption is not satisfied.
# 2.3451004150609558e-09
# The Ignorability Assumption is not satisfied.
# 6.509349154683369e-10
# The Ignorability Assumption is not satisfied.
# 4.5746942560909717e-14
# The Ignorability Assumption is not satisfied.
# 4.2385890871453914e-14
# The Ignorability Assumption is not satisfied.
# 1.4099721634269733e-10
# The Ignorability Assumption is not satisfied.
# 1.2315561624878692e-14
# The Ignorability Assumption is not satisfied.
# 9.150788629621138e-16
# The Ignorability Assumption is not satisfied.
# 1.045686927161204e-12
# The Ignorability Assumption is not satisfied.
# 6.349476607228058e-11
# The Ignorability Assumption is not satisfied.
# 6.068987459696546e-11
# The Ignorability Assumption is not satisfied.
# 4.338467953041005e-21
# The Ignorability Assumption is not satisfied.
# 5.473271604296719e-12
# The Ignorability Assumption is not satisfied.
# 8.383817763155078e-15
# The Ignorability Assumption is not satisfied.
# 5.2893339911072415e-18
# The Ignorability Assumption is not satisfied.
# 4.658785446204579e-11
# The Ignorability Assumption is not satisfied.
# 4.336174909990596e-12
# The Ignorability Assumption is not satisfied.
# 7.582587708236797e-22
# The Ignorability Assumption is not satisfied.
# 2.6222689366917445e-18
# The Ignorability Assumption is not satisfied.
# 4.874290925471387e-10
# The Ignorability Assumption is not satisfied.
# 4.5751377340813034e-14
# The Ignorability Assumption is not satisfied.
# 3.021648390073302e-17
# The Ignorability Assumption is not satisfied.
# 2.2259945386486392e-11
# The Ignorability Assumption is not satisfied.
# 2.0008209803371583e-11
# The Ignorability Assumption is not satisfied.
# 1.7122472717871735e-09
# The Ignorability Assumption is not satisfied.
# 2.5688206915175924e-11
# The Ignorability Assumption is not satisfied.
# 2.5721513662543548e-12
# The Ignorability Assumption is not satisfied.
# 2.817472808935442e-12
# The Ignorability Assumption is not satisfied.
# 4.296651571653911e-12
# The Ignorability Assumption is not satisfied.
# 9.826639062976259e-10
# The Ignorability Assumption is not satisfied.
# 8.708669627456971e-19
# The Ignorability Assumption is not satisfied.
# 4.58368879381179e-12
# The Ignorability Assumption is not satisfied.
# 2.7174899454373383e-18
# The Ignorability Assumption is not satisfied.
# 2.2669493756455143e-10
# The Ignorability Assumption is not satisfied.
# 1.920314633020753e-09
# The Ignorability Assumption is not satisfied.
# 3.2214426698845266e-20
# The Ignorability Assumption is not satisfied.
# 8.221985829657964e-14
# The Ignorability Assumption is not satisfied.
# 7.635222561987503e-14
# The Ignorability Assumption is not satisfied.
# 1.4379394690703307e-13
# The Ignorability Assumption is not satisfied.
# 1.6889169540011873e-15
# The Ignorability Assumption is not satisfied.
# 1.1561069438631369e-11
# The Ignorability Assumption is not satisfied.
# 5.783831031309882e-20
# The Ignorability Assumption is not satisfied.
# 3.39470661826545e-07
# The Ignorability Assumption is not satisfied.
# 1.5384604129393354e-18
# The Ignorability Assumption is not satisfied.
# 3.3885397441136554e-12
# The Ignorability Assumption is not satisfied.
# 5.342807576047685e-11
# The Ignorability Assumption is not satisfied.
# 2.7760423680012455e-12
# The Ignorability Assumption is not satisfied.
# 2.9678631370221837e-15
# The Ignorability Assumption is not satisfied.
# 7.605022898266589e-10
# The Ignorability Assumption is not satisfied.
# 4.809966552878988e-12
# The Ignorability Assumption is not satisfied.
# 2.1089282767102696e-12
# The Ignorability Assumption is not satisfied.
# 1.5157745343141676e-15
# The Ignorability Assumption is not satisfied.
# 9.818455991787609e-11
# The Ignorability Assumption is not satisfied.
# 1.6908037841722858e-13
# The Ignorability Assumption is not satisfied.
# 2.6414757537914154e-15
# The Ignorability Assumption is not satisfied.
# 5.870234129505908e-14
# The Ignorability Assumption is not satisfied.
# 2.340020149832624e-13
# The Ignorability Assumption is not satisfied.
# 3.019249253324448e-14
# The Ignorability Assumption is not satisfied.
# 6.676324369288913e-20
# The Ignorability Assumption is not satisfied.
# 1.846272366451122e-13
# The Ignorability Assumption is not satisfied.
# 1.386432272680451e-12
# The Ignorability Assumption is not satisfied.
# 1.4156853210256953e-11
# The Ignorability Assumption is not satisfied.
# 1.3684377819252455e-08
# The Ignorability Assumption is not satisfied.
# 3.3838775195650187e-14
# The Ignorability Assumption is not satisfied.
# 1.850780845425864e-13
# The Ignorability Assumption is not satisfied.
# 1.672613780818116e-13
# The Ignorability Assumption is not satisfied.
# 1.2996345996828498e-12
# The Ignorability Assumption is not satisfied.
# 1.1506797643012442e-15
# The Ignorability Assumption is not satisfied.
# 6.148134399296571e-11
# The Ignorability Assumption is not satisfied.
# 1.1052294479229461e-09
# The Ignorability Assumption is not satisfied.
# 1.4863876046499813e-15
# The Ignorability Assumption is not satisfied.
# 2.5733047023067487e-23
# The Ignorability Assumption is not satisfied.
# 3.939225146426455e-14
# The Ignorability Assumption is not satisfied.
# 3.3367171289376123e-12
# The Ignorability Assumption is not satisfied.
# 1.749254436408333e-14
# The Ignorability Assumption is not satisfied.
# 2.852204906756885e-18
# The Ignorability Assumption is not satisfied.
# 3.117689556642999e-12
# The Ignorability Assumption is not satisfied.
# 3.1703942412279566e-11
# The Ignorability Assumption is not satisfied.
# 5.734606133198498e-12
# The Ignorability Assumption is not satisfied.
# 2.9547260732355227e-14
# The Ignorability Assumption is not satisfied.
# 4.319696955698688e-16
# The Ignorability Assumption is not satisfied.
# 1.0025677745399359e-09
# The Ignorability Assumption is not satisfied.
# 1.3094391010824709e-08
# The Ignorability Assumption is not satisfied.
# 7.509148669275312e-09
# The Ignorability Assumption is not satisfied.
# 1.1006927348562646e-11
# The Ignorability Assumption is not satisfied.
# 4.628322284312317e-16
# The Ignorability Assumption is not satisfied.
# 8.89164437700887e-09
# The Ignorability Assumption is not satisfied.
# 1.0709152544990197e-10
# The Ignorability Assumption is not satisfied.
# 2.9276454779122887e-08
# The Ignorability Assumption is not satisfied.
# 2.643791048149736e-13
# The Ignorability Assumption is not satisfied.
# 1.8934213909323526e-13
# The Ignorability Assumption is not satisfied.
# 2.854041067855154e-07
# The Ignorability Assumption is not satisfied.
# 1.4092805242440286e-13
# The Ignorability Assumption is not satisfied.
# 8.971475372653272e-15
# The Ignorability Assumption is not satisfied.
# 3.79915926950661e-09
# The Ignorability Assumption is not satisfied.
# 4.771164929902344e-12
# The Ignorability Assumption is not satisfied.
# 1.907083821492381e-14
# The Ignorability Assumption is not satisfied.
# 8.292252781791418e-16
# The Ignorability Assumption is not satisfied.
# 4.015679087800276e-15
# The Ignorability Assumption is not satisfied.
# 2.7062964330538487e-11
# The Ignorability Assumption is not satisfied.
# 8.533111799612176e-10
# The Ignorability Assumption is not satisfied.
# 2.9512397844347796e-10
# The Ignorability Assumption is not satisfied.
# 1.2637020507201616e-14
# The Ignorability Assumption is not satisfied.
# 1.3438128108194747e-15
# The Ignorability Assumption is not satisfied.
# 3.060600426496891e-17
# The Ignorability Assumption is not satisfied.
# 1.5002455100778201e-12
# The Ignorability Assumption is not satisfied.
# 2.8298914830077147e-06
# The Ignorability Assumption is not satisfied.
# 1.2239754119683784e-07
# The Ignorability Assumption is not satisfied.
# 1.9157689085103068e-16
# The Ignorability Assumption is not satisfied.
# 6.643005338388671e-08
# The Ignorability Assumption is not satisfied.
# 3.9331006641704644e-13
# The Ignorability Assumption is not satisfied.
# 2.17457258588115e-16
# The Ignorability Assumption is not satisfied.
# 1.331744986080555e-14
# The Ignorability Assumption is not satisfied.
# 6.46923833628554e-08
# The Ignorability Assumption is not satisfied.
# 2.741689966197269e-12
# The Ignorability Assumption is not satisfied.
# 1.5909350859467777e-10
# The Ignorability Assumption is not satisfied.
# 1.9848766558745316e-13
# The Ignorability Assumption is not satisfied.
# 6.352157254336592e-17
# The Ignorability Assumption is not satisfied.
# 4.220169236153662e-15
# The Ignorability Assumption is not satisfied.
# 3.456761180045642e-17
# The Ignorability Assumption is not satisfied.
# 1.9946075810625586e-09
# The Ignorability Assumption is not satisfied.
# 1.1728811677291854e-12
# The Ignorability Assumption is not satisfied.
# 7.445746875885148e-13
# The Ignorability Assumption is not satisfied.
# 7.254702925948184e-15
# The Ignorability Assumption is not satisfied.
# 1.4401960189804517e-14
# The Ignorability Assumption is not satisfied.
# 1.5267210615767673e-12
# The Ignorability Assumption is not satisfied.
# 1.2477841497539046e-14
# The Ignorability Assumption is not satisfied.
# 1.151146371655507e-05
# The Ignorability Assumption is not satisfied.
# 5.879973363089276e-09
# The Ignorability Assumption is not satisfied.
# 1.1813321841598241e-12
# The Ignorability Assumption is not satisfied.
# 3.0965452118109484e-15
# The Ignorability Assumption is not satisfied.
# 1.0229527538108225e-13
# The Ignorability Assumption is not satisfied.
# 2.429857640851557e-11
# The Ignorability Assumption is not satisfied.
# 6.05150206040069e-09
# The Ignorability Assumption is not satisfied.
# 4.520829770918993e-13
# The Ignorability Assumption is not satisfied.
# 5.615290426218103e-13
# The Ignorability Assumption is not satisfied.
# 7.91777089557629e-09
# The Ignorability Assumption is not satisfied.
# 7.968189510644238e-10
# The Ignorability Assumption is not satisfied.
# 4.0109766151141334e-13
# The Ignorability Assumption is not satisfied.
# 2.157780558792779e-12
# The Ignorability Assumption is not satisfied.
# 3.5383814568314414e-13
# The Ignorability Assumption is not satisfied.
# 2.271773608567739e-13
# The Ignorability Assumption is not satisfied.
# 3.144767236943252e-08
# The Ignorability Assumption is not satisfied.
# 4.377683682362793e-09
# The Ignorability Assumption is not satisfied.
# 3.0713559936848903e-13
# The Ignorability Assumption is not satisfied.
# 2.0879218813340372e-13
# The Ignorability Assumption is not satisfied.
# 9.384127940932702e-14
# The Ignorability Assumption is not satisfied.
# 2.2366259437472094e-16
# The Ignorability Assumption is not satisfied.
# 5.822337443778674e-11
# The Ignorability Assumption is not satisfied.
# 4.601966519076823e-19
# The Ignorability Assumption is not satisfied.
# 1.3024460483539912e-08
# The Ignorability Assumption is not satisfied.
# 3.0982234836551767e-16
# The Ignorability Assumption is not satisfied.
# 9.008775447740086e-18
# The Ignorability Assumption is not satisfied.
# 1.1043511286370653e-09
# The Ignorability Assumption is not satisfied.
# 3.8921718560829895e-10
# The Ignorability Assumption is not satisfied.
# 2.106422844839209e-07
# The Ignorability Assumption is not satisfied.
# 3.8912336041585515e-10
# The Ignorability Assumption is not satisfied.
# 9.491586401877057e-15
# The Ignorability Assumption is not satisfied.
# 8.330378329979054e-10
# The Ignorability Assumption is not satisfied.
# 1.1976732420248893e-14
# The Ignorability Assumption is not satisfied.
# 1.3903027423329681e-14
# The Ignorability Assumption is not satisfied.
# 3.619712375069242e-14
# The Ignorability Assumption is not satisfied.
# 4.498288840000951e-12
# The Ignorability Assumption is not satisfied.
# 4.109838939075608e-12
# The Ignorability Assumption is not satisfied.
# 6.721022919868219e-07
# The Ignorability Assumption is not satisfied.
# 2.5502410176687033e-08
# The Ignorability Assumption is not satisfied.
# 8.366701822968681e-10
# The Ignorability Assumption is not satisfied.
# 2.66619602412081e-19
# The Ignorability Assumption is not satisfied.
# 3.18828805435218e-16
# The Ignorability Assumption is not satisfied.
# 2.8309542621695857e-14
# The Ignorability Assumption is not satisfied.
# 1.085203023467507e-13
# The Ignorability Assumption is not satisfied.
# 3.967339203710333e-13
# The Ignorability Assumption is not satisfied.
# 4.914376021523981e-19
# The Ignorability Assumption is not satisfied.
# 2.4076577307318426e-17
# The Ignorability Assumption is not satisfied.
# 1.8621774144069487e-05
# The Ignorability Assumption is not satisfied.
# 1.4607480925458617e-15
# The Ignorability Assumption is not satisfied.
# 2.7197202076465367e-08
# The Ignorability Assumption is not satisfied.
# 4.207801872092711e-11
# The Ignorability Assumption is not satisfied.
# 4.1175084462650017e-13
# The Ignorability Assumption is not satisfied.
# 1.6127930503246472e-09
# The Ignorability Assumption is not satisfied.
# 1.451008240441041e-13
# The Ignorability Assumption is not satisfied.
# 1.8004312135751938e-07
# The Ignorability Assumption is not satisfied.
# 1.8940180934501394e-13
# The Ignorability Assumption is not satisfied.
# 8.12255127846673e-14
# The Ignorability Assumption is not satisfied.
# 2.0490684954953948e-13
# The Ignorability Assumption is not satisfied.
# 1.697155575674234e-14
# The Ignorability Assumption is not satisfied.
# 3.7761654176432207e-16
# The Ignorability Assumption is not satisfied.
# 5.461241480716643e-15
# The Ignorability Assumption is not satisfied.
# 3.916565961278558e-12
# The Ignorability Assumption is not satisfied.
# 2.2559622694720506e-11
# The Ignorability Assumption is not satisfied.
# 2.0726500789396058e-19
# The Ignorability Assumption is not satisfied.
# 4.7503233434332456e-09
# The Ignorability Assumption is not satisfied.
# 1.0070810070436057e-11
# The Ignorability Assumption is not satisfied.
# 1.0291663634923902e-14
# The Ignorability Assumption is not satisfied.
# 2.5641563184704435e-13
# The Ignorability Assumption is not satisfied.
# 1.5611819589498057e-10
# The Ignorability Assumption is not satisfied.
# 1.0031382846275715e-17
# The Ignorability Assumption is not satisfied.
# 1.9205399535503974e-08
# The Ignorability Assumption is not satisfied.
# 2.377131710350718e-13
# The Ignorability Assumption is not satisfied.
# 7.345271840070342e-14
# The Ignorability Assumption is not satisfied.
# 5.491304466722381e-08
# The Ignorability Assumption is not satisfied.
# 2.8938637492380634e-11
# The Ignorability Assumption is not satisfied.
# 1.711219196367149e-10
# The Ignorability Assumption is not satisfied.
# 1.5172851858824278e-13
# The Ignorability Assumption is not satisfied.
# 1.8723391427167985e-13
# The Ignorability Assumption is not satisfied.
# 9.245428230123565e-12
# The Ignorability Assumption is not satisfied.
# 9.603472499977631e-09
# The Ignorability Assumption is not satisfied.
# 3.297713064520715e-18
# The Ignorability Assumption is not satisfied.
# 1.738666252560523e-14
# The Ignorability Assumption is not satisfied.
# 2.991324622483073e-14
# The Ignorability Assumption is not satisfied.
# 8.036819687929854e-10
# The Ignorability Assumption is not satisfied.
# 3.2874011448137413e-09
# The Ignorability Assumption is not satisfied.
# 9.689287787264506e-14
# The Ignorability Assumption is not satisfied.
# 1.6780629894445154e-10
# The Ignorability Assumption is not satisfied.
# 1.001051692841969e-07
# The Ignorability Assumption is not satisfied.
# 4.285172465873969e-14
# The Ignorability Assumption is not satisfied.
# 3.3838615654286214e-12
# The Ignorability Assumption is not satisfied.
# 9.050054947316561e-14
# The Ignorability Assumption is not satisfied.
# 1.1768445931958905e-11
# The Ignorability Assumption is not satisfied.
# 2.5543867088620006e-08
# The Ignorability Assumption is not satisfied.
# 6.792672124559548e-13
# The Ignorability Assumption is not satisfied.
# 8.399567032956507e-19
# The Ignorability Assumption is not satisfied.
# 7.402752700582566e-15
# The Ignorability Assumption is not satisfied.
# 6.892965270153682e-21
# The Ignorability Assumption is not satisfied.
# 3.751811784723046e-14
# The Ignorability Assumption is not satisfied.
# 6.4207269876819245e-12
# The Ignorability Assumption is not satisfied.
# 8.376949029026047e-15
# The Ignorability Assumption is not satisfied.
# 1.185518578650273e-10
# The Ignorability Assumption is not satisfied.
# 1.2943366174642793e-08
# The Ignorability Assumption is not satisfied.
# 1.31362999175751e-13
# The Ignorability Assumption is not satisfied.
# 1.71224933631264e-08
# The Ignorability Assumption is not satisfied.
# 5.935010268939409e-20
# The Ignorability Assumption is not satisfied.
# 1.3516040680830417e-14
# The Ignorability Assumption is not satisfied.
# 2.0749456170590064e-12
# The Ignorability Assumption is not satisfied.
# 5.304759085580724e-15
# The Ignorability Assumption is not satisfied.
# 2.150964721577991e-11
# The Ignorability Assumption is not satisfied.
# 6.950544998783809e-16
# The Ignorability Assumption is not satisfied.
# 2.285336940465634e-23
# The Ignorability Assumption is not satisfied.
# 4.668193295942454e-10
# The Ignorability Assumption is not satisfied.
# 3.3393543428276334e-10
# The Ignorability Assumption is not satisfied.
# 5.0945224839948236e-12
# The Ignorability Assumption is not satisfied.
# 1.5468031169000063e-12
# The Ignorability Assumption is not satisfied.
# 7.873428918325297e-10
# The Ignorability Assumption is not satisfied.
# 3.8902915039275794e-13
# The Ignorability Assumption is not satisfied.
# 2.1928593031173368e-17
# The Ignorability Assumption is not satisfied.
# 2.892028024526766e-15
# The Ignorability Assumption is not satisfied.
# 2.7582770095262574e-13
# The Ignorability Assumption is not satisfied.
# 1.3745559265122582e-09
# The Ignorability Assumption is not satisfied.
# 5.0724781025151965e-15
# The Ignorability Assumption is not satisfied.
# 9.056892214926555e-10
# The Ignorability Assumption is not satisfied.
# 1.9524770828201917e-08
# The Ignorability Assumption is not satisfied.
# 4.534660851585994e-09
# The Ignorability Assumption is not satisfied.
# 1.0525662638054589e-06
# The Ignorability Assumption is not satisfied.
# 9.690361182535848e-12
# The Ignorability Assumption is not satisfied.
# 6.904894146283948e-11
# The Ignorability Assumption is not satisfied.
# 8.203294612322746e-14
# The Ignorability Assumption is not satisfied.
# 6.386789979346227e-17
# The Ignorability Assumption is not satisfied.
# 2.2182627482085383e-09
# The Ignorability Assumption is not satisfied.
# 5.2180918826473613e-11
# The Ignorability Assumption is not satisfied.
# 1.63393120452606e-12
# The Ignorability Assumption is not satisfied.
# 2.8247419556439413e-14
# The Ignorability Assumption is not satisfied.
# 2.1162984559824025e-13
# The Ignorability Assumption is not satisfied.
# 1.178099658857936e-12
# The Ignorability Assumption is not satisfied.
# 1.7797431782937525e-15
# The Ignorability Assumption is not satisfied.
# 1.9084978055849993e-15
# The Ignorability Assumption is not satisfied.
# 4.352856335064956e-15
# The Ignorability Assumption is not satisfied.
# 1.9081503927275396e-16
# The Ignorability Assumption is not satisfied.
# 3.538711599259031e-10
# The Ignorability Assumption is not satisfied.
# 1.0052245522309867e-09
# The Ignorability Assumption is not satisfied.
# 5.13500074255116e-10
# The Ignorability Assumption is not satisfied.
# 1.2173100163531734e-06
# The Ignorability Assumption is not satisfied.
# 2.1863942978040294e-15
# The Ignorability Assumption is not satisfied.
# 8.823067686483154e-11
# The Ignorability Assumption is not satisfied.
# 4.4485279884302463e-10
# The Ignorability Assumption is not satisfied.
# 8.416424212292404e-09
# The Ignorability Assumption is not satisfied.
# 3.5000067308272213e-07
# The Ignorability Assumption is not satisfied.
# 1.9898037177489606e-11
# The Ignorability Assumption is not satisfied.
# 1.5534360136376524e-08
# The Ignorability Assumption is not satisfied.
# 4.2794691952128677e-19
# The Ignorability Assumption is not satisfied.
# 1.7306590214137676e-11
# The Ignorability Assumption is not satisfied.
# 5.840372528877756e-12
# The Ignorability Assumption is not satisfied.
# 2.930242327630202e-12
# The Ignorability Assumption is not satisfied.
# 5.13633658264287e-11
# The Ignorability Assumption is not satisfied.
# 3.2488354831970787e-15
# The Ignorability Assumption is not satisfied.
# 2.5999464447488863e-14
# The Ignorability Assumption is not satisfied.
# 5.955399326446853e-17
# The Ignorability Assumption is not satisfied.
# 3.0647265281553626e-18
# The Ignorability Assumption is not satisfied.
# 4.880391960608304e-21
# The Ignorability Assumption is not satisfied.
# 1.3217172954391089e-12
# The Ignorability Assumption is not satisfied.
# 4.489669502144301e-17
# The Ignorability Assumption is not satisfied.
# 4.8204668483712553e-17
# The Ignorability Assumption is not satisfied.
# 4.053092584558062e-11
# The Ignorability Assumption is not satisfied.
# 2.376889348182386e-15
# The Ignorability Assumption is not satisfied.
# 3.221775854725326e-15
# The Ignorability Assumption is not satisfied.
# 5.354473672561838e-09
# The Ignorability Assumption is not satisfied.
# 2.8006816048451967e-08
# The Ignorability Assumption is not satisfied.
# 2.4504743868084384e-11
# The Ignorability Assumption is not satisfied.
# 4.435412859724468e-14
# The Ignorability Assumption is not satisfied.
# 5.291545099637987e-10
# The Ignorability Assumption is not satisfied.
# 5.918944362580329e-11
# The Ignorability Assumption is not satisfied.
# 1.0887582039545051e-21
# The Ignorability Assumption is not satisfied.
# 2.742944999806309e-12
# The Ignorability Assumption is not satisfied.
# 4.220469153204228e-16
# The Ignorability Assumption is not satisfied.
# 3.876784113788914e-10
# The Ignorability Assumption is not satisfied.
# 4.2452027219478467e-13
# The Ignorability Assumption is not satisfied.
# 2.778616760540563e-08
# The Ignorability Assumption is not satisfied.
# 3.607580664605319e-07
# The Ignorability Assumption is not satisfied.
# 1.1127504774418696e-14
# The Ignorability Assumption is not satisfied.
# 1.3967480156111997e-09
# The Ignorability Assumption is not satisfied.
# 1.9973850241624502e-15
# The Ignorability Assumption is not satisfied.
# 1.1385015022638155e-09
# The Ignorability Assumption is not satisfied.
# 1.1928798727987362e-16
# The Ignorability Assumption is not satisfied.
# 1.0543130400699546e-13
# The Ignorability Assumption is not satisfied.
# 2.5739554568320944e-17
# The Ignorability Assumption is not satisfied.
# 1.5519856718669024e-10
# The Ignorability Assumption is not satisfied.
# 1.1463759657946593e-07
# The Ignorability Assumption is not satisfied.
# 1.7804013383231086e-14
# The Ignorability Assumption is not satisfied.
# 3.8718423344069697e-10
# The Ignorability Assumption is not satisfied.
# 8.581963404149115e-15
# The Ignorability Assumption is not satisfied.
# 2.568796277799736e-11
# The Ignorability Assumption is not satisfied.
# 1.3537175570198945e-11
# The Ignorability Assumption is not satisfied.
# 3.3740876069090013e-16
# The Ignorability Assumption is not satisfied.
# 6.0591410846029116e-12
# The Ignorability Assumption is not satisfied.
# 1.5810450886135508e-10
# The Ignorability Assumption is not satisfied.
# 1.9808292124809977e-11
# The Ignorability Assumption is not satisfied.
# 2.3646899612994667e-18
# The Ignorability Assumption is not satisfied.
# 4.661445473836284e-20
# The Ignorability Assumption is not satisfied.
# 1.8389575439855495e-10
# The Ignorability Assumption is not satisfied.
# 1.3605615416194843e-16
# The Ignorability Assumption is not satisfied.
# 6.991940117132437e-08
# The Ignorability Assumption is not satisfied.
# 2.4344572022464585e-18
# The Ignorability Assumption is not satisfied.
# 3.878978773891229e-10
# The Ignorability Assumption is not satisfied.
# 7.431583017421462e-11
# The Ignorability Assumption is not satisfied.
# 1.314599983973351e-16
# The Ignorability Assumption is not satisfied.
# 3.1563845665997995e-13
# The Ignorability Assumption is not satisfied.
# 2.8271884628245736e-10
# The Ignorability Assumption is not satisfied.
# 3.998057875577841e-15
# The Ignorability Assumption is not satisfied.
# 1.5878011100087621e-09
# The Ignorability Assumption is not satisfied.
# 9.539191898340949e-17
# The Ignorability Assumption is not satisfied.
# 5.496229115005114e-10
# The Ignorability Assumption is not satisfied.
# 7.308294913688818e-12
# The Ignorability Assumption is not satisfied.
# 5.702050169470868e-11
# The Ignorability Assumption is not satisfied.
# 9.435179815446324e-11
# The Ignorability Assumption is not satisfied.
# 1.1950491131069961e-11
# The Ignorability Assumption is not satisfied.
# 4.150989673953837e-11
# The Ignorability Assumption is not satisfied.
# 2.529953567323229e-11
# The Ignorability Assumption is not satisfied.
# 1.5188662370233986e-13
# The Ignorability Assumption is not satisfied.
# 1.1815548572236022e-11
# The Ignorability Assumption is not satisfied.
# 1.0423558017922048e-07
# The Ignorability Assumption is not satisfied.
# 5.98493087286217e-17
# The Ignorability Assumption is not satisfied.
# 2.3410288947129002e-11
# The Ignorability Assumption is not satisfied.
# 1.6004117189199698e-09
# The Ignorability Assumption is not satisfied.
# 7.485511666826928e-16
# The Ignorability Assumption is not satisfied.
# 3.608054254066473e-11
# The Ignorability Assumption is not satisfied.
# 9.343262002946738e-14
# The Ignorability Assumption is not satisfied.
# 7.289994687480503e-12
# The Ignorability Assumption is not satisfied.
# 1.6168108035968865e-13
# The Ignorability Assumption is not satisfied.
# 1.3871666974230364e-15
# The Ignorability Assumption is not satisfied.
# 5.123151925616676e-15
# The Ignorability Assumption is not satisfied.
# 4.105068902152737e-08
# The Ignorability Assumption is not satisfied.
# 1.0339089129330942e-08
# The Ignorability Assumption is not satisfied.
# 5.430177392175464e-13
# The Ignorability Assumption is not satisfied.
# 4.3340268189494297e-07
# The Ignorability Assumption is not satisfied.
# 4.1970242928035524e-13
# The Ignorability Assumption is not satisfied.
# 3.885463549663473e-08
# The Ignorability Assumption is not satisfied.
# 8.264443984334893e-12
# The Ignorability Assumption is not satisfied.
# 1.044197441278261e-14
# The Ignorability Assumption is not satisfied.
# 1.2359579688391824e-14
# The Ignorability Assumption is not satisfied.
# 2.5862746740423163e-08
# The Ignorability Assumption is not satisfied.
# 2.5907137128218773e-13
# The Ignorability Assumption is not satisfied.
# 3.662212630895269e-12
# The Ignorability Assumption is not satisfied.
# 4.1759850018832974e-11
# The Ignorability Assumption is not satisfied.
# 2.3232525684684398e-10
# The Ignorability Assumption is not satisfied.
# 3.8414078839038584e-11
# The Ignorability Assumption is not satisfied.
# 2.576402058063047e-10
# The Ignorability Assumption is not satisfied.
# 1.333042891067119e-12
# The Ignorability Assumption is not satisfied.
# 1.7863889933643636e-08
# The Ignorability Assumption is not satisfied.
# 9.708545687926888e-16
# The Ignorability Assumption is not satisfied.
# 2.1459380413199014e-11
# The Ignorability Assumption is not satisfied.
# 1.9187371188942012e-11
# The Ignorability Assumption is not satisfied.
# 1.5679587177130904e-11
# The Ignorability Assumption is not satisfied.
# 3.91061393327627e-10
# The Ignorability Assumption is not satisfied.
# 8.94268003797019e-13
# The Ignorability Assumption is not satisfied.
# 1.9925725665253868e-10
# The Ignorability Assumption is not satisfied.
# 8.63004455004147e-10
# The Ignorability Assumption is not satisfied.
# 1.8423057209063265e-21
# The Ignorability Assumption is not satisfied.
# 6.655749343812067e-13
# The Ignorability Assumption is not satisfied.
# 2.3883870301100986e-09
# The Ignorability Assumption is not satisfied.
# 1.2007571083209315e-23
# The Ignorability Assumption is not satisfied.
# 1.5582781981495514e-11
# The Ignorability Assumption is not satisfied.
# 1.618173625569131e-18
# The Ignorability Assumption is not satisfied.
# 2.0952871496174015e-13
# The Ignorability Assumption is not satisfied.
# 2.8687789312287873e-19
# The Ignorability Assumption is not satisfied.
# 5.765903891655685e-10
# The Ignorability Assumption is not satisfied.
# 9.283168947714916e-11
# The Ignorability Assumption is not satisfied.
# 1.690453335933235e-08
# The Ignorability Assumption is not satisfied.
# 2.375061545113494e-16
# The Ignorability Assumption is not satisfied.
# 3.2049490022270556e-12
# The Ignorability Assumption is not satisfied.
# 3.121016861732915e-11
# The Ignorability Assumption is not satisfied.
# 6.265388024744354e-15
# The Ignorability Assumption is not satisfied.
# 1.847456330731023e-11
# The Ignorability Assumption is not satisfied.
# 1.0513948647722789e-12
# The Ignorability Assumption is not satisfied.
# 3.273756579661766e-14
# The Ignorability Assumption is not satisfied.
# 2.7627093134771883e-06
# The Ignorability Assumption is not satisfied.
# 2.512354591224975e-13
# The Ignorability Assumption is not satisfied.
# 5.652896217649247e-17
# The Ignorability Assumption is not satisfied.
# 1.777366399112151e-14
# The Ignorability Assumption is not satisfied.
# 3.907325705651821e-12
# The Ignorability Assumption is not satisfied.
# 6.403403222816147e-11
# The Ignorability Assumption is not satisfied.
# 1.700286793166066e-16
# The Ignorability Assumption is not satisfied.
# 8.88700104231843e-13
# The Ignorability Assumption is not satisfied.
# 8.56053810533418e-12
# The Ignorability Assumption is not satisfied.
# 3.368275085835618e-11
# The Ignorability Assumption is not satisfied.
# 5.559609141357779e-12
# The Ignorability Assumption is not satisfied.
# 2.3197937176762994e-20
# The Ignorability Assumption is not satisfied.
# 2.447390692710065e-13
# The Ignorability Assumption is not satisfied.
# 3.7544791816077256e-10
# The Ignorability Assumption is not satisfied.
# 1.1808153943942788e-15
# The Ignorability Assumption is not satisfied.
# 5.016296432216493e-10
# The Ignorability Assumption is not satisfied.
# 1.2201917229981647e-10
# The Ignorability Assumption is not satisfied.
# 3.5385700135601676e-13
# The Ignorability Assumption is not satisfied.
# 5.249978015159453e-12
# The Ignorability Assumption is not satisfied.
# 1.8994451076389183e-20
# The Ignorability Assumption is not satisfied.
# 4.388859970358558e-16
# The Ignorability Assumption is not satisfied.
# 7.97724269530362e-08
# The Ignorability Assumption is not satisfied.
# 1.774399557227485e-22
# The Ignorability Assumption is not satisfied.
# 7.188537303194199e-09
# The Ignorability Assumption is not satisfied.
# 1.2188685559365417e-07
# The Ignorability Assumption is not satisfied.
# 2.6749550287714735e-08
# The Ignorability Assumption is not satisfied.
# 3.7173113281257314e-14
# The Ignorability Assumption is not satisfied.
# 1.5316053015069395e-10
# The Ignorability Assumption is not satisfied.
# 7.453394648230557e-13
# The Ignorability Assumption is not satisfied.
# 5.247923719956576e-17
# The Ignorability Assumption is not satisfied.
# 3.199281756820008e-14
# The Ignorability Assumption is not satisfied.
# 5.995207849723469e-12
# The Ignorability Assumption is not satisfied.
# 2.5271494065439767e-12
# The Ignorability Assumption is not satisfied.
# 1.68845707277009e-16
# The Ignorability Assumption is not satisfied.
# 4.062889369643737e-11
# The Ignorability Assumption is not satisfied.
# 9.385539467048603e-14
# The Ignorability Assumption is not satisfied.
# 1.0935196194415316e-12
# The Ignorability Assumption is not satisfied.
# 7.173290739581644e-08
# The Ignorability Assumption is not satisfied.
# 1.2938619535025884e-10
# The Ignorability Assumption is not satisfied.
# 7.123461185142775e-10
# The Ignorability Assumption is not satisfied.
# 2.185461534071543e-10
# The Ignorability Assumption is not satisfied.
# 9.219337377948072e-11
# The Ignorability Assumption is not satisfied.
# 2.7341199291388572e-14
# The Ignorability Assumption is not satisfied.
# 2.1446946866846855e-13
# The Ignorability Assumption is not satisfied.
# 2.6107193373849258e-15
# The Ignorability Assumption is not satisfied.
# 3.258487822199013e-11
# The Ignorability Assumption is not satisfied.
# 2.2486716039439474e-10
# The Ignorability Assumption is not satisfied.
# 7.047557018224185e-12
# The Ignorability Assumption is not satisfied.
# 3.558592818181768e-14
# The Ignorability Assumption is not satisfied.
# 1.3923373370294616e-15
# The Ignorability Assumption is not satisfied.
# 4.611313669452317e-12
# The Ignorability Assumption is not satisfied.
# 6.0404581072690706e-12
# The Ignorability Assumption is not satisfied.
# 2.1439313326183073e-12
# The Ignorability Assumption is not satisfied.
# 9.523585340272573e-23
# The Ignorability Assumption is not satisfied.
# 1.7413542405562866e-15
# The Ignorability Assumption is not satisfied.
# 2.520388494444988e-14
# The Ignorability Assumption is not satisfied.
# 6.447247993825069e-08
# The Ignorability Assumption is not satisfied.
# 2.567172510796412e-12
# The Ignorability Assumption is not satisfied.
# 4.785750023675333e-15
# The Ignorability Assumption is not satisfied.
# 5.368920004601059e-13
# The Ignorability Assumption is not satisfied.
# 3.4452381019556255e-12
# The Ignorability Assumption is not satisfied.
# 7.581424500671293e-18
# The Ignorability Assumption is not satisfied.
# 1.1384299811807067e-15
# The Ignorability Assumption is not satisfied.
# 6.504428102016452e-11
# The Ignorability Assumption is not satisfied.
# 1.9394619100799367e-14
# The Ignorability Assumption is not satisfied.
# 1.3072651130299694e-14
# The Ignorability Assumption is not satisfied.
# 1.0252876228036791e-19
# The Ignorability Assumption is not satisfied.
# 3.04824283252707e-15
# The Ignorability Assumption is not satisfied.
# 6.115428310903804e-13
# The Ignorability Assumption is not satisfied.
# 3.466675617513255e-11
# The Ignorability Assumption is not satisfied.
# 3.53445609542117e-12
# The Ignorability Assumption is not satisfied.
# 1.4356447520348652e-14
# The Ignorability Assumption is not satisfied.
# 7.53954425198776e-13
# The Ignorability Assumption is not satisfied.
# 1.4812352124220771e-18
# The Ignorability Assumption is not satisfied.
# 3.735882940976698e-10
# The Ignorability Assumption is not satisfied.
# 7.522704788182852e-15
# The Ignorability Assumption is not satisfied.
# 1.764526543431882e-10
# The Ignorability Assumption is not satisfied.
# 5.344932841488312e-13
# The Ignorability Assumption is not satisfied.
# 1.3536343611138074e-15
# The Ignorability Assumption is not satisfied.
# 7.670036123053458e-15
# The Ignorability Assumption is not satisfied.
# 1.3825234377199095e-11
# The Ignorability Assumption is not satisfied.
# 3.1802950230204316e-13
# The Ignorability Assumption is not satisfied.
# 8.082633701571235e-18
# The Ignorability Assumption is not satisfied.
# 9.315679022431036e-12
# The Ignorability Assumption is not satisfied.
# 1.0810510272827401e-12
# The Ignorability Assumption is not satisfied.
# 3.75483301769662e-10
# The Ignorability Assumption is not satisfied.
# 6.225783180557351e-12
# The Ignorability Assumption is not satisfied.
# 6.535827595300079e-10
# The Ignorability Assumption is not satisfied.
# 3.470642524966944e-10
# The Ignorability Assumption is not satisfied.
# 6.546424865503214e-10
# The Ignorability Assumption is not satisfied.
# 6.577771246660093e-14
# The Ignorability Assumption is not satisfied.
# 4.756911835116405e-08
# The Ignorability Assumption is not satisfied.
# 4.302540238941926e-12
# The Ignorability Assumption is not satisfied.
# 3.601411113381917e-14
# The Ignorability Assumption is not satisfied.
# 7.859949337239404e-13
# The Ignorability Assumption is not satisfied.
# 4.7719044862701935e-18
# The Ignorability Assumption is not satisfied.
# 2.62911638342135e-12
# The Ignorability Assumption is not satisfied.
# 1.2854500396423342e-15
# The Ignorability Assumption is not satisfied.
# 2.0491125880143703e-17
# The Ignorability Assumption is not satisfied.
# 7.433161693515761e-08
# The Ignorability Assumption is not satisfied.
# 1.301607421845734e-15
# The Ignorability Assumption is not satisfied.
# 3.556642517152244e-17
# The Ignorability Assumption is not satisfied.
# 2.4099547978957e-10
# The Ignorability Assumption is not satisfied.
# 1.4407951199898336e-17
# The Ignorability Assumption is not satisfied.
# 9.205938312733447e-15
# The Ignorability Assumption is not satisfied.
# 6.2642631821602055e-12
# The Ignorability Assumption is not satisfied.
# 7.148623488616269e-10
# The Ignorability Assumption is not satisfied.
# 1.3096389202989022e-14
# The Ignorability Assumption is not satisfied.
# 3.4704553867677407e-12
# The Ignorability Assumption is not satisfied.
# 1.9648336961788184e-16
# The Ignorability Assumption is not satisfied.
# 1.2002427043700436e-13
# The Ignorability Assumption is not satisfied.
# 2.8646115142670065e-08
# The Ignorability Assumption is not satisfied.
# 3.3004881417092743e-16
# The Ignorability Assumption is not satisfied.
# 2.545195112518866e-08
# The Ignorability Assumption is not satisfied.
# 1.8499291391619732e-13
# The Ignorability Assumption is not satisfied.
# 3.0379533696197183e-13
# The Ignorability Assumption is not satisfied.
# 8.593335747320057e-12
# ...
# 7.841677945028011e-13
# The Ignorability Assumption is not satisfied.
# 7.118418213445725e-21
# The Ignorability Assumption is not satisfied.
# 8.400326757953412e-12
# The Ignorability Assumption is not satisfied.
# 5.950817230340827e-11
# The Ignorability Assumption is not satisfied.
# 1.2491120296300809e-09
# The Ignorability Assumption is not satisfied.
# 3.298205781129766e-18
# The Ignorability Assumption is not satisfied.
# 1.8002746756060924e-16
# The Ignorability Assumption is not satisfied.
# 4.052038362603043e-09
# The Ignorability Assumption is not satisfied.
# 1.3458315377168408e-13
# The Ignorability Assumption is not satisfied.
# 2.1308174727413416e-17
# The Ignorability Assumption is not satisfied.
# 2.2385862672506454e-18
# The Ignorability Assumption is not satisfied.
# 1.858108072605653e-13
# The Ignorability Assumption is not satisfied.
# 1.2088764480190515e-11
# The Ignorability Assumption is not satisfied.
# 5.8022189861183294e-11
# The Ignorability Assumption is not satisfied.
# 1.2953595968234769e-08
# The Ignorability Assumption is not satisfied.
# 8.730301039935515e-09
# The Ignorability Assumption is not satisfied.
# 2.202584364877544e-14
# The Ignorability Assumption is not satisfied.
# 1.8548082735094855e-09
# The Ignorability Assumption is not satisfied.
# 1.2923143663382274e-13
# The Ignorability Assumption is not satisfied.
# 7.311003731869014e-11
# The Ignorability Assumption is not satisfied.
# 7.215208669429544e-15
# The Ignorability Assumption is not satisfied.
# 9.518820721177968e-13
# The Ignorability Assumption is not satisfied.
# 3.898175801782305e-09
# The Ignorability Assumption is not satisfied.
# 8.091262882582377e-07
# The Ignorability Assumption is not satisfied.
# 1.4314525742501732e-09
# The Ignorability Assumption is not satisfied.
# 4.420239983457878e-11
# The Ignorability Assumption is not satisfied.
# 6.223228297446525e-11
# The Ignorability Assumption is not satisfied.
# 3.5396175724862865e-09
# The Ignorability Assumption is not satisfied.
# 4.759202619928795e-15
# The Ignorability Assumption is not satisfied.
# 4.248874339099699e-13
# The Ignorability Assumption is not satisfied.
# 1.697869411170632e-15
# The Ignorability Assumption is not satisfied.
# 4.719727602849175e-20
# The Ignorability Assumption is not satisfied.
# 2.32262653075047e-10
# The Ignorability Assumption is not satisfied.
# 1.0083486633228178e-12
# The Ignorability Assumption is not satisfied.
# 9.35142151126321e-12
# The Ignorability Assumption is not satisfied.
# 8.902549934340772e-10
# The Ignorability Assumption is not satisfied.
# 5.619400721972569e-11
# The Ignorability Assumption is not satisfied.
# 1.3519795557941375e-14
# The Ignorability Assumption is not satisfied.
# 6.308313500327095e-10
# The Ignorability Assumption is not satisfied.
# 1.6590575743184033e-09
# The Ignorability Assumption is not satisfied.
# 2.9882826130312725e-08
# The Ignorability Assumption is not satisfied.
# 2.1439006960867948e-07
# The Ignorability Assumption is not satisfied.
# 1.2899229927945245e-10
# The Ignorability Assumption is not satisfied.
# 6.687213949676267e-10
# The Ignorability Assumption is not satisfied.
# 1.6039042856939983e-15
# The Ignorability Assumption is not satisfied.
# 2.962161218826002e-13
# The Ignorability Assumption is not satisfied.
# 5.242085530172311e-10
# The Ignorability Assumption is not satisfied.
# 3.252748283839963e-18
# The Ignorability Assumption is not satisfied.
# 1.0758294937967384e-13
# The Ignorability Assumption is not satisfied.
# 4.509747516303885e-15
# The Ignorability Assumption is not satisfied.
# 8.910421699537198e-17
# The Ignorability Assumption is not satisfied.
# 3.298754385371544e-12
# The Ignorability Assumption is not satisfied.
# 1.2490248098824643e-15
# The Ignorability Assumption is not satisfied.
# 2.0955031875125074e-09
# The Ignorability Assumption is not satisfied.
# 3.8248935557750293e-16
# The Ignorability Assumption is not satisfied.
# 2.0497260110793083e-17
# The Ignorability Assumption is not satisfied.
# 2.1569595435304208e-23
# The Ignorability Assumption is not satisfied.
# 9.478933459574532e-14
# The Ignorability Assumption is not satisfied.
# 2.2189445615154534e-09
# The Ignorability Assumption is not satisfied.
# 1.3796698525124721e-15
# The Ignorability Assumption is not satisfied.
# 6.011066323225064e-11
# The Ignorability Assumption is not satisfied.
# 8.611508562926925e-13
# The Ignorability Assumption is not satisfied.
# 2.696689066973757e-08
# The Ignorability Assumption is not satisfied.
# 9.781588059393237e-12
# The Ignorability Assumption is not satisfied.
# 1.300290077388806e-11
# The Ignorability Assumption is not satisfied.
# 5.494236924335579e-10
# The Ignorability Assumption is not satisfied.
# 1.4030379723627118e-08
# The Ignorability Assumption is not satisfied.
# 5.213713795447605e-10
# The Ignorability Assumption is not satisfied.
# 1.8749610525184606e-10
# The Ignorability Assumption is not satisfied.
# 1.0230119626117581e-11
# The Ignorability Assumption is not satisfied.
# 4.472735050502602e-18
# The Ignorability Assumption is not satisfied.
# 3.3609502920119e-14
# The Ignorability Assumption is not satisfied.
# 5.550367528471798e-16
# The Ignorability Assumption is not satisfied.
# 4.180977516491366e-16
# The Ignorability Assumption is not satisfied.
# 8.569865056402435e-09
# The Ignorability Assumption is not satisfied.
# 2.4307842065355264e-12
# The Ignorability Assumption is not satisfied.
# 1.8489034497175368e-10
# The Ignorability Assumption is not satisfied.
# 1.5703246089122282e-16
# The Ignorability Assumption is not satisfied.
# 7.258413684301036e-12
# The Ignorability Assumption is not satisfied.
# 2.804034951491247e-12
# The Ignorability Assumption is not satisfied.
# 2.9602103169344084e-07
# The Ignorability Assumption is not satisfied.
# 1.2725070287760785e-19
# The Ignorability Assumption is not satisfied.
# 1.4455873272497548e-13
# The Ignorability Assumption is not satisfied.
# 4.78384142886908e-08
# The Ignorability Assumption is not satisfied.
# 3.5675471842451058e-12
# The Ignorability Assumption is not satisfied.
# 3.78253541298985e-17
# The Ignorability Assumption is not satisfied.
# 7.972104285576441e-16
# The Ignorability Assumption is not satisfied.
# 2.4685145288187966e-14
# The Ignorability Assumption is not satisfied.
# 2.0611229504763195e-14
# The Ignorability Assumption is not satisfied.
# 6.20246495326455e-16
# The Ignorability Assumption is not satisfied.
# 5.223364788345114e-12
# The Ignorability Assumption is not satisfied.
# 2.0583389647668165e-09
# The Ignorability Assumption is not satisfied.
# 5.951715583522164e-10
# The Ignorability Assumption is not satisfied.
# 7.388003929453394e-17
# The Ignorability Assumption is not satisfied.
# 5.930223967869751e-09
# The Ignorability Assumption is not satisfied.
# 2.250883376875471e-06
# The Ignorability Assumption is not satisfied.
# 7.016139364031381e-11
# The Ignorability Assumption is not satisfied.
# 3.1368330718409573e-18
# The Ignorability Assumption is not satisfied.
# 2.1914594317975815e-05
# The Ignorability Assumption is not satisfied.
# 7.546344530953204e-09
# The Ignorability Assumption is not satisfied.
# 2.7470769648578465e-09
# The Ignorability Assumption is not satisfied.
# 1.3888994589067582e-11
# The Ignorability Assumption is not satisfied.
# 1.6807073341167573e-15
# The Ignorability Assumption is not satisfied.
# 6.981389353431624e-14
# The Ignorability Assumption is not satisfied.
# 8.00856097455975e-15
# The Ignorability Assumption is not satisfied.
# 5.267938330996506e-15
# The Ignorability Assumption is not satisfied.
# 1.14614856437517e-23
# The Ignorability Assumption is not satisfied.
# 5.311789878005499e-12
# The Ignorability Assumption is not satisfied.
# 4.600623212741253e-19
# The Ignorability Assumption is not satisfied.
# 1.6597964178341531e-12
# The Ignorability Assumption is not satisfied.
# 2.3574039267845814e-14
# The Ignorability Assumption is not satisfied.
# 1.0905322156138284e-12
# The Ignorability Assumption is not satisfied.
# 2.1079494175812193e-14
# The Ignorability Assumption is not satisfied.
# 3.129696159680951e-11
# The Ignorability Assumption is not satisfied.
# 1.1791748852666044e-11
# The Ignorability Assumption is not satisfied.
# 1.703885280109618e-09
# The Ignorability Assumption is not satisfied.
# 1.060315516084353e-12
# The Ignorability Assumption is not satisfied.
# 4.4227106669569213e-11
# The Ignorability Assumption is not satisfied.
# 1.1753559418481703e-15
# The Ignorability Assumption is not satisfied.
# 5.400317178262694e-09
# The Ignorability Assumption is not satisfied.
# 1.3551627419848746e-15
# The Ignorability Assumption is not satisfied.
# 2.9009281721513553e-15
# The Ignorability Assumption is not satisfied.
# 1.2900146769680076e-12
# The Ignorability Assumption is not satisfied.
# 2.532478802418065e-11
# The Ignorability Assumption is not satisfied.
# 3.66861562295561e-14
# The Ignorability Assumption is not satisfied.
# 1.3120972748100667e-18
# The Ignorability Assumption is not satisfied.
# 3.423675699616231e-16
# The Ignorability Assumption is not satisfied.
# 1.272985262172687e-11
# The Ignorability Assumption is not satisfied.
# 9.149896869393578e-15
# The Ignorability Assumption is not satisfied.
# 6.700570251527368e-11
# The Ignorability Assumption is not satisfied.
# 2.2097742695103848e-08
# The Ignorability Assumption is not satisfied.
# 9.835929772511124e-11
# The Ignorability Assumption is not satisfied.
# 3.9939186917982634e-10
# The Ignorability Assumption is not satisfied.
# 3.464470322703901e-12
# The Ignorability Assumption is not satisfied.
# 9.78583335522747e-11
# The Ignorability Assumption is not satisfied.
# 6.847030104963733e-17
# The Ignorability Assumption is not satisfied.
# 2.6461629547747915e-10
# The Ignorability Assumption is not satisfied.
# 6.349776689048038e-11
# The Ignorability Assumption is not satisfied.
# 3.1928303006179727e-11
# The Ignorability Assumption is not satisfied.
# 4.100152505649325e-09
# The Ignorability Assumption is not satisfied.
# 1.4209189290996039e-13
# The Ignorability Assumption is not satisfied.
# 4.149496989594953e-17
# The Ignorability Assumption is not satisfied.
# 2.5030753830741914e-10
# The Ignorability Assumption is not satisfied.
# 1.7068583879315844e-17
# The Ignorability Assumption is not satisfied.
# 3.516585722966478e-09
# The Ignorability Assumption is not satisfied.
# 2.2896170480564186e-11
# The Ignorability Assumption is not satisfied.
# 6.913010252886214e-15
# The Ignorability Assumption is not satisfied.
# 7.358556737305478e-15
# The Ignorability Assumption is not satisfied.
# 2.3480871584878786e-16
# The Ignorability Assumption is not satisfied.
# 8.105096376514815e-15
# The Ignorability Assumption is not satisfied.
# 2.1759206335979082e-13
# The Ignorability Assumption is not satisfied.
# 1.016492679656124e-16
# The Ignorability Assumption is not satisfied.
# 1.2028142196136062e-07
# The Ignorability Assumption is not satisfied.
# 6.657522552792093e-13
# The Ignorability Assumption is not satisfied.
# 6.199104014451853e-18
# The Ignorability Assumption is not satisfied.
# 2.490837627215436e-14
# The Ignorability Assumption is not satisfied.
# 9.773698305953866e-09
# The Ignorability Assumption is not satisfied.
# 2.8856229424961016e-06
# The Ignorability Assumption is not satisfied.
# 1.818705111654881e-11
# The Ignorability Assumption is not satisfied.
# 2.4721446448081345e-18
# The Ignorability Assumption is not satisfied.
# 1.159792516156828e-09
# The Ignorability Assumption is not satisfied.
# 4.5203493571327216e-11
# The Ignorability Assumption is not satisfied.
# 5.404149899616877e-10
# The Ignorability Assumption is not satisfied.
# 3.880405288498281e-09
# The Ignorability Assumption is not satisfied.
# 4.764126857562778e-16
# The Ignorability Assumption is not satisfied.
# 2.6188224483459577e-18
# The Ignorability Assumption is not satisfied.
# 1.0366467326865407e-13
# The Ignorability Assumption is not satisfied.
# 1.862531185761441e-21
# The Ignorability Assumption is not satisfied.
# 3.2948679567141217e-10
# The Ignorability Assumption is not satisfied.
# 2.1486533338374227e-15
# The Ignorability Assumption is not satisfied.
# 3.0152313404623826e-14
# The Ignorability Assumption is not satisfied.
# 1.7027271113329874e-12
# The Ignorability Assumption is not satisfied.
# 3.344410989086852e-11
# The Ignorability Assumption is not satisfied.
# 1.2057247281920278e-09
# The Ignorability Assumption is not satisfied.
# 6.902739647732754e-13
# The Ignorability Assumption is not satisfied.
# 7.466735948514988e-21
# The Ignorability Assumption is not satisfied.
# 2.6216418602749193e-09
# The Ignorability Assumption is not satisfied.
# 5.6339563683372115e-12
# The Ignorability Assumption is not satisfied.
# 7.837466599777283e-12
# The Ignorability Assumption is not satisfied.
# 5.447330214516017e-07
# The Ignorability Assumption is not satisfied.
# 4.737897953515423e-10
# The Ignorability Assumption is not satisfied.
# 1.2802602084596225e-12
# The Ignorability Assumption is not satisfied.
# 1.7942763508852927e-07
# The Ignorability Assumption is not satisfied.
# 5.547970625752865e-11
# The Ignorability Assumption is not satisfied.
# 6.084424201604106e-06
# The Ignorability Assumption is not satisfied.
# 1.3583179532830525e-07
# The Ignorability Assumption is not satisfied.
# 1.4653468072275124e-08
# The Ignorability Assumption is not satisfied.
# 1.2330349718653807e-10
# The Ignorability Assumption is not satisfied.
# 3.396672455945164e-11
# The Ignorability Assumption is not satisfied.
# 1.2567160377075086e-10
# The Ignorability Assumption is not satisfied.
# 3.487676911871313e-10
# The Ignorability Assumption is not satisfied.
# 6.419235442262329e-18
# The Ignorability Assumption is not satisfied.
# 1.0080897696605899e-11
# The Ignorability Assumption is not satisfied.
# 1.5677172538748883e-10
# The Ignorability Assumption is not satisfied.
# 7.755619580336466e-10
# The Ignorability Assumption is not satisfied.
# 6.126137704175707e-14
# The Ignorability Assumption is not satisfied.
# 6.014995455608828e-13
# The Ignorability Assumption is not satisfied.
# 1.4178749338057058e-10
# The Ignorability Assumption is not satisfied.
# 2.081501747366172e-12
# The Ignorability Assumption is not satisfied.
# 8.355873084285315e-14
# The Ignorability Assumption is not satisfied.
# 3.121694168125734e-14
# The Ignorability Assumption is not satisfied.
# 1.3286717433878512e-10
# The Ignorability Assumption is not satisfied.
# 4.2291801941883777e-13
# The Ignorability Assumption is not satisfied.
# 2.0599348478439373e-11
# The Ignorability Assumption is not satisfied.
# 3.376769598750952e-12
# The Ignorability Assumption is not satisfied.
# 1.006969090731074e-12
# The Ignorability Assumption is not satisfied.
# 5.2811658801655146e-12
# The Ignorability Assumption is not satisfied.
# 5.4797313517940425e-14
# The Ignorability Assumption is not satisfied.
# 6.326269887090097e-09
# The Ignorability Assumption is not satisfied.
# 6.501636803768956e-11
# The Ignorability Assumption is not satisfied.
# 1.93974988576884e-11
# The Ignorability Assumption is not satisfied.
# 1.4344407751571966e-12
# The Ignorability Assumption is not satisfied.
# 2.865584278187066e-14
# The Ignorability Assumption is not satisfied.
# 1.750628543999248e-15
# The Ignorability Assumption is not satisfied.
# 7.211833379616189e-11
# The Ignorability Assumption is not satisfied.
# 2.7247337528331435e-14
# The Ignorability Assumption is not satisfied.
# 2.9977360652867945e-09
# The Ignorability Assumption is not satisfied.
# 1.2227367041099494e-13
# The Ignorability Assumption is not satisfied.
# 5.766061883877254e-14
# The Ignorability Assumption is not satisfied.
# 3.195380391512058e-08
# The Ignorability Assumption is not satisfied.
# 8.99836737375766e-17
# The Ignorability Assumption is not satisfied.
# 7.11697300089437e-12
# The Ignorability Assumption is not satisfied.
# 3.551543106785328e-09
# The Ignorability Assumption is not satisfied.
# 2.8853873046862408e-11
# The Ignorability Assumption is not satisfied.
# 1.1252018692293786e-13
# The Ignorability Assumption is not satisfied.
# 1.2760903706853451e-20
# The Ignorability Assumption is not satisfied.
# 4.7984282200862826e-12
# The Ignorability Assumption is not satisfied.
# 9.342809063857668e-12
# The Ignorability Assumption is not satisfied.
# 5.29901688097554e-10
# The Ignorability Assumption is not satisfied.
# 1.458682055886103e-10
# The Ignorability Assumption is not satisfied.
# 9.347982163794953e-16
# The Ignorability Assumption is not satisfied.
# 9.140902941250595e-13
# The Ignorability Assumption is not satisfied.
# 4.567609460416682e-12
# The Ignorability Assumption is not satisfied.
# 1.97868974249088e-10
# The Ignorability Assumption is not satisfied.

# %%
COUNT3
# Out:
# 1000

# %% [markdown]
# ### Scenario 4

# %%
# 2종 오류 (confounder인 C가 안 찾아짐.)

np.random.seed(1)

COUNT4 = 0
for i in range(1000):
    
    n = 1000 
    k0_co = 0.3
    k1_co = 1
    k0_at = 1.5
    k1_at = 1
    k0_nt = -1
    k1_nt = 2

    a0 = -2 #changeable
    a1 = -1

    X = np.random.binomial(1,0.5,size=n)

    mu_Z = 1/(1+np.exp(1-2*X))
    Z = np.random.binomial(1,mu_Z,size=n)

    p_at = np.exp(-2.5+3.5*X)/(1+np.exp(-2.5+3.5*X)+np.exp(-2.5+3.5*X))
    p_nt = np.exp(-2.5+3.5*X)/(1+np.exp(-2.5+3.5*X)+np.exp(-2.5+3.5*X))
    p_co = 1/(1+np.exp(-2.5+3.5*X)+np.exp(-2.5+3.5*X))

    C=[]
    for j in range(n):
        C.append(np.random.choice(["co","at","nt"], size=1, replace=True, p=[p_at[j],p_nt[j],p_co[j]])[0])
    C=np.array(C)

    A = np.repeat(0,n)
    A[C=="at"] = 1
    A[(C=="co")*(Z==1)] = 1

    Y = np.random.normal(0,1,n)
    for k in range(n):

        if C[k]=="co":
            mu_y = k0_co+k1_co*X[k]+(a0+a1*X[k])*A[k]
            Y[k] = np.random.normal(mu_y,1,1)[0]
        elif C[k] == "at":
            mu_y = k0_at+k1_at*X[k]
            Y[k] = np.random.normal(mu_y,1,1)[0]
        else:
            mu_y = k0_nt+k1_nt*X[k]
            Y[k] = np.random.normal(mu_y,1,1)[0]
            
    #data = pd.DataFrame({"col1":Y,"col2":Z,"col3":A,"col4":C,"col5":X})
    #data.loc[data["col4"]=="nt","col4"] = 0 
    #data.loc[data["col4"]=="co","col4"] = 1
    #data.loc[data["col4"]=="at","col4"] = 2 
    
    pvalue = IgnorTest(cause=A, effect=Y, explorer=Z, covariate=X, level=0.05, dtype="mixed")
    if pvalue<=0.01:
        COUNT4 = COUNT4+1
# Out:
# 1.3081458486699698e-21
# The Ignorability Assumption is not satisfied.
# 8.029375791169955e-26
# The Ignorability Assumption is not satisfied.
# 4.2544548440813966e-17
# The Ignorability Assumption is not satisfied.
# 1.2902411302522566e-19
# The Ignorability Assumption is not satisfied.
# 4.7247695517117026e-29
# The Ignorability Assumption is not satisfied.
# 1.308726267365342e-12
# The Ignorability Assumption is not satisfied.
# 2.9151474115202787e-19
# The Ignorability Assumption is not satisfied.
# 7.971545142575393e-24
# The Ignorability Assumption is not satisfied.
# 2.8748649129491176e-25
# The Ignorability Assumption is not satisfied.
# 6.945270726561645e-18
# The Ignorability Assumption is not satisfied.
# 3.358352145587968e-23
# The Ignorability Assumption is not satisfied.
# 1.065730421570571e-11
# The Ignorability Assumption is not satisfied.
# 8.506965386616636e-19
# The Ignorability Assumption is not satisfied.
# 4.223158546021412e-26
# The Ignorability Assumption is not satisfied.
# 5.440485105258697e-21
# The Ignorability Assumption is not satisfied.
# 1.0895005593578067e-24
# The Ignorability Assumption is not satisfied.
# 1.542152397058513e-20
# The Ignorability Assumption is not satisfied.
# 2.5280690187203005e-20
# The Ignorability Assumption is not satisfied.
# 3.3110018937975614e-25
# The Ignorability Assumption is not satisfied.
# 3.52347459919376e-22
# The Ignorability Assumption is not satisfied.
# 1.1887580443621037e-19
# The Ignorability Assumption is not satisfied.
# 7.336515731554911e-27
# The Ignorability Assumption is not satisfied.
# 5.950531404727721e-16
# The Ignorability Assumption is not satisfied.
# 1.3009292712065063e-22
# The Ignorability Assumption is not satisfied.
# 1.68887553805768e-22
# The Ignorability Assumption is not satisfied.
# 1.0873711544664746e-17
# The Ignorability Assumption is not satisfied.
# 5.581121158153702e-22
# The Ignorability Assumption is not satisfied.
# 2.0998308199867604e-17
# The Ignorability Assumption is not satisfied.
# 2.7469022047433237e-25
# The Ignorability Assumption is not satisfied.
# 3.8082346317888123e-16
# The Ignorability Assumption is not satisfied.
# 4.0763781613274226e-20
# The Ignorability Assumption is not satisfied.
# 5.076309986102552e-19
# The Ignorability Assumption is not satisfied.
# 3.3421028542118387e-23
# The Ignorability Assumption is not satisfied.
# 4.6129684475632044e-21
# The Ignorability Assumption is not satisfied.
# 8.088798062841614e-26
# The Ignorability Assumption is not satisfied.
# 4.3667101001996516e-21
# The Ignorability Assumption is not satisfied.
# 2.8839406483920897e-25
# The Ignorability Assumption is not satisfied.
# 2.8292059314674575e-25
# The Ignorability Assumption is not satisfied.
# 1.0191160036757256e-18
# The Ignorability Assumption is not satisfied.
# 1.2529367644808083e-20
# The Ignorability Assumption is not satisfied.
# 4.477721737057595e-23
# The Ignorability Assumption is not satisfied.
# 3.988530804246628e-21
# The Ignorability Assumption is not satisfied.
# 1.1646831869827112e-17
# The Ignorability Assumption is not satisfied.
# 1.7989111816794233e-16
# The Ignorability Assumption is not satisfied.
# 3.600992209178982e-29
# The Ignorability Assumption is not satisfied.
# 5.134603859139737e-12
# The Ignorability Assumption is not satisfied.
# 3.091214699634237e-22
# The Ignorability Assumption is not satisfied.
# 1.164010211381291e-19
# The Ignorability Assumption is not satisfied.
# 1.6977998643969376e-14
# The Ignorability Assumption is not satisfied.
# 1.9168108520532226e-21
# The Ignorability Assumption is not satisfied.
# 3.555487763619122e-20
# The Ignorability Assumption is not satisfied.
# 9.659023128867589e-20
# The Ignorability Assumption is not satisfied.
# 6.39690306522763e-17
# The Ignorability Assumption is not satisfied.
# 3.017056485032862e-17
# The Ignorability Assumption is not satisfied.
# 5.936815407621003e-22
# The Ignorability Assumption is not satisfied.
# 8.205984758121979e-21
# The Ignorability Assumption is not satisfied.
# 2.7339966037320767e-18
# The Ignorability Assumption is not satisfied.
# 2.4161810224975018e-17
# The Ignorability Assumption is not satisfied.
# 3.5451937137819706e-19
# The Ignorability Assumption is not satisfied.
# 6.217152231194746e-15
# The Ignorability Assumption is not satisfied.
# 8.287468885085612e-19
# The Ignorability Assumption is not satisfied.
# 2.3562258709612486e-16
# The Ignorability Assumption is not satisfied.
# 1.9158623800201996e-23
# The Ignorability Assumption is not satisfied.
# 6.6227245478117105e-15
# The Ignorability Assumption is not satisfied.
# 1.959796560022868e-24
# The Ignorability Assumption is not satisfied.
# 4.1680603649791675e-24
# The Ignorability Assumption is not satisfied.
# 1.3045368902004916e-16
# The Ignorability Assumption is not satisfied.
# 1.2334627447747994e-17
# The Ignorability Assumption is not satisfied.
# 2.215120244978282e-21
# The Ignorability Assumption is not satisfied.
# 3.879511476399712e-14
# The Ignorability Assumption is not satisfied.
# 4.13612518596124e-18
# The Ignorability Assumption is not satisfied.
# 7.472333246124304e-18
# The Ignorability Assumption is not satisfied.
# 1.4219388122369193e-23
# The Ignorability Assumption is not satisfied.
# 1.2373595448201117e-17
# The Ignorability Assumption is not satisfied.
# 2.590802032146614e-18
# The Ignorability Assumption is not satisfied.
# 7.429933157940629e-26
# The Ignorability Assumption is not satisfied.
# 5.5062960704401375e-25
# The Ignorability Assumption is not satisfied.
# 5.830936470335987e-25
# The Ignorability Assumption is not satisfied.
# 4.441832041408114e-20
# The Ignorability Assumption is not satisfied.
# 8.434309248599569e-16
# The Ignorability Assumption is not satisfied.
# 1.1106918202374668e-25
# The Ignorability Assumption is not satisfied.
# 7.146039394720501e-23
# The Ignorability Assumption is not satisfied.
# 4.2351181849253726e-22
# The Ignorability Assumption is not satisfied.
# 1.6394003835261008e-19
# The Ignorability Assumption is not satisfied.
# 1.268513188639258e-23
# The Ignorability Assumption is not satisfied.
# 1.3665047616185784e-21
# The Ignorability Assumption is not satisfied.
# 5.442375755172717e-23
# The Ignorability Assumption is not satisfied.
# 1.9577188354808354e-24
# The Ignorability Assumption is not satisfied.
# 1.4881423000522312e-14
# The Ignorability Assumption is not satisfied.
# 5.068208918542658e-13
# The Ignorability Assumption is not satisfied.
# 1.375661031585994e-21
# The Ignorability Assumption is not satisfied.
# 1.1594169427456035e-22
# The Ignorability Assumption is not satisfied.
# 2.6355436488903817e-17
# The Ignorability Assumption is not satisfied.
# 3.184993027807365e-21
# The Ignorability Assumption is not satisfied.
# 9.287361226377557e-13
# The Ignorability Assumption is not satisfied.
# 3.078119721728984e-14
# The Ignorability Assumption is not satisfied.
# 8.906507425715283e-21
# The Ignorability Assumption is not satisfied.
# 1.3034501260517354e-18
# The Ignorability Assumption is not satisfied.
# 9.143669480716007e-23
# The Ignorability Assumption is not satisfied.
# 4.993490744820277e-18
# The Ignorability Assumption is not satisfied.
# 6.2324045623143625e-15
# The Ignorability Assumption is not satisfied.
# 5.079264184659926e-19
# The Ignorability Assumption is not satisfied.
# 3.732501029434215e-23
# The Ignorability Assumption is not satisfied.
# 6.615349463423223e-25
# The Ignorability Assumption is not satisfied.
# 1.7589907297248444e-17
# The Ignorability Assumption is not satisfied.
# 3.1192570797609574e-25
# The Ignorability Assumption is not satisfied.
# 9.443487415208886e-25
# The Ignorability Assumption is not satisfied.
# 5.860491734802213e-16
# The Ignorability Assumption is not satisfied.
# 2.6356104143679237e-22
# The Ignorability Assumption is not satisfied.
# 4.2856812274589827e-16
# The Ignorability Assumption is not satisfied.
# 9.238218339492243e-15
# The Ignorability Assumption is not satisfied.
# 1.404092037179478e-14
# The Ignorability Assumption is not satisfied.
# 4.040210778177769e-18
# The Ignorability Assumption is not satisfied.
# 7.365800067803294e-21
# The Ignorability Assumption is not satisfied.
# 7.970362532074321e-14
# The Ignorability Assumption is not satisfied.
# 2.4922177699858048e-17
# The Ignorability Assumption is not satisfied.
# 5.864439288534548e-22
# The Ignorability Assumption is not satisfied.
# 1.986410055789658e-15
# The Ignorability Assumption is not satisfied.
# 3.0986150429263923e-15
# The Ignorability Assumption is not satisfied.
# 5.258191292120587e-12
# The Ignorability Assumption is not satisfied.
# 1.1305667275828778e-17
# The Ignorability Assumption is not satisfied.
# 1.3070517034860116e-20
# The Ignorability Assumption is not satisfied.
# 8.77532409941075e-23
# The Ignorability Assumption is not satisfied.
# 1.1336280635332304e-25
# The Ignorability Assumption is not satisfied.
# 3.476086958267166e-14
# The Ignorability Assumption is not satisfied.
# 1.1239063880784527e-18
# The Ignorability Assumption is not satisfied.
# 2.2608589722269616e-21
# The Ignorability Assumption is not satisfied.
# 2.4246321329561138e-18
# The Ignorability Assumption is not satisfied.
# 7.51266275795526e-18
# The Ignorability Assumption is not satisfied.
# 2.0364747507387855e-21
# The Ignorability Assumption is not satisfied.
# 5.1790727989832635e-15
# The Ignorability Assumption is not satisfied.
# 2.058244659431409e-23
# The Ignorability Assumption is not satisfied.
# 4.726634874261081e-22
# The Ignorability Assumption is not satisfied.
# 3.0754455138195882e-21
# The Ignorability Assumption is not satisfied.
# 7.531852554218387e-17
# The Ignorability Assumption is not satisfied.
# 2.701512539678341e-22
# The Ignorability Assumption is not satisfied.
# 5.41025118816769e-15
# The Ignorability Assumption is not satisfied.
# 2.8054541668456097e-16
# The Ignorability Assumption is not satisfied.
# 5.68029962875879e-27
# The Ignorability Assumption is not satisfied.
# 5.506974257614294e-15
# The Ignorability Assumption is not satisfied.
# 4.741508039867959e-19
# The Ignorability Assumption is not satisfied.
# 3.900609525897319e-21
# The Ignorability Assumption is not satisfied.
# 9.670405556406683e-21
# The Ignorability Assumption is not satisfied.
# 1.8529804870504343e-31
# The Ignorability Assumption is not satisfied.
# 1.260087325286299e-13
# The Ignorability Assumption is not satisfied.
# 1.918254382940364e-25
# The Ignorability Assumption is not satisfied.
# 4.1902902265743973e-16
# The Ignorability Assumption is not satisfied.
# 2.0903650412038248e-16
# The Ignorability Assumption is not satisfied.
# 2.1513515838514795e-14
# The Ignorability Assumption is not satisfied.
# 8.024691813138035e-20
# The Ignorability Assumption is not satisfied.
# 9.192130869527504e-28
# The Ignorability Assumption is not satisfied.
# 1.2158884477740512e-19
# The Ignorability Assumption is not satisfied.
# 1.6151818519003968e-23
# The Ignorability Assumption is not satisfied.
# 8.263285146862125e-20
# The Ignorability Assumption is not satisfied.
# 2.994712960066291e-20
# The Ignorability Assumption is not satisfied.
# 5.950219859234295e-19
# The Ignorability Assumption is not satisfied.
# 1.3103421157326633e-17
# The Ignorability Assumption is not satisfied.
# 3.814418214718194e-27
# The Ignorability Assumption is not satisfied.
# 1.2181391299898906e-17
# The Ignorability Assumption is not satisfied.
# 4.819073724717184e-25
# The Ignorability Assumption is not satisfied.
# 1.6348166248299405e-19
# The Ignorability Assumption is not satisfied.
# 2.9571529565519706e-16
# The Ignorability Assumption is not satisfied.
# 1.51324766626804e-15
# The Ignorability Assumption is not satisfied.
# 1.6531166968830317e-23
# The Ignorability Assumption is not satisfied.
# 6.675002671499658e-19
# The Ignorability Assumption is not satisfied.
# 6.592471911636849e-22
# The Ignorability Assumption is not satisfied.
# 3.9345230027946437e-16
# The Ignorability Assumption is not satisfied.
# 1.9360441577943607e-19
# The Ignorability Assumption is not satisfied.
# 7.61088818138759e-20
# The Ignorability Assumption is not satisfied.
# 4.286773651451133e-26
# The Ignorability Assumption is not satisfied.
# 4.536576343951041e-21
# The Ignorability Assumption is not satisfied.
# 2.018184546502157e-24
# The Ignorability Assumption is not satisfied.
# 1.5631311948795668e-26
# The Ignorability Assumption is not satisfied.
# 1.535467304593971e-16
# The Ignorability Assumption is not satisfied.
# 1.0788872524640115e-14
# The Ignorability Assumption is not satisfied.
# 1.3357630999337792e-17
# The Ignorability Assumption is not satisfied.
# 9.83728766355071e-18
# The Ignorability Assumption is not satisfied.
# 4.110765249957424e-16
# The Ignorability Assumption is not satisfied.
# 7.363935708716583e-17
# The Ignorability Assumption is not satisfied.
# 5.832568306179759e-16
# The Ignorability Assumption is not satisfied.
# 5.371388167748459e-28
# The Ignorability Assumption is not satisfied.
# 4.41340805596818e-25
# The Ignorability Assumption is not satisfied.
# 6.439627948569129e-20
# The Ignorability Assumption is not satisfied.
# 9.903694465433597e-17
# The Ignorability Assumption is not satisfied.
# 2.3719944086597628e-17
# The Ignorability Assumption is not satisfied.
# 2.926324337622825e-23
# The Ignorability Assumption is not satisfied.
# 8.045945592144559e-20
# The Ignorability Assumption is not satisfied.
# 3.2235985915159006e-17
# The Ignorability Assumption is not satisfied.
# 1.845649632506865e-21
# The Ignorability Assumption is not satisfied.
# 1.1466443433750125e-24
# The Ignorability Assumption is not satisfied.
# 1.3309271882301115e-20
# The Ignorability Assumption is not satisfied.
# 4.465813166759493e-18
# The Ignorability Assumption is not satisfied.
# 1.7978572745944566e-17
# The Ignorability Assumption is not satisfied.
# 1.5617706381897007e-29
# The Ignorability Assumption is not satisfied.
# 1.637369261359684e-20
# The Ignorability Assumption is not satisfied.
# 1.179970864684442e-22
# The Ignorability Assumption is not satisfied.
# 2.0604095003537556e-26
# The Ignorability Assumption is not satisfied.
# 9.363907486066785e-17
# The Ignorability Assumption is not satisfied.
# 8.820472192694428e-20
# The Ignorability Assumption is not satisfied.
# 3.4478783276926675e-33
# The Ignorability Assumption is not satisfied.
# 7.653349134498015e-25
# The Ignorability Assumption is not satisfied.
# 2.878584319798277e-18
# The Ignorability Assumption is not satisfied.
# 1.5409191832306244e-19
# The Ignorability Assumption is not satisfied.
# 1.6012337228196027e-24
# The Ignorability Assumption is not satisfied.
# 1.492890744692388e-17
# The Ignorability Assumption is not satisfied.
# 7.937047079584006e-20
# The Ignorability Assumption is not satisfied.
# 5.923372609263325e-19
# The Ignorability Assumption is not satisfied.
# 1.4561256323547256e-18
# The Ignorability Assumption is not satisfied.
# 6.17925395870836e-19
# The Ignorability Assumption is not satisfied.
# 6.668748744824507e-20
# The Ignorability Assumption is not satisfied.
# 1.368757921156269e-19
# The Ignorability Assumption is not satisfied.
# 1.174666453282877e-16
# The Ignorability Assumption is not satisfied.
# 1.5217610695538233e-24
# The Ignorability Assumption is not satisfied.
# 3.266608518667012e-20
# The Ignorability Assumption is not satisfied.
# 3.288772359264721e-28
# The Ignorability Assumption is not satisfied.
# 1.544039290031327e-16
# The Ignorability Assumption is not satisfied.
# 8.700061682166046e-16
# The Ignorability Assumption is not satisfied.
# 3.8619291812230073e-26
# The Ignorability Assumption is not satisfied.
# 3.4461126709746924e-20
# The Ignorability Assumption is not satisfied.
# 1.2506010629534906e-21
# The Ignorability Assumption is not satisfied.
# 1.0051460140345407e-19
# The Ignorability Assumption is not satisfied.
# 5.498572126753075e-23
# The Ignorability Assumption is not satisfied.
# 1.0192524079184165e-17
# The Ignorability Assumption is not satisfied.
# 1.102931172183758e-30
# The Ignorability Assumption is not satisfied.
# 2.671446830543675e-12
# The Ignorability Assumption is not satisfied.
# 1.091588119894497e-25
# The Ignorability Assumption is not satisfied.
# 1.8805195430571674e-19
# The Ignorability Assumption is not satisfied.
# 1.5638000174219963e-18
# The Ignorability Assumption is not satisfied.
# 6.923707314643663e-21
# The Ignorability Assumption is not satisfied.
# 7.269861661535023e-23
# The Ignorability Assumption is not satisfied.
# 1.91467168773186e-16
# The Ignorability Assumption is not satisfied.
# 9.595501694679661e-20
# The Ignorability Assumption is not satisfied.
# 2.516279917515293e-20
# The Ignorability Assumption is not satisfied.
# 2.4550865882488654e-23
# The Ignorability Assumption is not satisfied.
# 7.306329285053469e-16
# The Ignorability Assumption is not satisfied.
# 3.5873321831430113e-19
# The Ignorability Assumption is not satisfied.
# 1.3549812995765162e-21
# The Ignorability Assumption is not satisfied.
# 1.1891228176142069e-21
# The Ignorability Assumption is not satisfied.
# 1.7138583173646882e-22
# The Ignorability Assumption is not satisfied.
# 5.003865321910385e-22
# The Ignorability Assumption is not satisfied.
# 6.886972387072067e-28
# The Ignorability Assumption is not satisfied.
# 8.789328814483048e-21
# The Ignorability Assumption is not satisfied.
# 6.640092741126448e-20
# The Ignorability Assumption is not satisfied.
# 6.193935040791515e-20
# The Ignorability Assumption is not satisfied.
# 1.2792736613349926e-15
# The Ignorability Assumption is not satisfied.
# 1.767425312800419e-21
# The Ignorability Assumption is not satisfied.
# 2.9912155876089645e-23
# The Ignorability Assumption is not satisfied.
# 1.695094823163395e-21
# The Ignorability Assumption is not satisfied.
# 1.1901568988481513e-19
# The Ignorability Assumption is not satisfied.
# 5.675352739583756e-24
# The Ignorability Assumption is not satisfied.
# 4.530610664798105e-17
# The Ignorability Assumption is not satisfied.
# 4.899697650507461e-16
# The Ignorability Assumption is not satisfied.
# 7.987074660632375e-23
# The Ignorability Assumption is not satisfied.
# 8.074983166374424e-31
# The Ignorability Assumption is not satisfied.
# 9.929791703269772e-22
# The Ignorability Assumption is not satisfied.
# 1.6634546164486956e-19
# The Ignorability Assumption is not satisfied.
# 1.1562722326640713e-20
# The Ignorability Assumption is not satisfied.
# 3.947893848132319e-27
# The Ignorability Assumption is not satisfied.
# 5.897498653361999e-19
# The Ignorability Assumption is not satisfied.
# 4.686318148321207e-18
# The Ignorability Assumption is not satisfied.
# 1.074224792493203e-20
# The Ignorability Assumption is not satisfied.
# 1.327974914594954e-24
# The Ignorability Assumption is not satisfied.
# 3.1094541640666017e-21
# The Ignorability Assumption is not satisfied.
# 6.407218945466758e-18
# The Ignorability Assumption is not satisfied.
# 2.3286787378617997e-15
# The Ignorability Assumption is not satisfied.
# 8.647766826720224e-16
# The Ignorability Assumption is not satisfied.
# 3.805967948359289e-18
# The Ignorability Assumption is not satisfied.
# 2.6664104161398655e-22
# The Ignorability Assumption is not satisfied.
# 2.7763385283928635e-16
# The Ignorability Assumption is not satisfied.
# 2.704059617503887e-18
# The Ignorability Assumption is not satisfied.
# 1.0362018442585295e-15
# The Ignorability Assumption is not satisfied.
# 4.9033103976747765e-21
# The Ignorability Assumption is not satisfied.
# 9.353611796079246e-21
# The Ignorability Assumption is not satisfied.
# 1.1921875593933827e-12
# The Ignorability Assumption is not satisfied.
# 1.8814920643435776e-20
# The Ignorability Assumption is not satisfied.
# 2.5002127076272216e-24
# The Ignorability Assumption is not satisfied.
# 7.24980977460731e-15
# The Ignorability Assumption is not satisfied.
# 2.124057372733399e-18
# The Ignorability Assumption is not satisfied.
# 4.341006335540488e-21
# The Ignorability Assumption is not satisfied.
# 6.97577258356963e-22
# The Ignorability Assumption is not satisfied.
# 4.3017879050742484e-23
# The Ignorability Assumption is not satisfied.
# 6.498858547315362e-19
# The Ignorability Assumption is not satisfied.
# 1.4701801569216896e-18
# The Ignorability Assumption is not satisfied.
# 1.073472512604464e-17
# The Ignorability Assumption is not satisfied.
# 7.5434626774839125e-22
# The Ignorability Assumption is not satisfied.
# 4.7226489994378e-24
# The Ignorability Assumption is not satisfied.
# 1.0619617609568814e-25
# The Ignorability Assumption is not satisfied.
# 5.436044675622235e-19
# The Ignorability Assumption is not satisfied.
# 3.08645601478645e-11
# The Ignorability Assumption is not satisfied.
# 3.6055549903945885e-15
# The Ignorability Assumption is not satisfied.
# 2.609352065569856e-25
# The Ignorability Assumption is not satisfied.
# 6.663506458694899e-14
# The Ignorability Assumption is not satisfied.
# 1.0319534452254941e-21
# The Ignorability Assumption is not satisfied.
# 3.6518010853947206e-25
# The Ignorability Assumption is not satisfied.
# 1.31163048940332e-24
# The Ignorability Assumption is not satisfied.
# 1.0070836381679372e-14
# The Ignorability Assumption is not satisfied.
# 1.2020715846377596e-20
# The Ignorability Assumption is not satisfied.
# 6.458507003207976e-17
# The Ignorability Assumption is not satisfied.
# 3.667117366614926e-21
# The Ignorability Assumption is not satisfied.
# 1.4567331516849315e-25
# The Ignorability Assumption is not satisfied.
# 1.2015941818486263e-21
# The Ignorability Assumption is not satisfied.
# 1.7728098110635064e-27
# The Ignorability Assumption is not satisfied.
# 4.99644994199328e-17
# The Ignorability Assumption is not satisfied.
# 2.1919300428387073e-19
# The Ignorability Assumption is not satisfied.
# 4.547250667381712e-20
# The Ignorability Assumption is not satisfied.
# 1.1824896226942757e-22
# The Ignorability Assumption is not satisfied.
# 8.894868289020381e-20
# The Ignorability Assumption is not satisfied.
# 5.610943889839575e-19
# The Ignorability Assumption is not satisfied.
# 7.314268225940894e-20
# The Ignorability Assumption is not satisfied.
# 1.3919001977606494e-10
# The Ignorability Assumption is not satisfied.
# 2.8342437774623037e-15
# The Ignorability Assumption is not satisfied.
# 4.492618128565609e-21
# The Ignorability Assumption is not satisfied.
# 6.701734798876068e-24
# The Ignorability Assumption is not satisfied.
# 4.676548726253714e-20
# The Ignorability Assumption is not satisfied.
# 3.3616394477692797e-18
# The Ignorability Assumption is not satisfied.
# 4.65008475150961e-16
# The Ignorability Assumption is not satisfied.
# 1.9465651340625264e-20
# The Ignorability Assumption is not satisfied.
# 2.6492399144365935e-19
# The Ignorability Assumption is not satisfied.
# 1.3553148487228355e-16
# The Ignorability Assumption is not satisfied.
# 1.4630051372173485e-15
# The Ignorability Assumption is not satisfied.
# 2.4950935596728885e-21
# The Ignorability Assumption is not satisfied.
# 6.141755576757195e-22
# The Ignorability Assumption is not satisfied.
# 2.922745554916714e-20
# The Ignorability Assumption is not satisfied.
# 1.094139662991608e-20
# The Ignorability Assumption is not satisfied.
# 2.2074207190738452e-14
# The Ignorability Assumption is not satisfied.
# 2.2916147703245076e-16
# The Ignorability Assumption is not satisfied.
# 3.8140469458460774e-21
# The Ignorability Assumption is not satisfied.
# 1.7893395793853723e-20
# The Ignorability Assumption is not satisfied.
# 7.042490569041899e-22
# The Ignorability Assumption is not satisfied.
# 2.2505469706866675e-24
# The Ignorability Assumption is not satisfied.
# 6.846171310092869e-17
# The Ignorability Assumption is not satisfied.
# 1.0328447624416767e-26
# The Ignorability Assumption is not satisfied.
# 1.7237322264633913e-15
# The Ignorability Assumption is not satisfied.
# 1.060316699151808e-24
# The Ignorability Assumption is not satisfied.
# 1.6208672815989313e-24
# The Ignorability Assumption is not satisfied.
# 8.698925445988763e-18
# The Ignorability Assumption is not satisfied.
# 1.5225970534728118e-16
# The Ignorability Assumption is not satisfied.
# 4.94293382149133e-13
# The Ignorability Assumption is not satisfied.
# 4.871807402404122e-15
# The Ignorability Assumption is not satisfied.
# 6.554831927842435e-20
# The Ignorability Assumption is not satisfied.
# 4.4354201040666535e-15
# The Ignorability Assumption is not satisfied.
# 1.5991803069437684e-22
# The Ignorability Assumption is not satisfied.
# 1.979577369663369e-21
# The Ignorability Assumption is not satisfied.
# 4.360953570883083e-21
# The Ignorability Assumption is not satisfied.
# 3.0332291491250456e-19
# The Ignorability Assumption is not satisfied.
# 2.5844010008484925e-20
# The Ignorability Assumption is not satisfied.
# 3.75534105769855e-13
# The Ignorability Assumption is not satisfied.
# 1.3513817962097785e-15
# The Ignorability Assumption is not satisfied.
# 2.8209742204064364e-16
# The Ignorability Assumption is not satisfied.
# 3.8387347549198636e-27
# The Ignorability Assumption is not satisfied.
# 1.0604902803969247e-24
# The Ignorability Assumption is not satisfied.
# 2.280870271787787e-20
# The Ignorability Assumption is not satisfied.
# 3.9402455277306215e-19
# The Ignorability Assumption is not satisfied.
# 8.822737408140566e-20
# The Ignorability Assumption is not satisfied.
# 2.435201083373103e-25
# The Ignorability Assumption is not satisfied.
# 7.842302809075967e-26
# The Ignorability Assumption is not satisfied.
# 8.676876309282098e-12
# The Ignorability Assumption is not satisfied.
# 2.4376047980835917e-24
# The Ignorability Assumption is not satisfied.
# 2.5768741451907713e-14
# The Ignorability Assumption is not satisfied.
# 1.615122876423653e-16
# The Ignorability Assumption is not satisfied.
# 6.099831553522125e-21
# The Ignorability Assumption is not satisfied.
# 1.1009829114248302e-15
# The Ignorability Assumption is not satisfied.
# 8.138297476630921e-22
# The Ignorability Assumption is not satisfied.
# 1.51262968363549e-13
# The Ignorability Assumption is not satisfied.
# 4.283811540478073e-21
# The Ignorability Assumption is not satisfied.
# 4.541027803663052e-21
# The Ignorability Assumption is not satisfied.
# 1.665027503032583e-20
# The Ignorability Assumption is not satisfied.
# 1.5219447416492529e-21
# The Ignorability Assumption is not satisfied.
# 1.4584051143672488e-25
# The Ignorability Assumption is not satisfied.
# 2.688528511451643e-22
# The Ignorability Assumption is not satisfied.
# 5.830840798441007e-21
# The Ignorability Assumption is not satisfied.
# 1.8509416361103703e-19
# The Ignorability Assumption is not satisfied.
# 5.226955854998331e-27
# The Ignorability Assumption is not satisfied.
# 8.773439994053326e-16
# The Ignorability Assumption is not satisfied.
# 4.816224610579403e-19
# The Ignorability Assumption is not satisfied.
# 3.4458506275025436e-23
# The Ignorability Assumption is not satisfied.
# 8.216661690847566e-21
# The Ignorability Assumption is not satisfied.
# 6.258345823405195e-17
# The Ignorability Assumption is not satisfied.
# 1.1548010646584849e-24
# The Ignorability Assumption is not satisfied.
# 1.3554268226492831e-16
# The Ignorability Assumption is not satisfied.
# 4.268346165141811e-21
# The Ignorability Assumption is not satisfied.
# 1.399514105171258e-20
# The Ignorability Assumption is not satisfied.
# 6.288113455656485e-14
# The Ignorability Assumption is not satisfied.
# 7.467623938514467e-18
# The Ignorability Assumption is not satisfied.
# 1.0013018365150408e-17
# The Ignorability Assumption is not satisfied.
# 7.187288099785118e-22
# The Ignorability Assumption is not satisfied.
# 3.8328547137315405e-21
# The Ignorability Assumption is not satisfied.
# 3.605539518329238e-18
# The Ignorability Assumption is not satisfied.
# 1.0316175370693885e-15
# The Ignorability Assumption is not satisfied.
# 1.4901459565897168e-25
# The Ignorability Assumption is not satisfied.
# 2.179576304051682e-22
# The Ignorability Assumption is not satisfied.
# 4.152296037617782e-20
# The Ignorability Assumption is not satisfied.
# 2.3001905645917612e-15
# The Ignorability Assumption is not satisfied.
# 4.047558940293293e-16
# The Ignorability Assumption is not satisfied.
# 4.25552779075533e-21
# The Ignorability Assumption is not satisfied.
# 7.781356832163556e-18
# The Ignorability Assumption is not satisfied.
# 2.520314438072522e-14
# The Ignorability Assumption is not satisfied.
# 3.502177380328315e-21
# The Ignorability Assumption is not satisfied.
# 1.924772066806791e-21
# The Ignorability Assumption is not satisfied.
# 5.014341700715537e-20
# The Ignorability Assumption is not satisfied.
# 3.9704368297556564e-19
# The Ignorability Assumption is not satisfied.
# 6.37456136177507e-14
# The Ignorability Assumption is not satisfied.
# 1.861997821099576e-20
# The Ignorability Assumption is not satisfied.
# 3.6331078428370684e-27
# The Ignorability Assumption is not satisfied.
# 1.3229602922381054e-21
# The Ignorability Assumption is not satisfied.
# 9.849056429875034e-29
# The Ignorability Assumption is not satisfied.
# 3.412421298267869e-21
# The Ignorability Assumption is not satisfied.
# 6.4992198415817365e-21
# The Ignorability Assumption is not satisfied.
# 4.373664350657142e-21
# The Ignorability Assumption is not satisfied.
# 2.3936052695843008e-17
# The Ignorability Assumption is not satisfied.
# 9.031327545258619e-15
# The Ignorability Assumption is not satisfied.
# 1.8954421833479878e-25
# The Ignorability Assumption is not satisfied.
# 9.120439325387787e-15
# The Ignorability Assumption is not satisfied.
# 1.2037994348927918e-28
# The Ignorability Assumption is not satisfied.
# 5.09223029833579e-23
# The Ignorability Assumption is not satisfied.
# 7.022094561833917e-18
# The Ignorability Assumption is not satisfied.
# 8.910488229238797e-22
# The Ignorability Assumption is not satisfied.
# 4.1058683494163457e-19
# The Ignorability Assumption is not satisfied.
# 2.30965196599431e-25
# The Ignorability Assumption is not satisfied.
# 2.1087674909600553e-32
# The Ignorability Assumption is not satisfied.
# 1.1295386227007265e-17
# The Ignorability Assumption is not satisfied.
# 4.184141868092296e-16
# The Ignorability Assumption is not satisfied.
# 7.325873959748085e-18
# The Ignorability Assumption is not satisfied.
# 9.115530755081674e-22
# The Ignorability Assumption is not satisfied.
# 2.553560444477477e-16
# The Ignorability Assumption is not satisfied.
# 1.0521563930294035e-18
# The Ignorability Assumption is not satisfied.
# 9.237130877995809e-27
# The Ignorability Assumption is not satisfied.
# 8.3670607313987385e-22
# The Ignorability Assumption is not satisfied.
# 7.306976671869801e-19
# The Ignorability Assumption is not satisfied.
# 2.577306797133911e-15
# The Ignorability Assumption is not satisfied.
# 3.8050189851232015e-25
# The Ignorability Assumption is not satisfied.
# 3.157544997551708e-16
# The Ignorability Assumption is not satisfied.
# 4.733775186051621e-15
# The Ignorability Assumption is not satisfied.
# 4.482258644756716e-16
# The Ignorability Assumption is not satisfied.
# 9.557723880366492e-13
# The Ignorability Assumption is not satisfied.
# 3.380801798241941e-20
# The Ignorability Assumption is not satisfied.
# 7.667485162189762e-18
# The Ignorability Assumption is not satisfied.
# 7.284823693852464e-21
# The Ignorability Assumption is not satisfied.
# 3.9577002706467e-23
# The Ignorability Assumption is not satisfied.
# 1.31871481899696e-14
# The Ignorability Assumption is not satisfied.
# 2.774492522753941e-16
# The Ignorability Assumption is not satisfied.
# 8.602953556872414e-21
# The Ignorability Assumption is not satisfied.
# 2.386970846074777e-21
# The Ignorability Assumption is not satisfied.
# 1.0392044861381575e-21
# The Ignorability Assumption is not satisfied.
# 9.827481583557834e-20
# The Ignorability Assumption is not satisfied.
# 2.02182932209931e-20
# The Ignorability Assumption is not satisfied.
# 3.2894204156846838e-24
# The Ignorability Assumption is not satisfied.
# 4.064418446807521e-21
# The Ignorability Assumption is not satisfied.
# 3.2467987893129875e-25
# The Ignorability Assumption is not satisfied.
# 1.8896002779213846e-17
# The Ignorability Assumption is not satisfied.
# 2.723894425016346e-15
# The Ignorability Assumption is not satisfied.
# 6.106013740264721e-16
# The Ignorability Assumption is not satisfied.
# 3.3328656913340304e-13
# The Ignorability Assumption is not satisfied.
# 1.1764720635880472e-22
# The Ignorability Assumption is not satisfied.
# 1.0699026860602764e-17
# The Ignorability Assumption is not satisfied.
# 7.556928044344419e-15
# The Ignorability Assumption is not satisfied.
# 2.7123340635111893e-17
# The Ignorability Assumption is not satisfied.
# 1.9458984145922777e-13
# The Ignorability Assumption is not satisfied.
# 4.27002271403643e-18
# The Ignorability Assumption is not satisfied.
# 6.756144169102862e-15
# The Ignorability Assumption is not satisfied.
# 6.177925656857462e-26
# The Ignorability Assumption is not satisfied.
# 1.629646103435917e-17
# The Ignorability Assumption is not satisfied.
# 1.3712930300789248e-20
# The Ignorability Assumption is not satisfied.
# 1.0976447227578112e-18
# The Ignorability Assumption is not satisfied.
# 2.9122810091663187e-16
# The Ignorability Assumption is not satisfied.
# 1.1646944879424923e-23
# The Ignorability Assumption is not satisfied.
# 7.3867801433885005e-22
# The Ignorability Assumption is not satisfied.
# 3.605402309600965e-26
# The Ignorability Assumption is not satisfied.
# 1.4781064224384155e-26
# The Ignorability Assumption is not satisfied.
# 2.2101038514728196e-27
# The Ignorability Assumption is not satisfied.
# 2.929761191494695e-17
# The Ignorability Assumption is not satisfied.
# 5.377930617730197e-24
# The Ignorability Assumption is not satisfied.
# 7.369059072768707e-25
# The Ignorability Assumption is not satisfied.
# 9.866426829804465e-19
# The Ignorability Assumption is not satisfied.
# 2.5612662941567424e-21
# The Ignorability Assumption is not satisfied.
# 6.365464989215725e-23
# The Ignorability Assumption is not satisfied.
# 1.1737555302730176e-14
# The Ignorability Assumption is not satisfied.
# 3.5404145207269995e-14
# The Ignorability Assumption is not satisfied.
# 5.269434763022908e-19
# The Ignorability Assumption is not satisfied.
# 1.3024921921609353e-21
# The Ignorability Assumption is not satisfied.
# 2.8421840570556812e-15
# The Ignorability Assumption is not satisfied.
# 2.7080371770081534e-18
# The Ignorability Assumption is not satisfied.
# 5.235384549160269e-31
# The Ignorability Assumption is not satisfied.
# 1.1071639166518302e-19
# The Ignorability Assumption is not satisfied.
# 8.958129713864272e-26
# The Ignorability Assumption is not satisfied.
# 3.051762659186652e-17
# The Ignorability Assumption is not satisfied.
# 4.318271013019592e-20
# The Ignorability Assumption is not satisfied.
# 3.6485266929982275e-14
# The Ignorability Assumption is not satisfied.
# 3.201894191971395e-13
# The Ignorability Assumption is not satisfied.
# 1.23065588969922e-22
# The Ignorability Assumption is not satisfied.
# 2.1525137048180832e-15
# The Ignorability Assumption is not satisfied.
# 7.617587607592802e-21
# The Ignorability Assumption is not satisfied.
# 8.369655407973354e-17
# The Ignorability Assumption is not satisfied.
# 5.525130754014293e-23
# The Ignorability Assumption is not satisfied.
# 4.490919856649598e-19
# The Ignorability Assumption is not satisfied.
# 5.6474278470745946e-24
# The Ignorability Assumption is not satisfied.
# 7.130076621575086e-18
# The Ignorability Assumption is not satisfied.
# 5.036638578687223e-15
# The Ignorability Assumption is not satisfied.
# 7.464305080698442e-22
# The Ignorability Assumption is not satisfied.
# 1.8883191630681157e-16
# The Ignorability Assumption is not satisfied.
# 1.0188893078439502e-22
# The Ignorability Assumption is not satisfied.
# 6.67136970370135e-17
# The Ignorability Assumption is not satisfied.
# 8.348802195248954e-18
# The Ignorability Assumption is not satisfied.
# 2.0414745861544888e-24
# The Ignorability Assumption is not satisfied.
# 4.201360816258469e-17
# The Ignorability Assumption is not satisfied.
# 8.698358900277145e-18
# The Ignorability Assumption is not satisfied.
# 7.956269827788961e-18
# The Ignorability Assumption is not satisfied.
# 9.797604597992667e-25
# The Ignorability Assumption is not satisfied.
# 5.1141722536301e-27
# The Ignorability Assumption is not satisfied.
# 3.575367043381194e-18
# The Ignorability Assumption is not satisfied.
# 6.185039378066033e-25
# The Ignorability Assumption is not satisfied.
# 1.320655550397674e-14
# The Ignorability Assumption is not satisfied.
# 1.1385858529130717e-25
# The Ignorability Assumption is not satisfied.
# 6.038453992527537e-15
# The Ignorability Assumption is not satisfied.
# 3.796223357557011e-18
# The Ignorability Assumption is not satisfied.
# 7.289740627559111e-23
# The Ignorability Assumption is not satisfied.
# 3.946480049121456e-19
# The Ignorability Assumption is not satisfied.
# 4.939177450655954e-16
# The Ignorability Assumption is not satisfied.
# 3.0835737915988837e-21
# The Ignorability Assumption is not satisfied.
# 1.1504429123900034e-17
# The Ignorability Assumption is not satisfied.
# 2.2102108398787404e-22
# The Ignorability Assumption is not satisfied.
# 6.557275389170405e-17
# The Ignorability Assumption is not satisfied.
# 3.2147736792763126e-19
# The Ignorability Assumption is not satisfied.
# 1.7614819208758847e-18
# The Ignorability Assumption is not satisfied.
# 6.113740884122143e-16
# The Ignorability Assumption is not satisfied.
# 2.348101694654869e-19
# The Ignorability Assumption is not satisfied.
# 2.0034918093825537e-17
# The Ignorability Assumption is not satisfied.
# 1.64011406584124e-17
# The Ignorability Assumption is not satisfied.
# 6.102684599990747e-23
# The Ignorability Assumption is not satisfied.
# 1.383793633376291e-18
# The Ignorability Assumption is not satisfied.
# 1.297437617136747e-14
# The Ignorability Assumption is not satisfied.
# 4.781436818905239e-25
# The Ignorability Assumption is not satisfied.
# 6.558031939674888e-18
# The Ignorability Assumption is not satisfied.
# 8.648616108767659e-17
# The Ignorability Assumption is not satisfied.
# 1.7110471883658783e-22
# The Ignorability Assumption is not satisfied.
# 2.9813903781423065e-19
# The Ignorability Assumption is not satisfied.
# 3.1837554904010056e-22
# The Ignorability Assumption is not satisfied.
# 3.225066134867543e-20
# The Ignorability Assumption is not satisfied.
# 1.2809802302892799e-21
# The Ignorability Assumption is not satisfied.
# 1.0003389054467999e-21
# The Ignorability Assumption is not satisfied.
# 2.0095519820354393e-22
# The Ignorability Assumption is not satisfied.
# 1.24628851680171e-14
# The Ignorability Assumption is not satisfied.
# 4.830729579289026e-16
# The Ignorability Assumption is not satisfied.
# 1.3374568097066232e-19
# The Ignorability Assumption is not satisfied.
# 3.4303881842090697e-13
# The Ignorability Assumption is not satisfied.
# 2.4505268397909797e-19
# The Ignorability Assumption is not satisfied.
# 6.871399725063963e-16
# The Ignorability Assumption is not satisfied.
# 8.638820431795558e-18
# The Ignorability Assumption is not satisfied.
# 1.0537784020009166e-23
# The Ignorability Assumption is not satisfied.
# 1.6838271710431271e-22
# The Ignorability Assumption is not satisfied.
# 2.3860756530096332e-14
# The Ignorability Assumption is not satisfied.
# 8.026413075569673e-20
# The Ignorability Assumption is not satisfied.
# 7.957048538972986e-22
# The Ignorability Assumption is not satisfied.
# 2.4894476833272886e-19
# The Ignorability Assumption is not satisfied.
# 1.7928062158466565e-16
# The Ignorability Assumption is not satisfied.
# 7.319265726876878e-15
# The Ignorability Assumption is not satisfied.
# 6.803249578515076e-17
# The Ignorability Assumption is not satisfied.
# 1.652727652952413e-19
# The Ignorability Assumption is not satisfied.
# 1.6402463058436765e-16
# The Ignorability Assumption is not satisfied.
# 5.340863645318897e-24
# The Ignorability Assumption is not satisfied.
# 4.6677166579956e-18
# The Ignorability Assumption is not satisfied.
# 1.7370513742026883e-19
# The Ignorability Assumption is not satisfied.
# 1.5362943238212422e-18
# The Ignorability Assumption is not satisfied.
# 2.690737145416189e-18
# The Ignorability Assumption is not satisfied.
# 1.6721095874034757e-19
# The Ignorability Assumption is not satisfied.
# 5.698687434682683e-17
# The Ignorability Assumption is not satisfied.
# 6.151482099494804e-16
# The Ignorability Assumption is not satisfied.
# 6.341645768983943e-29
# The Ignorability Assumption is not satisfied.
# 2.2924110222314094e-21
# The Ignorability Assumption is not satisfied.
# 1.850130120466692e-16
# The Ignorability Assumption is not satisfied.
# 8.487945856226097e-31
# The Ignorability Assumption is not satisfied.
# 2.6234820518302964e-18
# The Ignorability Assumption is not satisfied.
# 1.3971308204283347e-24
# The Ignorability Assumption is not satisfied.
# 5.1796627054312865e-20
# The Ignorability Assumption is not satisfied.
# 5.799257015587856e-26
# The Ignorability Assumption is not satisfied.
# 1.352463453832227e-16
# The Ignorability Assumption is not satisfied.
# 8.113301534576527e-18
# The Ignorability Assumption is not satisfied.
# 4.06064097818069e-15
# The Ignorability Assumption is not satisfied.
# 5.305601549008788e-23
# The Ignorability Assumption is not satisfied.
# 3.7907378941273936e-20
# The Ignorability Assumption is not satisfied.
# 2.874926304242659e-19
# The Ignorability Assumption is not satisfied.
# 6.255071762042199e-24
# The Ignorability Assumption is not satisfied.
# 6.073093416928678e-19
# The Ignorability Assumption is not satisfied.
# 1.0776080495121827e-21
# The Ignorability Assumption is not satisfied.
# 9.813113240188833e-21
# The Ignorability Assumption is not satisfied.
# 1.0776900485962624e-13
# The Ignorability Assumption is not satisfied.
# 4.088313057445018e-19
# The Ignorability Assumption is not satisfied.
# 2.7717380591979223e-24
# The Ignorability Assumption is not satisfied.
# 1.7811738019191067e-21
# The Ignorability Assumption is not satisfied.
# 1.458468344782045e-19
# The Ignorability Assumption is not satisfied.
# 2.78957721319283e-17
# The Ignorability Assumption is not satisfied.
# 7.932059776714573e-24
# The Ignorability Assumption is not satisfied.
# 2.387768774339857e-20
# The Ignorability Assumption is not satisfied.
# 1.3794849950390173e-18
# The Ignorability Assumption is not satisfied.
# 1.7510051280213983e-17
# The Ignorability Assumption is not satisfied.
# 2.3736057644434856e-22
# The Ignorability Assumption is not satisfied.
# 2.3940224375156915e-26
# The Ignorability Assumption is not satisfied.
# 1.0510246216169684e-21
# The Ignorability Assumption is not satisfied.
# 4.980273560582593e-19
# The Ignorability Assumption is not satisfied.
# 1.0354175116806085e-21
# The Ignorability Assumption is not satisfied.
# 7.274110396325123e-18
# The Ignorability Assumption is not satisfied.
# 5.882344627244975e-18
# The Ignorability Assumption is not satisfied.
# 4.251681500775827e-21
# The Ignorability Assumption is not satisfied.
# 3.442375287992285e-19
# The Ignorability Assumption is not satisfied.
# 2.797229783751153e-28
# The Ignorability Assumption is not satisfied.
# 6.06715519181078e-23
# The Ignorability Assumption is not satisfied.
# 1.5462049814950657e-14
# The Ignorability Assumption is not satisfied.
# 5.454749183996598e-30
# The Ignorability Assumption is not satisfied.
# 9.51045399577419e-16
# The Ignorability Assumption is not satisfied.
# 5.068161675370102e-14
# The Ignorability Assumption is not satisfied.
# 6.844501127400409e-14
# The Ignorability Assumption is not satisfied.
# 6.377946324441578e-22
# The Ignorability Assumption is not satisfied.
# 5.643026751884486e-17
# The Ignorability Assumption is not satisfied.
# 1.8858712302248826e-20
# The Ignorability Assumption is not satisfied.
# 5.032986308704854e-24
# The Ignorability Assumption is not satisfied.
# 7.196417049588445e-22
# The Ignorability Assumption is not satisfied.
# 4.0693322497825915e-19
# The Ignorability Assumption is not satisfied.
# 4.894451826769144e-17
# The Ignorability Assumption is not satisfied.
# 6.17918516121771e-23
# The Ignorability Assumption is not satisfied.
# 1.7473202234605437e-16
# The Ignorability Assumption is not satisfied.
# 6.350723804054718e-21
# The Ignorability Assumption is not satisfied.
# 2.5906037259670267e-18
# The Ignorability Assumption is not satisfied.
# 1.4942084078814933e-14
# The Ignorability Assumption is not satisfied.
# 6.4648218964629635e-18
# The Ignorability Assumption is not satisfied.
# 4.020159667877687e-16
# The Ignorability Assumption is not satisfied.
# 2.2376053039213485e-18
# The Ignorability Assumption is not satisfied.
# 5.424733959061587e-18
# The Ignorability Assumption is not satisfied.
# 1.0393698460677118e-23
# The Ignorability Assumption is not satisfied.
# 1.9981145275727394e-18
# The Ignorability Assumption is not satisfied.
# 1.0293493946252522e-23
# The Ignorability Assumption is not satisfied.
# 2.2024282388021497e-17
# The Ignorability Assumption is not satisfied.
# 2.0568253955275463e-17
# The Ignorability Assumption is not satisfied.
# 5.398445896554078e-19
# The Ignorability Assumption is not satisfied.
# 1.7269157330234388e-22
# The Ignorability Assumption is not satisfied.
# 3.754330747497921e-24
# The Ignorability Assumption is not satisfied.
# 3.3134285442500196e-21
# The Ignorability Assumption is not satisfied.
# 3.060585011788166e-19
# The Ignorability Assumption is not satisfied.
# 6.606291810026591e-20
# The Ignorability Assumption is not satisfied.
# 2.3059883301888165e-31
# The Ignorability Assumption is not satisfied.
# 3.0138761545664345e-25
# The Ignorability Assumption is not satisfied.
# 1.290290552366918e-21
# The Ignorability Assumption is not satisfied.
# 1.0667003306661473e-14
# The Ignorability Assumption is not satisfied.
# 3.7239087446791875e-20
# The Ignorability Assumption is not satisfied.
# 1.9308728689436858e-21
# The Ignorability Assumption is not satisfied.
# 4.457988988713896e-20
# The Ignorability Assumption is not satisfied.
# 8.052628465046748e-21
# The Ignorability Assumption is not satisfied.
# 2.4154787764769077e-24
# The Ignorability Assumption is not satisfied.
# 3.6834390189438436e-23
# The Ignorability Assumption is not satisfied.
# 1.409637038462207e-17
# The Ignorability Assumption is not satisfied.
# 1.2309277403325551e-20
# The Ignorability Assumption is not satisfied.
# 1.1049130358749596e-22
# The Ignorability Assumption is not satisfied.
# 1.3227301384438437e-26
# The Ignorability Assumption is not satisfied.
# 2.2024548022672284e-22
# The Ignorability Assumption is not satisfied.
# 1.0494532408220399e-21
# The Ignorability Assumption is not satisfied.
# 4.7605648699094607e-20
# The Ignorability Assumption is not satisfied.
# 6.181047045621613e-19
# The Ignorability Assumption is not satisfied.
# 2.8282025306183974e-23
# The Ignorability Assumption is not satisfied.
# 3.6269431977413346e-20
# The Ignorability Assumption is not satisfied.
# 3.53924499028085e-23
# The Ignorability Assumption is not satisfied.
# 2.231050181283537e-15
# The Ignorability Assumption is not satisfied.
# 1.9764243477688334e-21
# The Ignorability Assumption is not satisfied.
# 1.4644520010760182e-17
# The Ignorability Assumption is not satisfied.
# 9.515203702873424e-20
# The Ignorability Assumption is not satisfied.
# 2.3203405801003554e-21
# The Ignorability Assumption is not satisfied.
# 8.955808953191974e-22
# The Ignorability Assumption is not satisfied.
# 8.578966331915376e-19
# The Ignorability Assumption is not satisfied.
# 1.5643088391363224e-22
# The Ignorability Assumption is not satisfied.
# 2.1274578671147702e-27
# The Ignorability Assumption is not satisfied.
# 1.7571637302316528e-18
# The Ignorability Assumption is not satisfied.
# 1.6707236292450273e-19
# The Ignorability Assumption is not satisfied.
# 3.5764223535247017e-16
# The Ignorability Assumption is not satisfied.
# 2.0278076886013395e-19
# The Ignorability Assumption is not satisfied.
# 2.151952325740237e-15
# The Ignorability Assumption is not satisfied.
# 1.2559768196514387e-18
# The Ignorability Assumption is not satisfied.
# 1.2237266024605552e-17
# The Ignorability Assumption is not satisfied.
# 1.5409624202182882e-21
# The Ignorability Assumption is not satisfied.
# 9.23919132000051e-14
# The Ignorability Assumption is not satisfied.
# 4.664321006678045e-18
# The Ignorability Assumption is not satisfied.
# 4.2118944951892184e-20
# The Ignorability Assumption is not satisfied.
# 1.092039259643124e-20
# The Ignorability Assumption is not satisfied.
# 2.015226874033263e-26
# The Ignorability Assumption is not satisfied.
# 9.341974479753906e-18
# The Ignorability Assumption is not satisfied.
# 4.8395479374820224e-24
# The Ignorability Assumption is not satisfied.
# 1.3319582856424564e-26
# The Ignorability Assumption is not satisfied.
# 4.439636493138798e-15
# The Ignorability Assumption is not satisfied.
# 4.1631705506767103e-22
# The Ignorability Assumption is not satisfied.
# 3.293566003080779e-26
# The Ignorability Assumption is not satisfied.
# 5.934476143163569e-18
# The Ignorability Assumption is not satisfied.
# 1.2558365531548622e-23
# The Ignorability Assumption is not satisfied.
# 5.6240360805275385e-22
# The Ignorability Assumption is not satisfied.
# 1.0003779824697428e-19
# The Ignorability Assumption is not satisfied.
# 3.70386902125045e-16
# The Ignorability Assumption is not satisfied.
# 4.130056943209675e-23
# The Ignorability Assumption is not satisfied.
# 3.1591709883401097e-18
# The Ignorability Assumption is not satisfied.
# 2.509022107866023e-24
# The Ignorability Assumption is not satisfied.
# 7.627004526696994e-21
# The Ignorability Assumption is not satisfied.
# 2.6457632546661143e-15
# The Ignorability Assumption is not satisfied.
# 7.695744528105099e-25
# The Ignorability Assumption is not satisfied.
# 8.361137806561723e-15
# The Ignorability Assumption is not satisfied.
# 5.955298151943085e-21
# The Ignorability Assumption is not satisfied.
# 1.1191959816312857e-20
# The Ignorability Assumption is not satisfied.
# 3.2800214707853707e-19
# The Ignorability Assumption is not satisfied.
# ...
# 1.065408978043695e-18
# The Ignorability Assumption is not satisfied.
# 8.648199295752656e-30
# The Ignorability Assumption is not satisfied.
# 8.824647642793376e-20
# The Ignorability Assumption is not satisfied.
# 3.391074983087476e-18
# The Ignorability Assumption is not satisfied.
# 5.323135461634477e-16
# The Ignorability Assumption is not satisfied.
# 7.723928542705577e-28
# The Ignorability Assumption is not satisfied.
# 4.045273696644868e-24
# The Ignorability Assumption is not satisfied.
# 2.478707576203172e-16
# The Ignorability Assumption is not satisfied.
# 2.508165156440739e-21
# The Ignorability Assumption is not satisfied.
# 3.58293636182382e-24
# The Ignorability Assumption is not satisfied.
# 6.41956206076735e-25
# The Ignorability Assumption is not satisfied.
# 1.6556596460969351e-22
# The Ignorability Assumption is not satisfied.
# 1.8314155054235972e-20
# The Ignorability Assumption is not satisfied.
# 7.140388767009966e-20
# The Ignorability Assumption is not satisfied.
# 1.9438160412997426e-15
# The Ignorability Assumption is not satisfied.
# 1.2247771922079944e-14
# The Ignorability Assumption is not satisfied.
# 1.8284856081903486e-22
# The Ignorability Assumption is not satisfied.
# 6.643069255372912e-16
# The Ignorability Assumption is not satisfied.
# 3.0631322782942666e-23
# The Ignorability Assumption is not satisfied.
# 4.368560279366756e-19
# The Ignorability Assumption is not satisfied.
# 1.3969296090961044e-20
# The Ignorability Assumption is not satisfied.
# 2.845476767887415e-20
# The Ignorability Assumption is not satisfied.
# 3.133537728592175e-17
# The Ignorability Assumption is not satisfied.
# 1.1223898720969391e-12
# The Ignorability Assumption is not satisfied.
# 2.040679814133e-18
# The Ignorability Assumption is not satisfied.
# 1.9657611439837627e-17
# The Ignorability Assumption is not satisfied.
# 1.3458786480143472e-18
# The Ignorability Assumption is not satisfied.
# 1.6844510571731625e-16
# The Ignorability Assumption is not satisfied.
# 3.4152331711471965e-22
# The Ignorability Assumption is not satisfied.
# 3.628706826509451e-20
# The Ignorability Assumption is not satisfied.
# 9.353555906538798e-21
# The Ignorability Assumption is not satisfied.
# 1.1732275265954728e-30
# The Ignorability Assumption is not satisfied.
# 2.365018968790702e-16
# The Ignorability Assumption is not satisfied.
# 6.421191424955864e-20
# The Ignorability Assumption is not satisfied.
# 2.075013956693228e-19
# The Ignorability Assumption is not satisfied.
# 7.66648931429909e-17
# The Ignorability Assumption is not satisfied.
# 4.61368746934934e-19
# The Ignorability Assumption is not satisfied.
# 1.3825895418720332e-21
# The Ignorability Assumption is not satisfied.
# 1.54913889540004e-17
# The Ignorability Assumption is not satisfied.
# 1.79924980653788e-15
# The Ignorability Assumption is not satisfied.
# 4.0921158581830694e-15
# The Ignorability Assumption is not satisfied.
# 1.7230669998623448e-13
# The Ignorability Assumption is not satisfied.
# 1.5265457939559022e-16
# The Ignorability Assumption is not satisfied.
# 5.228533980354919e-16
# The Ignorability Assumption is not satisfied.
# 1.0926530545405958e-21
# The Ignorability Assumption is not satisfied.
# 1.400752185710318e-22
# The Ignorability Assumption is not satisfied.
# 7.27935607697213e-16
# The Ignorability Assumption is not satisfied.
# 1.6267712984188045e-24
# The Ignorability Assumption is not satisfied.
# 2.817499824245386e-21
# The Ignorability Assumption is not satisfied.
# 1.2600835727548184e-21
# The Ignorability Assumption is not satisfied.
# 1.2526779901753548e-26
# The Ignorability Assumption is not satisfied.
# 4.678164602806311e-19
# The Ignorability Assumption is not satisfied.
# 4.735289656016431e-24
# The Ignorability Assumption is not satisfied.
# 5.57299108621444e-16
# The Ignorability Assumption is not satisfied.
# 4.118034023303947e-22
# The Ignorability Assumption is not satisfied.
# 4.357207343626326e-26
# The Ignorability Assumption is not satisfied.
# 1.0810626477724434e-31
# The Ignorability Assumption is not satisfied.
# 1.005533751294677e-21
# The Ignorability Assumption is not satisfied.
# 1.852287269595693e-15
# The Ignorability Assumption is not satisfied.
# 4.696507654335135e-25
# The Ignorability Assumption is not satisfied.
# 3.7104718958579337e-19
# The Ignorability Assumption is not satisfied.
# 1.6522116912681107e-21
# The Ignorability Assumption is not satisfied.
# 8.832119146442669e-15
# The Ignorability Assumption is not satisfied.
# 4.966115871036443e-18
# The Ignorability Assumption is not satisfied.
# 9.748118565238231e-21
# The Ignorability Assumption is not satisfied.
# 4.2611358907681905e-18
# The Ignorability Assumption is not satisfied.
# 2.3042504684762184e-15
# The Ignorability Assumption is not satisfied.
# 9.719505440462547e-18
# The Ignorability Assumption is not satisfied.
# 6.661307825729503e-18
# The Ignorability Assumption is not satisfied.
# 1.1544824387819353e-22
# The Ignorability Assumption is not satisfied.
# 2.7424752936246385e-26
# The Ignorability Assumption is not satisfied.
# 1.3005563932829562e-21
# The Ignorability Assumption is not satisfied.
# 1.1402451167699128e-21
# The Ignorability Assumption is not satisfied.
# 1.896034489655866e-20
# The Ignorability Assumption is not satisfied.
# 8.937462583755838e-15
# The Ignorability Assumption is not satisfied.
# 2.6420938168138954e-20
# The Ignorability Assumption is not satisfied.
# 1.7758931162975858e-18
# The Ignorability Assumption is not satisfied.
# 2.879422603370144e-23
# The Ignorability Assumption is not satisfied.
# 2.2008712865361454e-18
# The Ignorability Assumption is not satisfied.
# 5.899276184157705e-19
# The Ignorability Assumption is not satisfied.
# 4.46715643009141e-12
# The Ignorability Assumption is not satisfied.
# 4.3921192449929294e-27
# The Ignorability Assumption is not satisfied.
# 1.2712461773114645e-20
# The Ignorability Assumption is not satisfied.
# 4.2869510363644155e-13
# The Ignorability Assumption is not satisfied.
# 1.7102354830747297e-20
# The Ignorability Assumption is not satisfied.
# 2.246038543645954e-26
# The Ignorability Assumption is not satisfied.
# 1.5506418968612475e-21
# The Ignorability Assumption is not satisfied.
# 5.353023063297254e-22
# The Ignorability Assumption is not satisfied.
# 7.354051835423564e-21
# The Ignorability Assumption is not satisfied.
# 1.0208391900995774e-24
# The Ignorability Assumption is not satisfied.
# 5.42992181372647e-19
# The Ignorability Assumption is not satisfied.
# 4.599139834550567e-16
# The Ignorability Assumption is not satisfied.
# 7.817547329547546e-16
# The Ignorability Assumption is not satisfied.
# 4.565106506510959e-25
# The Ignorability Assumption is not satisfied.
# 1.0712789229529948e-15
# The Ignorability Assumption is not satisfied.
# 9.423362932426637e-11
# The Ignorability Assumption is not satisfied.
# 1.3924741836639567e-17
# The Ignorability Assumption is not satisfied.
# 6.629958968342183e-25
# The Ignorability Assumption is not satisfied.
# 5.927309135296927e-10
# The Ignorability Assumption is not satisfied.
# 9.719216523561709e-16
# The Ignorability Assumption is not satisfied.
# 4.460245803056523e-15
# The Ignorability Assumption is not satisfied.
# 3.832972507196419e-17
# The Ignorability Assumption is not satisfied.
# 3.196459460809983e-23
# The Ignorability Assumption is not satisfied.
# 6.816181829211606e-23
# The Ignorability Assumption is not satisfied.
# 4.108775627022777e-22
# The Ignorability Assumption is not satisfied.
# 8.232654425473495e-24
# The Ignorability Assumption is not satisfied.
# 1.1441192082758479e-33
# The Ignorability Assumption is not satisfied.
# 1.402735803991817e-21
# The Ignorability Assumption is not satisfied.
# 3.0979235706417094e-27
# The Ignorability Assumption is not satisfied.
# 1.0267806946490765e-18
# The Ignorability Assumption is not satisfied.
# 5.006606906164625e-23
# The Ignorability Assumption is not satisfied.
# 2.1290910550528505e-20
# The Ignorability Assumption is not satisfied.
# 4.5743596939102725e-20
# The Ignorability Assumption is not satisfied.
# 3.0996882986967577e-17
# The Ignorability Assumption is not satisfied.
# 8.476909345954216e-19
# The Ignorability Assumption is not satisfied.
# 3.003629775769541e-17
# The Ignorability Assumption is not satisfied.
# 1.4134647734257096e-18
# The Ignorability Assumption is not satisfied.
# 5.90048876100123e-18
# The Ignorability Assumption is not satisfied.
# 1.0922866712741535e-22
# The Ignorability Assumption is not satisfied.
# 7.111238541187169e-16
# The Ignorability Assumption is not satisfied.
# 1.6108091218194276e-22
# The Ignorability Assumption is not satisfied.
# 9.879678108218725e-22
# The Ignorability Assumption is not satisfied.
# 4.6400955997013976e-20
# The Ignorability Assumption is not satisfied.
# 6.802533242452576e-18
# The Ignorability Assumption is not satisfied.
# 8.536884140713696e-21
# The Ignorability Assumption is not satisfied.
# 1.2470177525660716e-28
# The Ignorability Assumption is not satisfied.
# 4.532462099594373e-26
# The Ignorability Assumption is not satisfied.
# 3.1129186072370886e-18
# The Ignorability Assumption is not satisfied.
# 9.228657371405873e-23
# The Ignorability Assumption is not satisfied.
# 2.0558180036693008e-17
# The Ignorability Assumption is not satisfied.
# 1.3523765647819662e-14
# The Ignorability Assumption is not satisfied.
# 3.1763843411778015e-17
# The Ignorability Assumption is not satisfied.
# 1.682036211372982e-17
# The Ignorability Assumption is not satisfied.
# 7.876440817147728e-20
# The Ignorability Assumption is not satisfied.
# 3.1906959011107646e-18
# The Ignorability Assumption is not satisfied.
# 1.909680368288643e-22
# The Ignorability Assumption is not satisfied.
# 1.615104549626131e-17
# The Ignorability Assumption is not satisfied.
# 3.477633095436114e-17
# The Ignorability Assumption is not satisfied.
# 6.329156225735432e-18
# The Ignorability Assumption is not satisfied.
# 3.7115852372103216e-16
# The Ignorability Assumption is not satisfied.
# 5.439611840525416e-21
# The Ignorability Assumption is not satisfied.
# 1.2249886285961669e-24
# The Ignorability Assumption is not satisfied.
# 4.484382460939656e-18
# The Ignorability Assumption is not satisfied.
# 6.475936085759021e-27
# The Ignorability Assumption is not satisfied.
# 7.76226204074985e-17
# The Ignorability Assumption is not satisfied.
# 6.05847047846104e-17
# The Ignorability Assumption is not satisfied.
# 1.4229124299365397e-21
# The Ignorability Assumption is not satisfied.
# 1.9323375266375503e-23
# The Ignorability Assumption is not satisfied.
# 5.588415963581212e-26
# The Ignorability Assumption is not satisfied.
# 1.4211796777658703e-22
# The Ignorability Assumption is not satisfied.
# 2.915302764333724e-20
# The Ignorability Assumption is not satisfied.
# 8.468352146742024e-24
# The Ignorability Assumption is not satisfied.
# 9.049181431452672e-14
# The Ignorability Assumption is not satisfied.
# 9.50436263126804e-21
# The Ignorability Assumption is not satisfied.
# 7.349998941442439e-26
# The Ignorability Assumption is not satisfied.
# 3.9759744565725218e-22
# The Ignorability Assumption is not satisfied.
# 8.529424684532995e-16
# The Ignorability Assumption is not satisfied.
# 4.408344316659671e-11
# The Ignorability Assumption is not satisfied.
# 2.1909286713157163e-19
# The Ignorability Assumption is not satisfied.
# 5.127838534546563e-25
# The Ignorability Assumption is not satisfied.
# 2.1938799561787877e-17
# The Ignorability Assumption is not satisfied.
# 1.3682734924302327e-17
# The Ignorability Assumption is not satisfied.
# 1.9069752363332888e-16
# The Ignorability Assumption is not satisfied.
# 1.80046306894989e-14
# The Ignorability Assumption is not satisfied.
# 1.3721246669229212e-25
# The Ignorability Assumption is not satisfied.
# 7.691568340688892e-26
# The Ignorability Assumption is not satisfied.
# 6.611089468206421e-21
# The Ignorability Assumption is not satisfied.
# 4.252505712059245e-30
# The Ignorability Assumption is not satisfied.
# 4.616975634651142e-15
# The Ignorability Assumption is not satisfied.
# 2.255396173653404e-24
# The Ignorability Assumption is not satisfied.
# 2.302962124131747e-22
# The Ignorability Assumption is not satisfied.
# 1.2688221479908623e-19
# The Ignorability Assumption is not satisfied.
# 4.003397850914535e-18
# The Ignorability Assumption is not satisfied.
# 3.5951059674075746e-16
# The Ignorability Assumption is not satisfied.
# 3.389124667761895e-19
# The Ignorability Assumption is not satisfied.
# 2.341098541874838e-28
# The Ignorability Assumption is not satisfied.
# 1.3156597767238288e-14
# The Ignorability Assumption is not satisfied.
# 3.8113695589606867e-17
# The Ignorability Assumption is not satisfied.
# 1.3630771255033796e-16
# The Ignorability Assumption is not satisfied.
# 1.2406708594501747e-12
# The Ignorability Assumption is not satisfied.
# 1.12934261033968e-17
# The Ignorability Assumption is not satisfied.
# 5.940407288535342e-20
# The Ignorability Assumption is not satisfied.
# 3.2304783464597333e-13
# The Ignorability Assumption is not satisfied.
# 4.3224923054242835e-18
# The Ignorability Assumption is not satisfied.
# 3.687158104960413e-11
# The Ignorability Assumption is not satisfied.
# 6.633982244951009e-12
# The Ignorability Assumption is not satisfied.
# 3.016969008024698e-15
# The Ignorability Assumption is not satisfied.
# 1.914945477147984e-17
# The Ignorability Assumption is not satisfied.
# 9.192751282888961e-17
# The Ignorability Assumption is not satisfied.
# 4.200296232224936e-17
# The Ignorability Assumption is not satisfied.
# 2.0685047903335415e-17
# The Ignorability Assumption is not satisfied.
# 1.010222559663558e-25
# The Ignorability Assumption is not satisfied.
# 3.73922761719385e-20
# The Ignorability Assumption is not satisfied.
# 2.5736031870219695e-16
# The Ignorability Assumption is not satisfied.
# 2.0943252598747507e-16
# The Ignorability Assumption is not satisfied.
# 2.392273087792063e-19
# The Ignorability Assumption is not satisfied.
# 4.906869633407221e-19
# The Ignorability Assumption is not satisfied.
# 1.5901236659185392e-16
# The Ignorability Assumption is not satisfied.
# 1.289560960614528e-19
# The Ignorability Assumption is not satisfied.
# 9.526232986085475e-21
# The Ignorability Assumption is not satisfied.
# 6.06530344001095e-22
# The Ignorability Assumption is not satisfied.
# 3.6574116488908595e-16
# The Ignorability Assumption is not satisfied.
# 1.3720854305489094e-19
# The Ignorability Assumption is not satisfied.
# 1.577118862118646e-17
# The Ignorability Assumption is not satisfied.
# 1.5810219043252173e-20
# The Ignorability Assumption is not satisfied.
# 8.677461392794105e-19
# The Ignorability Assumption is not satisfied.
# 3.7351032454269583e-19
# The Ignorability Assumption is not satisfied.
# 1.3803517910191863e-20
# The Ignorability Assumption is not satisfied.
# 2.2082501245293635e-15
# The Ignorability Assumption is not satisfied.
# 2.1485175292617497e-19
# The Ignorability Assumption is not satisfied.
# 3.543888863675508e-18
# The Ignorability Assumption is not satisfied.
# 3.642520664408726e-20
# The Ignorability Assumption is not satisfied.
# 4.241102766325793e-20
# The Ignorability Assumption is not satisfied.
# 2.602845256665136e-23
# The Ignorability Assumption is not satisfied.
# 2.4220254965297786e-17
# The Ignorability Assumption is not satisfied.
# 3.015709813296007e-22
# The Ignorability Assumption is not satisfied.
# 1.6984120498515842e-15
# The Ignorability Assumption is not satisfied.
# 7.073843768177795e-22
# The Ignorability Assumption is not satisfied.
# 9.024623164197001e-20
# The Ignorability Assumption is not satisfied.
# 2.5848113294530945e-14
# The Ignorability Assumption is not satisfied.
# 3.655442748527813e-23
# The Ignorability Assumption is not satisfied.
# 9.257238967093325e-18
# The Ignorability Assumption is not satisfied.
# 1.8893938045402898e-16
# The Ignorability Assumption is not satisfied.
# 2.9918052934317216e-18
# The Ignorability Assumption is not satisfied.
# 4.017132649182103e-21
# The Ignorability Assumption is not satisfied.
# 1.5747095607578511e-28
# The Ignorability Assumption is not satisfied.
# 1.8090124567676124e-17
# The Ignorability Assumption is not satisfied.
# 5.562429814107703e-20
# The Ignorability Assumption is not satisfied.
# 1.0904108957329638e-16
# The Ignorability Assumption is not satisfied.
# 2.050704161133136e-18
# The Ignorability Assumption is not satisfied.
# 2.35843628364328e-23
# The Ignorability Assumption is not satisfied.
# 1.5859477141147062e-19
# The Ignorability Assumption is not satisfied.
# 1.933738584879651e-18
# The Ignorability Assumption is not satisfied.
# 5.99839250742243e-16
# The Ignorability Assumption is not satisfied.

# %%
COUNT4
# Out:
# 1000

# %% [markdown]
# ### Scenario 5

# %%
#실제 ATE 찾아지는 상황 (but, 실제 causal effect = 0) <1종 오류>

np.random.seed(1)

COUNT5 = 0
for i in range(1000):
    
    n = 1000 
    k0_co = 0.8
    k1_co = 1
    k0_at = 0.8
    k1_at = 1
    k0_nt = 0.8
    k1_nt = 1
    k0_de = 0.8
    k1_de = 1

    a0 = 0 #changeable
    a1 = 0

    X = np.random.binomial(1,0.5,size=n)

    mu_Z = 1/(1+np.exp(1-2*X))
    Z = np.random.binomial(1,mu_Z,size=n)

    p_at = np.exp(-2.5+3.5*X)/(1+np.exp(-2.5+3.5*X)+np.exp(-2.5+3.5*X))
    p_nt = np.exp(-2.5+3.5*X)/(1+np.exp(-2.5+3.5*X)+np.exp(-2.5+3.5*X))
    p_co = 0.75/(1+np.exp(-2.5+3.5*X)+np.exp(-2.5+3.5*X))
    p_de = 0.25/(1+np.exp(-2.5+3.5*X)+np.exp(-2.5+3.5*X))
    

    C=[]
    for j in range(n):
        C.append(np.random.choice(["co","at","nt","de"], size=1, replace=True, p=[p_at[j],p_nt[j],p_co[j],p_de[j]])[0])
    C=np.array(C)

    A = np.repeat(0,n)
    A[C=="at"] = 1
    A[(C=="co")*(Z==1)] = 1
    A[(C=="de")*(Z==0)] = 1

    Y = np.random.normal(0,1,n)
    for k in range(n):

        if C[k]=="co":
            mu_y = k0_co+k1_co*X[k]+(a0+a1*X[k])*A[k]
            Y[k] = np.random.normal(mu_y,1,1)[0]
        elif C[k] == "at":
            mu_y = k0_at+k1_at*X[k]
            Y[k] = np.random.normal(mu_y,1,1)[0]
        elif C[k] == "nt":
            mu_y = k0_nt+k1_nt*X[k]
            Y[k] = np.random.normal(mu_y,1,1)[0]
        else:
            mu_y = k0_de+k1_de*X[k]
            Y[k] = np.random.normal(mu_y,1,1)[0]
            
    #data = pd.DataFrame({"col1":Y,"col2":Z,"col3":A,"col4":C,"col5":X})
    #data.loc[data["col4"]=="nt","col4"] = 0 
    #data.loc[data["col4"]=="co","col4"] = 1
    #data.loc[data["col4"]=="at","col4"] = 2 
    
    pvalue = IgnorTest(cause=A, effect=Y, explorer=Z, covariate=X, level=0.05, dtype="mixed")
    if pvalue<=0.05:
        COUNT5 = COUNT5+1
# Out:
# 0.15045047478034115
# The Ignorability Assumption is satisfied.
# 0.12230630995226696
# The Ignorability Assumption is satisfied.
# 0.6842562217271986
# The Ignorability Assumption is satisfied.
# 0.3849341996125172
# The Ignorability Assumption is satisfied.
# 0.7864708419144251
# The Ignorability Assumption is satisfied.
# 0.19984731731957814
# The Ignorability Assumption is satisfied.
# 0.07640023285783452
# The Ignorability Assumption is satisfied.
# 0.3674828757835217
# The Ignorability Assumption is satisfied.
# 0.4212027919809933
# The Ignorability Assumption is satisfied.
# 0.617749348943258
# The Ignorability Assumption is satisfied.
# 0.8165009251419331
# The Ignorability Assumption is satisfied.
# 0.23396256733228243
# The Ignorability Assumption is satisfied.
# 0.3320562732491292
# The Ignorability Assumption is satisfied.
# 0.09430945095192358
# The Ignorability Assumption is satisfied.
# 0.3319392810555479
# The Ignorability Assumption is satisfied.
# 0.31477865589164505
# The Ignorability Assumption is satisfied.
# 0.4803066809038967
# The Ignorability Assumption is satisfied.
# 0.2683168296387709
# The Ignorability Assumption is satisfied.
# 0.3506438871284406
# The Ignorability Assumption is satisfied.
# 0.8501862743820742
# The Ignorability Assumption is satisfied.
# 0.4695501056778073
# The Ignorability Assumption is satisfied.
# 0.3697572903991418
# The Ignorability Assumption is satisfied.
# 0.6412868770376235
# The Ignorability Assumption is satisfied.
# 0.3168321180170977
# The Ignorability Assumption is satisfied.
# 0.978093288410426
# The Ignorability Assumption is satisfied.
# 0.24687378402229535
# The Ignorability Assumption is satisfied.
# 0.4170398586637083
# The Ignorability Assumption is satisfied.
# 0.2834378887589118
# The Ignorability Assumption is satisfied.
# 0.5703740353466151
# The Ignorability Assumption is satisfied.
# 0.29995287269137794
# The Ignorability Assumption is satisfied.
# 0.48216420651451686
# The Ignorability Assumption is satisfied.
# 0.5827855844218885
# The Ignorability Assumption is satisfied.
# 0.18455598111012006
# The Ignorability Assumption is satisfied.
# 0.8025692815598426
# The Ignorability Assumption is satisfied.
# 0.43095710282694955
# The Ignorability Assumption is satisfied.
# 0.8805965659953336
# The Ignorability Assumption is satisfied.
# 0.5667200162301003
# The Ignorability Assumption is satisfied.
# 0.11788119364244871
# The Ignorability Assumption is satisfied.
# 0.46359849540036735
# The Ignorability Assumption is satisfied.
# 0.527988324347162
# The Ignorability Assumption is satisfied.
# 0.0604941531539523
# The Ignorability Assumption is satisfied.
# 0.3402289968562114
# The Ignorability Assumption is satisfied.
# 0.9332706228746361
# The Ignorability Assumption is satisfied.
# 0.7070180863687767
# The Ignorability Assumption is satisfied.
# 0.4989002008608271
# The Ignorability Assumption is satisfied.
# 0.03284178325803358
# The Ignorability Assumption is not satisfied.
# 0.6253708116492248
# The Ignorability Assumption is satisfied.
# 0.07444497502484858
# The Ignorability Assumption is satisfied.
# 0.5169778082668417
# The Ignorability Assumption is satisfied.
# 0.21827090273854013
# The Ignorability Assumption is satisfied.
# 0.755493584872848
# The Ignorability Assumption is satisfied.
# 0.5495486037399403
# The Ignorability Assumption is satisfied.
# 0.03062921268590355
# The Ignorability Assumption is not satisfied.
# 0.2871774417558947
# The Ignorability Assumption is satisfied.
# 0.5340989329363288
# The Ignorability Assumption is satisfied.
# 0.7992526460526814
# The Ignorability Assumption is satisfied.
# 0.9757002112297163
# The Ignorability Assumption is satisfied.
# 0.9966992013418912
# The Ignorability Assumption is satisfied.
# 0.8351048738924628
# The Ignorability Assumption is satisfied.
# 0.6784129660940522
# The Ignorability Assumption is satisfied.
# 0.06703632963572187
# The Ignorability Assumption is satisfied.
# 0.035429112651762754
# The Ignorability Assumption is not satisfied.
# 0.20893475450470655
# The Ignorability Assumption is satisfied.
# 0.12628882642813605
# The Ignorability Assumption is satisfied.
# 0.6934687397080115
# The Ignorability Assumption is satisfied.
# 0.719138694320879
# The Ignorability Assumption is satisfied.
# 0.7542709223230906
# The Ignorability Assumption is satisfied.
# 0.1168241667829758
# The Ignorability Assumption is satisfied.
# 0.37030395341064337
# The Ignorability Assumption is satisfied.
# 0.10346640991488873
# The Ignorability Assumption is satisfied.
# 0.1342737809094763
# The Ignorability Assumption is satisfied.
# 0.7330196074478331
# The Ignorability Assumption is satisfied.
# 0.5819826394233494
# The Ignorability Assumption is satisfied.
# 0.26106899117365845
# The Ignorability Assumption is satisfied.
# 0.8398604883488434
# The Ignorability Assumption is satisfied.
# 0.3601647282084876
# The Ignorability Assumption is satisfied.
# 0.6939610785929531
# The Ignorability Assumption is satisfied.
# 0.5686627748576412
# The Ignorability Assumption is satisfied.
# 0.29394214613065034
# The Ignorability Assumption is satisfied.
# 0.051476451652315826
# The Ignorability Assumption is satisfied.
# 0.49316689113868284
# The Ignorability Assumption is satisfied.
# 0.23814529913597493
# The Ignorability Assumption is satisfied.
# 0.6673280837485653
# The Ignorability Assumption is satisfied.
# 0.2835454276856488
# The Ignorability Assumption is satisfied.
# 0.09405673460207951
# The Ignorability Assumption is satisfied.
# 0.19627618189582088
# The Ignorability Assumption is satisfied.
# 0.4321545212682344
# The Ignorability Assumption is satisfied.
# 0.23452830374143943
# The Ignorability Assumption is satisfied.
# 0.5553262936277635
# The Ignorability Assumption is satisfied.
# 0.12416862120758138
# The Ignorability Assumption is satisfied.
# 0.39406705423978755
# The Ignorability Assumption is satisfied.
# 0.07267197147410245
# The Ignorability Assumption is satisfied.
# 0.3050413078978533
# The Ignorability Assumption is satisfied.
# 0.14351471419542725
# The Ignorability Assumption is satisfied.
# 0.8615260722056464
# The Ignorability Assumption is satisfied.
# 0.2055402543720943
# The Ignorability Assumption is satisfied.
# 0.9484188290953651
# The Ignorability Assumption is satisfied.
# 0.0039216046790196725
# The Ignorability Assumption is not satisfied.
# 0.8772273937050217
# The Ignorability Assumption is satisfied.
# 0.7859729819474978
# The Ignorability Assumption is satisfied.
# 0.6862040157009722
# The Ignorability Assumption is satisfied.
# 0.299289383448212
# The Ignorability Assumption is satisfied.
# 0.6867188159497732
# The Ignorability Assumption is satisfied.
# 0.5395323315944631
# The Ignorability Assumption is satisfied.
# 0.8112791454934858
# The Ignorability Assumption is satisfied.
# 0.01507097629459102
# The Ignorability Assumption is not satisfied.
# 0.7375003000941542
# The Ignorability Assumption is satisfied.
# 0.33404660371290384
# The Ignorability Assumption is satisfied.
# 0.8244737911712813
# The Ignorability Assumption is satisfied.
# 0.07320167369228944
# The Ignorability Assumption is satisfied.
# 0.7909561522491816
# The Ignorability Assumption is satisfied.
# 0.319876686953363
# The Ignorability Assumption is satisfied.
# 0.9150179115199625
# The Ignorability Assumption is satisfied.
# 0.9930055822668051
# The Ignorability Assumption is satisfied.
# 0.1371199770048919
# The Ignorability Assumption is satisfied.
# 0.4047810091957355
# The Ignorability Assumption is satisfied.
# 0.7764399068040685
# The Ignorability Assumption is satisfied.
# 0.35251683227875635
# The Ignorability Assumption is satisfied.
# 0.7630093782841285
# The Ignorability Assumption is satisfied.
# 0.19334112707097323
# The Ignorability Assumption is satisfied.
# 0.7410173344360205
# The Ignorability Assumption is satisfied.
# 0.5726471592479909
# The Ignorability Assumption is satisfied.
# 0.4123778660465699
# The Ignorability Assumption is satisfied.
# 0.9545573344122533
# The Ignorability Assumption is satisfied.
# 0.4755980637407715
# The Ignorability Assumption is satisfied.
# 0.9174868970764148
# The Ignorability Assumption is satisfied.
# 0.3080404735978011
# The Ignorability Assumption is satisfied.
# 0.5793740273224306
# The Ignorability Assumption is satisfied.
# 0.8604699161351728
# The Ignorability Assumption is satisfied.
# 0.6940861595260811
# The Ignorability Assumption is satisfied.
# 0.26723552246321286
# The Ignorability Assumption is satisfied.
# 0.1730532286005391
# The Ignorability Assumption is satisfied.
# 0.3882605965800421
# The Ignorability Assumption is satisfied.
# 0.9897376764430641
# The Ignorability Assumption is satisfied.
# 0.8186006703656581
# The Ignorability Assumption is satisfied.
# 0.09782935191605627
# The Ignorability Assumption is satisfied.
# 0.8118816036863836
# The Ignorability Assumption is satisfied.
# 0.667620509734644
# The Ignorability Assumption is satisfied.
# 0.4268982236789858
# The Ignorability Assumption is satisfied.
# 0.1859492732946394
# The Ignorability Assumption is satisfied.
# 0.9262221125611283
# The Ignorability Assumption is satisfied.
# 0.8699824691446562
# The Ignorability Assumption is satisfied.
# 0.883755656742712
# The Ignorability Assumption is satisfied.
# 0.224288358070307
# The Ignorability Assumption is satisfied.
# 0.5308970581680519
# The Ignorability Assumption is satisfied.
# 0.14246279371092052
# The Ignorability Assumption is satisfied.
# 0.014964577338987685
# The Ignorability Assumption is not satisfied.
# 0.6981173695368078
# The Ignorability Assumption is satisfied.
# 0.7093205620897338
# The Ignorability Assumption is satisfied.
# 0.9823275987874657
# The Ignorability Assumption is satisfied.
# 0.616006801480907
# The Ignorability Assumption is satisfied.
# 0.9384840957519213
# The Ignorability Assumption is satisfied.
# 0.2910919386839841
# The Ignorability Assumption is satisfied.
# 0.5379902741743641
# The Ignorability Assumption is satisfied.
# 0.7426282812521882
# The Ignorability Assumption is satisfied.
# 0.8350941631821492
# The Ignorability Assumption is satisfied.
# 0.8241884817412946
# The Ignorability Assumption is satisfied.
# 0.09733588649027229
# The Ignorability Assumption is satisfied.
# 0.8100114694763407
# The Ignorability Assumption is satisfied.
# 0.07070307988076471
# The Ignorability Assumption is satisfied.
# 0.4941559179891378
# The Ignorability Assumption is satisfied.
# 0.3437056064935614
# The Ignorability Assumption is satisfied.
# 0.5069902709776952
# The Ignorability Assumption is satisfied.
# 0.8840351313053285
# The Ignorability Assumption is satisfied.
# 0.6170441280293997
# The Ignorability Assumption is satisfied.
# 0.4285463966772102
# The Ignorability Assumption is satisfied.
# 0.035799870114476925
# The Ignorability Assumption is not satisfied.
# 0.14542694954815183
# The Ignorability Assumption is satisfied.
# 0.7373987750886
# The Ignorability Assumption is satisfied.
# 0.49953751281329795
# The Ignorability Assumption is satisfied.
# 0.5147794008300811
# The Ignorability Assumption is satisfied.
# 0.14304618627563062
# The Ignorability Assumption is satisfied.
# 0.3513158563905767
# The Ignorability Assumption is satisfied.
# 0.44506909094619085
# The Ignorability Assumption is satisfied.
# 0.09079784034982337
# The Ignorability Assumption is satisfied.
# 0.3192295171219199
# The Ignorability Assumption is satisfied.
# 0.28752930054738673
# The Ignorability Assumption is satisfied.
# 0.4693136031952032
# The Ignorability Assumption is satisfied.
# 0.1925111424781399
# The Ignorability Assumption is satisfied.
# 0.9985847791607336
# The Ignorability Assumption is satisfied.
# 0.3021913808141876
# The Ignorability Assumption is satisfied.
# 0.8798028049509427
# The Ignorability Assumption is satisfied.
# 0.7162312129497834
# The Ignorability Assumption is satisfied.
# 0.8126074026133462
# The Ignorability Assumption is satisfied.
# 0.8375067440169897
# The Ignorability Assumption is satisfied.
# 0.9291143390101527
# The Ignorability Assumption is satisfied.
# 0.04833836070260268
# The Ignorability Assumption is not satisfied.
# 0.7542288096656207
# The Ignorability Assumption is satisfied.
# 0.6082958133227538
# The Ignorability Assumption is satisfied.
# 0.7479975098149179
# The Ignorability Assumption is satisfied.
# 0.32769920650145107
# The Ignorability Assumption is satisfied.
# 0.9677052202189266
# The Ignorability Assumption is satisfied.
# 0.7919439707881726
# The Ignorability Assumption is satisfied.
# 0.015045254260531138
# The Ignorability Assumption is not satisfied.
# 0.4486439477177956
# The Ignorability Assumption is satisfied.
# 0.436613358149907
# The Ignorability Assumption is satisfied.
# 0.38037296107322477
# The Ignorability Assumption is satisfied.
# 0.9645155438276886
# The Ignorability Assumption is satisfied.
# 0.8947391502190719
# The Ignorability Assumption is satisfied.
# 0.7468182425309045
# The Ignorability Assumption is satisfied.
# 0.3662874986706871
# The Ignorability Assumption is satisfied.
# 0.6331675924230337
# The Ignorability Assumption is satisfied.
# 0.7931127132764835
# The Ignorability Assumption is satisfied.
# 0.3328968423158092
# The Ignorability Assumption is satisfied.
# 0.5231942342933049
# The Ignorability Assumption is satisfied.
# 0.7030080132243353
# The Ignorability Assumption is satisfied.
# 0.26616283339513
# The Ignorability Assumption is satisfied.
# 0.05737617456771766
# The Ignorability Assumption is satisfied.
# 0.6933609412130777
# The Ignorability Assumption is satisfied.
# 0.969341319188338
# The Ignorability Assumption is satisfied.
# 0.10306145928082412
# The Ignorability Assumption is satisfied.
# 0.3766592878031357
# The Ignorability Assumption is satisfied.
# 0.14375607181782257
# The Ignorability Assumption is satisfied.
# 0.9744639453365375
# The Ignorability Assumption is satisfied.
# 0.39708759157659596
# The Ignorability Assumption is satisfied.
# 0.5285460607880513
# The Ignorability Assumption is satisfied.
# 0.6203682822163846
# The Ignorability Assumption is satisfied.
# 0.1605057701645749
# The Ignorability Assumption is satisfied.
# 0.8943904745153083
# The Ignorability Assumption is satisfied.
# 0.3107113569622233
# The Ignorability Assumption is satisfied.
# 0.11235325181610117
# The Ignorability Assumption is satisfied.
# 0.2789670770899698
# The Ignorability Assumption is satisfied.
# 0.3562369415135403
# The Ignorability Assumption is satisfied.
# 0.5088947875338532
# The Ignorability Assumption is satisfied.
# 0.21562701129088507
# The Ignorability Assumption is satisfied.
# 0.6489173956398145
# The Ignorability Assumption is satisfied.
# 0.2680935166487892
# The Ignorability Assumption is satisfied.
# 0.8773353607013714
# The Ignorability Assumption is satisfied.
# 0.33326996203801706
# The Ignorability Assumption is satisfied.
# 0.0649668641682738
# The Ignorability Assumption is satisfied.
# 0.729027135638805
# The Ignorability Assumption is satisfied.
# 0.03224668505195139
# The Ignorability Assumption is not satisfied.
# 0.6224385432713313
# The Ignorability Assumption is satisfied.
# 0.3013424931084654
# The Ignorability Assumption is satisfied.
# 0.7815564868840111
# The Ignorability Assumption is satisfied.
# 0.7557581277325728
# The Ignorability Assumption is satisfied.
# 0.6926028304738163
# The Ignorability Assumption is satisfied.
# 0.5147213048682802
# The Ignorability Assumption is satisfied.
# 0.8395563702421202
# The Ignorability Assumption is satisfied.
# 0.9259562446041029
# The Ignorability Assumption is satisfied.
# 0.19945862252324606
# The Ignorability Assumption is satisfied.
# 0.7411468191050951
# The Ignorability Assumption is satisfied.
# 0.7392830192516984
# The Ignorability Assumption is satisfied.
# 0.8284804229603708
# The Ignorability Assumption is satisfied.
# 0.8949384758018085
# The Ignorability Assumption is satisfied.
# 0.7849798797990428
# The Ignorability Assumption is satisfied.
# 0.39781889509915697
# The Ignorability Assumption is satisfied.
# 0.3069580551200995
# The Ignorability Assumption is satisfied.
# 0.2897184155727777
# The Ignorability Assumption is satisfied.
# 0.6391507695947551
# The Ignorability Assumption is satisfied.
# 0.49989142495810357
# The Ignorability Assumption is satisfied.
# 0.5803313638615339
# The Ignorability Assumption is satisfied.
# 0.9855144242364141
# The Ignorability Assumption is satisfied.
# 0.2340461510206307
# The Ignorability Assumption is satisfied.
# 0.8160467884512596
# The Ignorability Assumption is satisfied.
# 0.16852094807512066
# The Ignorability Assumption is satisfied.
# 0.4836385941888628
# The Ignorability Assumption is satisfied.
# 0.41257434409553284
# The Ignorability Assumption is satisfied.
# 0.28789110442034105
# The Ignorability Assumption is satisfied.
# 0.9665987002691371
# The Ignorability Assumption is satisfied.
# 0.7272717999710366
# The Ignorability Assumption is satisfied.
# 0.46357176830263835
# The Ignorability Assumption is satisfied.
# 0.1699819299842081
# The Ignorability Assumption is satisfied.
# 0.03350251932770785
# The Ignorability Assumption is not satisfied.
# 0.7401774487191725
# The Ignorability Assumption is satisfied.
# 0.15675313369333616
# The Ignorability Assumption is satisfied.
# 0.474051413780352
# The Ignorability Assumption is satisfied.
# 0.10730709233459923
# The Ignorability Assumption is satisfied.
# 0.42610965349753305
# The Ignorability Assumption is satisfied.
# 0.6935391271228586
# The Ignorability Assumption is satisfied.
# 0.7701404765665933
# The Ignorability Assumption is satisfied.
# 0.9690509180357458
# The Ignorability Assumption is satisfied.
# 0.8597524580546606
# The Ignorability Assumption is satisfied.
# 0.2014707619961096
# The Ignorability Assumption is satisfied.
# 0.7711131686467168
# The Ignorability Assumption is satisfied.
# 0.3211254264821192
# The Ignorability Assumption is satisfied.
# 0.7272063009627505
# The Ignorability Assumption is satisfied.
# 0.45354697284729184
# The Ignorability Assumption is satisfied.
# 0.6866612399357546
# The Ignorability Assumption is satisfied.
# 0.10523274264598265
# The Ignorability Assumption is satisfied.
# 0.9012908251703828
# The Ignorability Assumption is satisfied.
# 0.5608771876812886
# The Ignorability Assumption is satisfied.
# 0.416259653286964
# The Ignorability Assumption is satisfied.
# 0.8552032649793588
# The Ignorability Assumption is satisfied.
# 0.9505507784904238
# The Ignorability Assumption is satisfied.
# 0.4822951410056189
# The Ignorability Assumption is satisfied.
# 0.011037347271289905
# The Ignorability Assumption is not satisfied.
# 0.99957173207856
# The Ignorability Assumption is satisfied.
# 0.7749873994075697
# The Ignorability Assumption is satisfied.
# 0.11181371596954566
# The Ignorability Assumption is satisfied.
# 0.8035163698462788
# The Ignorability Assumption is satisfied.
# 0.6217627420126988
# The Ignorability Assumption is satisfied.
# 0.559638712579573
# The Ignorability Assumption is satisfied.
# 0.8596174440011699
# The Ignorability Assumption is satisfied.
# 0.7113514826548278
# The Ignorability Assumption is satisfied.
# 0.7091778639163531
# The Ignorability Assumption is satisfied.
# 0.142032709829411
# The Ignorability Assumption is satisfied.
# 0.2542017576985062
# The Ignorability Assumption is satisfied.
# 0.6985613139427035
# The Ignorability Assumption is satisfied.
# 0.4344875324933585
# The Ignorability Assumption is satisfied.
# 0.29186050758413057
# The Ignorability Assumption is satisfied.
# 0.48533323879878687
# The Ignorability Assumption is satisfied.
# 0.31062490507402324
# The Ignorability Assumption is satisfied.
# 0.33739887307303684
# The Ignorability Assumption is satisfied.
# 0.6524347480468784
# The Ignorability Assumption is satisfied.
# 0.6747001767244913
# The Ignorability Assumption is satisfied.
# 0.2854041175245773
# The Ignorability Assumption is satisfied.
# 0.6735736283236566
# The Ignorability Assumption is satisfied.
# 0.15049839827467598
# The Ignorability Assumption is satisfied.
# 0.20453801242768405
# The Ignorability Assumption is satisfied.
# 0.7161194272246432
# The Ignorability Assumption is satisfied.
# 0.5069186772371301
# The Ignorability Assumption is satisfied.
# 0.13191129133792592
# The Ignorability Assumption is satisfied.
# 0.33415704345623387
# The Ignorability Assumption is satisfied.
# 0.9735330859198075
# The Ignorability Assumption is satisfied.
# 0.6522881749208786
# The Ignorability Assumption is satisfied.
# 0.05175460032697485
# The Ignorability Assumption is satisfied.
# 0.24703511871742265
# The Ignorability Assumption is satisfied.
# 0.2536753986233123
# The Ignorability Assumption is satisfied.
# 0.8956601854577403
# The Ignorability Assumption is satisfied.
# 0.5805016742760339
# The Ignorability Assumption is satisfied.
# 0.7098934731508261
# The Ignorability Assumption is satisfied.
# 0.6816929343041142
# The Ignorability Assumption is satisfied.
# 0.6401657731929553
# The Ignorability Assumption is satisfied.
# 0.7975001948814885
# The Ignorability Assumption is satisfied.
# 0.2671666522021177
# The Ignorability Assumption is satisfied.
# 0.6617228946700888
# The Ignorability Assumption is satisfied.
# 0.8073215676728275
# The Ignorability Assumption is satisfied.
# 0.5062841184977072
# The Ignorability Assumption is satisfied.
# 0.9287313697166666
# The Ignorability Assumption is satisfied.
# 0.2620720660932554
# The Ignorability Assumption is satisfied.
# 0.0018699522317218254
# The Ignorability Assumption is not satisfied.
# 0.5247882680761125
# The Ignorability Assumption is satisfied.
# 0.49592745915635605
# The Ignorability Assumption is satisfied.
# 0.06251774968795697
# The Ignorability Assumption is satisfied.
# 0.3653494565860021
# The Ignorability Assumption is satisfied.
# 0.7032908830299376
# The Ignorability Assumption is satisfied.
# 0.049287001667625625
# The Ignorability Assumption is not satisfied.
# 0.7355212466107179
# The Ignorability Assumption is satisfied.
# 0.41853880083767736
# The Ignorability Assumption is satisfied.
# 0.3883054785210541
# The Ignorability Assumption is satisfied.
# 0.6461264629056848
# The Ignorability Assumption is satisfied.
# 0.9873051868228493
# The Ignorability Assumption is satisfied.
# 0.6490330261926612
# The Ignorability Assumption is satisfied.
# 0.9794344210744437
# The Ignorability Assumption is satisfied.
# 0.8471817427755177
# The Ignorability Assumption is satisfied.
# 0.2615482930267335
# The Ignorability Assumption is satisfied.
# 0.13754006120327705
# The Ignorability Assumption is satisfied.
# 0.4117234294624402
# The Ignorability Assumption is satisfied.
# 0.8961320958712329
# The Ignorability Assumption is satisfied.
# 0.7442486696009606
# The Ignorability Assumption is satisfied.
# 0.24996263308902925
# The Ignorability Assumption is satisfied.
# 0.1698395570361879
# The Ignorability Assumption is satisfied.
# 0.5237126501013805
# The Ignorability Assumption is satisfied.
# 0.02926099154980076
# The Ignorability Assumption is not satisfied.
# 0.6835535661650076
# The Ignorability Assumption is satisfied.
# 0.3386943233700709
# The Ignorability Assumption is satisfied.
# 0.2264514092933351
# The Ignorability Assumption is satisfied.
# 0.305826431182076
# The Ignorability Assumption is satisfied.
# 0.41617698841277895
# The Ignorability Assumption is satisfied.
# 0.8386377776782908
# The Ignorability Assumption is satisfied.
# 0.4713528891430271
# The Ignorability Assumption is satisfied.
# 0.5007980407810309
# The Ignorability Assumption is satisfied.
# 0.17138256348812725
# The Ignorability Assumption is satisfied.
# 0.7016915517971074
# The Ignorability Assumption is satisfied.
# 0.44599795787869745
# The Ignorability Assumption is satisfied.
# 0.6994339574596256
# The Ignorability Assumption is satisfied.
# 0.8913410054332742
# The Ignorability Assumption is satisfied.
# 0.7811476992450361
# The Ignorability Assumption is satisfied.
# 0.6096664416824714
# The Ignorability Assumption is satisfied.
# 0.394433796974168
# The Ignorability Assumption is satisfied.
# 0.9714037870678105
# The Ignorability Assumption is satisfied.
# 0.23400282266903333
# The Ignorability Assumption is satisfied.
# 0.5008703064583355
# The Ignorability Assumption is satisfied.
# 0.9524997430023481
# The Ignorability Assumption is satisfied.
# 0.5817670584612402
# The Ignorability Assumption is satisfied.
# 0.8730582287038643
# The Ignorability Assumption is satisfied.
# 0.4561617961382288
# The Ignorability Assumption is satisfied.
# 0.005437943346653826
# The Ignorability Assumption is not satisfied.
# 0.6038973103233134
# The Ignorability Assumption is satisfied.
# 0.8501939705338767
# The Ignorability Assumption is satisfied.
# 0.7356031560711247
# The Ignorability Assumption is satisfied.
# 0.5365389538284433
# The Ignorability Assumption is satisfied.
# 0.015424069465872168
# The Ignorability Assumption is not satisfied.
# 0.3281192201806958
# The Ignorability Assumption is satisfied.
# 0.7138317771146874
# The Ignorability Assumption is satisfied.
# 0.7181762555406626
# The Ignorability Assumption is satisfied.
# 0.17237070885509762
# The Ignorability Assumption is satisfied.
# 0.5444902104303423
# The Ignorability Assumption is satisfied.
# 0.5408354037596432
# The Ignorability Assumption is satisfied.
# 0.0991421457232678
# The Ignorability Assumption is satisfied.
# 0.7186085314977286
# The Ignorability Assumption is satisfied.
# 0.1724392301447778
# The Ignorability Assumption is satisfied.
# 0.6873059634741043
# The Ignorability Assumption is satisfied.
# 0.9263551960289043
# The Ignorability Assumption is satisfied.
# 0.3281708975090562
# The Ignorability Assumption is satisfied.
# 0.18373078422289965
# The Ignorability Assumption is satisfied.
# 0.41430754858280106
# The Ignorability Assumption is satisfied.
# 0.2483202974110746
# The Ignorability Assumption is satisfied.
# 0.8571999046438461
# The Ignorability Assumption is satisfied.
# 0.9212138534286165
# The Ignorability Assumption is satisfied.
# 0.5834869048977555
# The Ignorability Assumption is satisfied.
# 0.4056223644693818
# The Ignorability Assumption is satisfied.
# 0.3145754972001257
# The Ignorability Assumption is satisfied.
# 0.6275430335197494
# The Ignorability Assumption is satisfied.
# 0.15106471905379534
# The Ignorability Assumption is satisfied.
# 0.1930495635522168
# The Ignorability Assumption is satisfied.
# 0.860703854982711
# The Ignorability Assumption is satisfied.
# 0.1705421959561963
# The Ignorability Assumption is satisfied.
# 0.23838729493880145
# The Ignorability Assumption is satisfied.
# 0.4229044202457608
# The Ignorability Assumption is satisfied.
# 0.1727039545781535
# The Ignorability Assumption is satisfied.
# 0.2623452334680174
# The Ignorability Assumption is satisfied.
# 0.8593542772414605
# The Ignorability Assumption is satisfied.
# 0.5477065136437782
# The Ignorability Assumption is satisfied.
# 0.23369522761320632
# The Ignorability Assumption is satisfied.
# 0.6500103135148393
# The Ignorability Assumption is satisfied.
# 0.43384174082167315
# The Ignorability Assumption is satisfied.
# 0.55299691541595
# The Ignorability Assumption is satisfied.
# 0.33550421964666316
# The Ignorability Assumption is satisfied.
# 0.910389590508899
# The Ignorability Assumption is satisfied.
# 0.9937888671795689
# The Ignorability Assumption is satisfied.
# 0.19510500645102768
# The Ignorability Assumption is satisfied.
# 0.2168054953623958
# The Ignorability Assumption is satisfied.
# 0.00717316061193141
# The Ignorability Assumption is not satisfied.
# 0.21012693563082505
# The Ignorability Assumption is satisfied.
# 0.48897442603512
# The Ignorability Assumption is satisfied.
# 0.5991992142654243
# The Ignorability Assumption is satisfied.
# 0.32657550147015996
# The Ignorability Assumption is satisfied.
# 0.3570156757825451
# The Ignorability Assumption is satisfied.
# 0.9906268352459746
# The Ignorability Assumption is satisfied.
# 0.2641962184766419
# The Ignorability Assumption is satisfied.
# 0.1610666854732483
# The Ignorability Assumption is satisfied.
# 0.3575615369134837
# The Ignorability Assumption is satisfied.
# 0.53175584099133
# The Ignorability Assumption is satisfied.
# 0.634521031451778
# The Ignorability Assumption is satisfied.
# 0.44205356036720644
# The Ignorability Assumption is satisfied.
# 0.742368430545574
# The Ignorability Assumption is satisfied.
# 0.38480873031322343
# The Ignorability Assumption is satisfied.
# 0.7346458982162813
# The Ignorability Assumption is satisfied.
# 0.9751916878409034
# The Ignorability Assumption is satisfied.
# 0.8651654331966683
# The Ignorability Assumption is satisfied.
# 0.5086304456426916
# The Ignorability Assumption is satisfied.
# 0.45743410624598213
# The Ignorability Assumption is satisfied.
# 0.10625268368734936
# The Ignorability Assumption is satisfied.
# 0.13185806680560966
# The Ignorability Assumption is satisfied.
# 0.2876614947892162
# The Ignorability Assumption is satisfied.
# 0.3847902977745187
# The Ignorability Assumption is satisfied.
# 0.42369834975178844
# The Ignorability Assumption is satisfied.
# 0.4977937165742139
# The Ignorability Assumption is satisfied.
# 0.5035078878751772
# The Ignorability Assumption is satisfied.
# 0.7292336437913818
# The Ignorability Assumption is satisfied.
# 0.12323262571008958
# The Ignorability Assumption is satisfied.
# 0.5728367849800127
# The Ignorability Assumption is satisfied.
# 0.23553833511057748
# The Ignorability Assumption is satisfied.
# 0.8679148567944439
# The Ignorability Assumption is satisfied.
# 0.027619741526462512
# The Ignorability Assumption is not satisfied.
# 0.05166023945558132
# The Ignorability Assumption is satisfied.
# 0.8556685522149047
# The Ignorability Assumption is satisfied.
# 0.6531976722811599
# The Ignorability Assumption is satisfied.
# 0.1515577646658953
# The Ignorability Assumption is satisfied.
# 0.8509423068283706
# The Ignorability Assumption is satisfied.
# 0.31579049752376787
# The Ignorability Assumption is satisfied.
# 0.9591255469031595
# The Ignorability Assumption is satisfied.
# 0.35598149097771015
# The Ignorability Assumption is satisfied.
# 0.8136374187863904
# The Ignorability Assumption is satisfied.
# 0.43678267763463907
# The Ignorability Assumption is satisfied.
# 0.5485700754826721
# The Ignorability Assumption is satisfied.
# 0.04501862070503097
# The Ignorability Assumption is not satisfied.
# 0.00010878154729707395
# The Ignorability Assumption is not satisfied.
# 0.6051823559346332
# The Ignorability Assumption is satisfied.
# 0.14664493552556473
# The Ignorability Assumption is satisfied.
# 0.34067019072385996
# The Ignorability Assumption is satisfied.
# 0.37774880938510913
# The Ignorability Assumption is satisfied.
# 0.7485750525651254
# The Ignorability Assumption is satisfied.
# 0.4475932665406429
# The Ignorability Assumption is satisfied.
# 0.49575646482383906
# The Ignorability Assumption is satisfied.
# 0.46107901599258316
# The Ignorability Assumption is satisfied.
# 0.5990147796580974
# The Ignorability Assumption is satisfied.
# 0.7750516626541961
# The Ignorability Assumption is satisfied.
# 0.9225251552494361
# The Ignorability Assumption is satisfied.
# 0.6976075022797623
# The Ignorability Assumption is satisfied.
# 0.7668350063521122
# The Ignorability Assumption is satisfied.
# 0.14853116834771252
# The Ignorability Assumption is satisfied.
# 0.8723776472630979
# The Ignorability Assumption is satisfied.
# 0.7489219469667515
# The Ignorability Assumption is satisfied.
# 0.8518884229549128
# The Ignorability Assumption is satisfied.
# 0.5567010263074074
# The Ignorability Assumption is satisfied.
# 0.35693274548434145
# The Ignorability Assumption is satisfied.
# 0.8126254398764903
# The Ignorability Assumption is satisfied.
# 0.8355408026370622
# The Ignorability Assumption is satisfied.
# 0.6980474336254939
# The Ignorability Assumption is satisfied.
# 0.20661269896788725
# The Ignorability Assumption is satisfied.
# 0.8461922221857519
# The Ignorability Assumption is satisfied.
# 0.7527426975851264
# The Ignorability Assumption is satisfied.
# 0.3078768480789108
# The Ignorability Assumption is satisfied.
# 0.28455010609167564
# The Ignorability Assumption is satisfied.
# 0.2255901456140357
# The Ignorability Assumption is satisfied.
# 0.1686903986269903
# The Ignorability Assumption is satisfied.
# 0.8070213799911125
# The Ignorability Assumption is satisfied.
# 0.32924415208686963
# The Ignorability Assumption is satisfied.
# 0.2137607703989045
# The Ignorability Assumption is satisfied.
# 0.5068225065708502
# The Ignorability Assumption is satisfied.
# 0.14823934182086082
# The Ignorability Assumption is satisfied.
# 0.4690814210706601
# The Ignorability Assumption is satisfied.
# 0.19053128016151002
# The Ignorability Assumption is satisfied.
# 0.7156193660469892
# The Ignorability Assumption is satisfied.
# 0.09492993262891347
# The Ignorability Assumption is satisfied.
# 0.09389225997554129
# The Ignorability Assumption is satisfied.
# 0.6799390855542693
# The Ignorability Assumption is satisfied.
# 0.5145848568771316
# The Ignorability Assumption is satisfied.
# 0.554512556011119
# The Ignorability Assumption is satisfied.
# 0.21191953130378416
# The Ignorability Assumption is satisfied.
# 0.4818735985370427
# The Ignorability Assumption is satisfied.
# 0.13965414518266983
# The Ignorability Assumption is satisfied.
# 0.1068089452268362
# The Ignorability Assumption is satisfied.
# 0.6310103052674236
# The Ignorability Assumption is satisfied.
# 0.9680856434107257
# The Ignorability Assumption is satisfied.
# 0.3682123543444167
# The Ignorability Assumption is satisfied.
# 0.3838302313509881
# The Ignorability Assumption is satisfied.
# 0.11672656799878225
# The Ignorability Assumption is satisfied.
# 0.65534071868723
# The Ignorability Assumption is satisfied.
# 0.2220510520674777
# The Ignorability Assumption is satisfied.
# 0.5949420860042383
# The Ignorability Assumption is satisfied.
# 0.19219196711513278
# The Ignorability Assumption is satisfied.
# 0.7198411046041358
# The Ignorability Assumption is satisfied.
# 0.8586642921059617
# The Ignorability Assumption is satisfied.
# 0.07335072618123496
# The Ignorability Assumption is satisfied.
# 0.6126792515049686
# The Ignorability Assumption is satisfied.
# 0.2612055794466847
# The Ignorability Assumption is satisfied.
# 0.057636371884096545
# The Ignorability Assumption is satisfied.
# 0.8442130703940723
# The Ignorability Assumption is satisfied.
# 0.06272972953573161
# The Ignorability Assumption is satisfied.
# 0.024476626964052495
# The Ignorability Assumption is not satisfied.
# 0.48241743065468556
# The Ignorability Assumption is satisfied.
# 0.35820531587226
# The Ignorability Assumption is satisfied.
# 0.8320198381223003
# The Ignorability Assumption is satisfied.
# 0.9120199397642899
# The Ignorability Assumption is satisfied.
# 0.7255408815681856
# The Ignorability Assumption is satisfied.
# 0.10175774462163181
# The Ignorability Assumption is satisfied.
# 0.1708541737527622
# The Ignorability Assumption is satisfied.
# 0.2842169604292318
# The Ignorability Assumption is satisfied.
# 0.767675563843025
# The Ignorability Assumption is satisfied.
# 0.44801891295503327
# The Ignorability Assumption is satisfied.
# 0.6269230504520671
# The Ignorability Assumption is satisfied.
# 0.9064737961376385
# The Ignorability Assumption is satisfied.
# 0.6073821329683251
# The Ignorability Assumption is satisfied.
# 0.5153500270778777
# The Ignorability Assumption is satisfied.
# 0.1633817141527749
# The Ignorability Assumption is satisfied.
# 0.39979243724918434
# The Ignorability Assumption is satisfied.
# 0.8138456574748021
# The Ignorability Assumption is satisfied.
# 0.05056991804914583
# The Ignorability Assumption is satisfied.
# 0.8486217980015628
# The Ignorability Assumption is satisfied.
# 0.5706530844340543
# The Ignorability Assumption is satisfied.
# 0.8488667290801487
# The Ignorability Assumption is satisfied.
# 0.2966361198171277
# The Ignorability Assumption is satisfied.
# 0.6157947937824553
# The Ignorability Assumption is satisfied.
# 0.29396765421919613
# The Ignorability Assumption is satisfied.
# 0.20826362745199237
# The Ignorability Assumption is satisfied.
# 0.43584934820319754
# The Ignorability Assumption is satisfied.
# 0.8242340886415492
# The Ignorability Assumption is satisfied.
# 0.8364936653086077
# The Ignorability Assumption is satisfied.
# 0.9674718968420896
# The Ignorability Assumption is satisfied.
# 0.4762493454145642
# The Ignorability Assumption is satisfied.
# 0.49667551142272015
# The Ignorability Assumption is satisfied.
# 0.4875547660251176
# The Ignorability Assumption is satisfied.
# 0.4777411657161389
# The Ignorability Assumption is satisfied.
# 0.24219960068309632
# The Ignorability Assumption is satisfied.
# 0.6211453454856686
# The Ignorability Assumption is satisfied.
# 0.41814838553378586
# The Ignorability Assumption is satisfied.
# 0.18154694054282258
# The Ignorability Assumption is satisfied.
# 0.9558272254413545
# The Ignorability Assumption is satisfied.
# 0.00219782271717816
# The Ignorability Assumption is not satisfied.
# 0.5317546312634658
# The Ignorability Assumption is satisfied.
# 0.21663974303676584
# The Ignorability Assumption is satisfied.
# 0.0766747425593707
# The Ignorability Assumption is satisfied.
# 0.7190433981517972
# The Ignorability Assumption is satisfied.
# 0.13806672479519236
# The Ignorability Assumption is satisfied.
# 0.11816679981194253
# The Ignorability Assumption is satisfied.
# 0.9214293981383397
# The Ignorability Assumption is satisfied.
# 0.19541903762498178
# The Ignorability Assumption is satisfied.
# 0.3837801503564366
# The Ignorability Assumption is satisfied.
# 0.09645362583099525
# The Ignorability Assumption is satisfied.
# 0.9635344236033285
# The Ignorability Assumption is satisfied.
# 0.5354397166517015
# The Ignorability Assumption is satisfied.
# 0.04785772114985227
# The Ignorability Assumption is not satisfied.
# 0.2114168029764936
# The Ignorability Assumption is satisfied.
# 0.38119993734713803
# The Ignorability Assumption is satisfied.
# 0.19019042810593895
# The Ignorability Assumption is satisfied.
# 0.028417543100558787
# The Ignorability Assumption is not satisfied.
# 0.06335920962498784
# The Ignorability Assumption is satisfied.
# 0.5959101568629765
# The Ignorability Assumption is satisfied.
# 0.8711356979096627
# The Ignorability Assumption is satisfied.
# 0.042376706024441435
# The Ignorability Assumption is not satisfied.
# 0.8924180167122518
# The Ignorability Assumption is satisfied.
# 0.5141065173719181
# The Ignorability Assumption is satisfied.
# 0.10131972270019633
# The Ignorability Assumption is satisfied.
# 0.3616500817486584
# The Ignorability Assumption is satisfied.
# 0.8547709719145942
# The Ignorability Assumption is satisfied.
# 0.8563851690293478
# The Ignorability Assumption is satisfied.
# 0.26139478144954087
# The Ignorability Assumption is satisfied.
# 0.21136094875540062
# The Ignorability Assumption is satisfied.
# 0.7867669005787652
# The Ignorability Assumption is satisfied.
# 0.9839450028368074
# The Ignorability Assumption is satisfied.
# 0.07193642024977938
# The Ignorability Assumption is satisfied.
# 0.5437010254582484
# The Ignorability Assumption is satisfied.
# 0.02551608618173613
# The Ignorability Assumption is not satisfied.
# 0.3461311231051054
# The Ignorability Assumption is satisfied.
# 0.30329176326390084
# The Ignorability Assumption is satisfied.
# 0.2101266162829856
# The Ignorability Assumption is satisfied.
# 0.46938042353912135
# The Ignorability Assumption is satisfied.
# 0.181137607281112
# The Ignorability Assumption is satisfied.
# 0.858485036099466
# The Ignorability Assumption is satisfied.
# 0.2610007089313221
# The Ignorability Assumption is satisfied.
# 0.05069690612023384
# The Ignorability Assumption is satisfied.
# 0.40230394300833267
# The Ignorability Assumption is satisfied.
# 0.48632435717300415
# The Ignorability Assumption is satisfied.
# 0.2146517284244826
# The Ignorability Assumption is satisfied.
# 0.1214624423258376
# The Ignorability Assumption is satisfied.
# 0.336904431848898
# The Ignorability Assumption is satisfied.
# 0.39734811452230806
# The Ignorability Assumption is satisfied.
# 0.766778381032122
# The Ignorability Assumption is satisfied.
# 0.45622622004667757
# The Ignorability Assumption is satisfied.
# 0.3479159561352836
# The Ignorability Assumption is satisfied.
# 0.33354509672300153
# The Ignorability Assumption is satisfied.
# 0.35867233959950406
# The Ignorability Assumption is satisfied.
# 0.3554923821700135
# The Ignorability Assumption is satisfied.
# 0.8919762493042178
# The Ignorability Assumption is satisfied.
# 0.08253344511943687
# The Ignorability Assumption is satisfied.
# 0.17547805874043887
# The Ignorability Assumption is satisfied.
# 0.4262648223569172
# The Ignorability Assumption is satisfied.
# 0.8430315902283616
# The Ignorability Assumption is satisfied.
# 0.948424517523574
# The Ignorability Assumption is satisfied.
# 0.29722064486115707
# The Ignorability Assumption is satisfied.
# 0.3823562208918911
# The Ignorability Assumption is satisfied.
# 0.2794581342057818
# The Ignorability Assumption is satisfied.
# 0.2646182922298783
# The Ignorability Assumption is satisfied.
# 0.8474209438718252
# The Ignorability Assumption is satisfied.
# 0.02833531039730144
# The Ignorability Assumption is not satisfied.
# 0.12676744615195915
# The Ignorability Assumption is satisfied.
# 0.10359151286580238
# The Ignorability Assumption is satisfied.
# 0.6276946508302108
# The Ignorability Assumption is satisfied.
# 0.935585282194008
# The Ignorability Assumption is satisfied.
# 0.06347936117560606
# The Ignorability Assumption is satisfied.
# 0.7561205701443661
# The Ignorability Assumption is satisfied.
# 0.7399384840254035
# The Ignorability Assumption is satisfied.
# 0.37844033998534493
# The Ignorability Assumption is satisfied.
# 0.6227210111277763
# The Ignorability Assumption is satisfied.
# 0.8767839477415801
# The Ignorability Assumption is satisfied.
# 0.6102231539240677
# The Ignorability Assumption is satisfied.
# 0.4299942319534803
# The Ignorability Assumption is satisfied.
# 0.1896040026258296
# The Ignorability Assumption is satisfied.
# 0.32121538670866856
# The Ignorability Assumption is satisfied.
# 0.37102923115302594
# The Ignorability Assumption is satisfied.
# 0.7604999033986173
# The Ignorability Assumption is satisfied.
# 0.473645962818496
# The Ignorability Assumption is satisfied.
# 0.7005476105372965
# The Ignorability Assumption is satisfied.
# 0.32450635906122755
# The Ignorability Assumption is satisfied.
# 0.003041420075840419
# The Ignorability Assumption is not satisfied.
# 0.11947018112545996
# The Ignorability Assumption is satisfied.
# 0.9279597806716569
# The Ignorability Assumption is satisfied.
# 0.3950491074352155
# The Ignorability Assumption is satisfied.
# 0.9628627048996509
# The Ignorability Assumption is satisfied.
# 0.04146273694974799
# The Ignorability Assumption is not satisfied.
# 0.8660846008112469
# The Ignorability Assumption is satisfied.
# 0.6123442926690362
# The Ignorability Assumption is satisfied.
# 0.8967751411086516
# The Ignorability Assumption is satisfied.
# 0.99111777094934
# The Ignorability Assumption is satisfied.
# 0.009713897677125254
# The Ignorability Assumption is not satisfied.
# 0.7048640352002971
# The Ignorability Assumption is satisfied.
# 0.5339751781697883
# The Ignorability Assumption is satisfied.
# 0.8820115092061774
# The Ignorability Assumption is satisfied.
# 0.13720608728888697
# The Ignorability Assumption is satisfied.
# 0.8703623820540003
# The Ignorability Assumption is satisfied.
# 0.5590264727132839
# The Ignorability Assumption is satisfied.
# 0.2746008918795761
# The Ignorability Assumption is satisfied.
# 0.5166827968627659
# The Ignorability Assumption is satisfied.
# 0.46852129576945445
# The Ignorability Assumption is satisfied.
# 0.012868652038815773
# The Ignorability Assumption is not satisfied.
# 0.9121206475436129
# The Ignorability Assumption is satisfied.
# 0.39288072088931036
# The Ignorability Assumption is satisfied.
# 0.5470798740456425
# The Ignorability Assumption is satisfied.
# 0.45592793277774435
# The Ignorability Assumption is satisfied.
# 0.941127135032932
# The Ignorability Assumption is satisfied.
# 0.6012077536479308
# The Ignorability Assumption is satisfied.
# 0.11422678421199653
# The Ignorability Assumption is satisfied.
# 0.9947023938783062
# The Ignorability Assumption is satisfied.
# 0.8909338055489222
# The Ignorability Assumption is satisfied.
# 0.25344724441338623
# The Ignorability Assumption is satisfied.
# 0.8402015193476321
# The Ignorability Assumption is satisfied.
# 0.27828295424099947
# The Ignorability Assumption is satisfied.
# 0.3392989495224835
# The Ignorability Assumption is satisfied.
# 0.27838746927444896
# The Ignorability Assumption is satisfied.
# 0.8013046965865863
# The Ignorability Assumption is satisfied.
# 0.7476047894984154
# The Ignorability Assumption is satisfied.
# 0.5817303258686178
# The Ignorability Assumption is satisfied.
# 0.22429945932316195
# The Ignorability Assumption is satisfied.
# 0.608666457165675
# The Ignorability Assumption is satisfied.
# 0.8031929211721403
# The Ignorability Assumption is satisfied.
# 0.5766022694229529
# The Ignorability Assumption is satisfied.
# 0.7482898575409205
# The Ignorability Assumption is satisfied.
# 0.8921597738870135
# The Ignorability Assumption is satisfied.
# 0.5755692859276917
# The Ignorability Assumption is satisfied.
# 0.3131513945675273
# The Ignorability Assumption is satisfied.
# 0.6292306849631935
# The Ignorability Assumption is satisfied.
# 0.895737394958875
# The Ignorability Assumption is satisfied.
# 0.21830954802452665
# The Ignorability Assumption is satisfied.
# 0.8944198894911692
# The Ignorability Assumption is satisfied.
# 0.7649108459562276
# The Ignorability Assumption is satisfied.
# 0.6391784291420848
# The Ignorability Assumption is satisfied.
# 0.9125448117355949
# The Ignorability Assumption is satisfied.
# 0.5374061064502669
# The Ignorability Assumption is satisfied.
# 0.7526051957415362
# The Ignorability Assumption is satisfied.
# 0.6574959655172595
# The Ignorability Assumption is satisfied.
# 0.3521672330323774
# The Ignorability Assumption is satisfied.
# 0.8690901066004348
# The Ignorability Assumption is satisfied.
# 0.30446803331807654
# The Ignorability Assumption is satisfied.
# 0.43015936642443553
# The Ignorability Assumption is satisfied.
# 0.13926034577252386
# The Ignorability Assumption is satisfied.
# 0.011715880790663219
# The Ignorability Assumption is not satisfied.
# 0.9025458457657414
# The Ignorability Assumption is satisfied.
# 0.27250595503641706
# The Ignorability Assumption is satisfied.
# 0.24865359460409647
# The Ignorability Assumption is satisfied.
# 0.9801574722667312
# The Ignorability Assumption is satisfied.
# 0.809538186373721
# The Ignorability Assumption is satisfied.
# 0.34825959299921627
# The Ignorability Assumption is satisfied.
# 0.5421603321054614
# The Ignorability Assumption is satisfied.
# 0.5637134010518201
# The Ignorability Assumption is satisfied.
# 0.026322555603799456
# The Ignorability Assumption is not satisfied.
# 0.3898237719139442
# The Ignorability Assumption is satisfied.
# 0.648766858735349
# The Ignorability Assumption is satisfied.
# 0.12241763387036379
# The Ignorability Assumption is satisfied.
# 0.18649298542661522
# The Ignorability Assumption is satisfied.
# 0.8171120891791993
# The Ignorability Assumption is satisfied.
# 0.3394410372165455
# The Ignorability Assumption is satisfied.
# 0.9489296041523094
# The Ignorability Assumption is satisfied.
# 0.9974398393551452
# The Ignorability Assumption is satisfied.
# 0.07618862916656716
# The Ignorability Assumption is satisfied.
# 0.23894154092422495
# The Ignorability Assumption is satisfied.
# 0.11582205453130129
# The Ignorability Assumption is satisfied.
# 0.8556556884553316
# The Ignorability Assumption is satisfied.
# 0.920476234460527
# The Ignorability Assumption is satisfied.
# 0.28548595370859714
# The Ignorability Assumption is satisfied.
# 0.1749790383402964
# The Ignorability Assumption is satisfied.
# 0.7528923228989627
# The Ignorability Assumption is satisfied.
# 0.49871900973347694
# The Ignorability Assumption is satisfied.
# 0.19221329944308546
# The Ignorability Assumption is satisfied.
# 0.5272973179383736
# The Ignorability Assumption is satisfied.
# 0.7688756212533021
# The Ignorability Assumption is satisfied.
# 0.774606572149696
# The Ignorability Assumption is satisfied.
# 0.965662303908766
# The Ignorability Assumption is satisfied.
# 0.12986362803938353
# The Ignorability Assumption is satisfied.
# 0.7384437510594583
# The Ignorability Assumption is satisfied.
# 0.10938807000313251
# The Ignorability Assumption is satisfied.
# 0.7169102540641623
# The Ignorability Assumption is satisfied.
# 0.7226209684642393
# The Ignorability Assumption is satisfied.
# 0.4686586619615196
# The Ignorability Assumption is satisfied.
# 0.5384147862734261
# The Ignorability Assumption is satisfied.
# 0.5829782689105543
# The Ignorability Assumption is satisfied.
# 0.9689958118614639
# The Ignorability Assumption is satisfied.
# 0.4142122787171916
# The Ignorability Assumption is satisfied.
# 0.6589862010072587
# The Ignorability Assumption is satisfied.
# 0.6820182561422155
# The Ignorability Assumption is satisfied.
# 0.40121398669764513
# The Ignorability Assumption is satisfied.
# 0.9066984567670505
# The Ignorability Assumption is satisfied.
# 0.9783486128350416
# The Ignorability Assumption is satisfied.
# 0.22243372574961687
# The Ignorability Assumption is satisfied.
# 0.5498337213975699
# The Ignorability Assumption is satisfied.
# 0.7572240487831681
# The Ignorability Assumption is satisfied.
# 0.9111263467084888
# The Ignorability Assumption is satisfied.
# 0.23887488357246883
# The Ignorability Assumption is satisfied.
# 0.9160951243043796
# The Ignorability Assumption is satisfied.
# 0.03144996948734496
# The Ignorability Assumption is not satisfied.
# 0.5258879594760137
# The Ignorability Assumption is satisfied.
# 0.48041125645692795
# The Ignorability Assumption is satisfied.
# 0.5797133439874655
# The Ignorability Assumption is satisfied.
# 0.398087151670405
# The Ignorability Assumption is satisfied.
# 0.8016591759386762
# The Ignorability Assumption is satisfied.
# 0.8725637689927642
# The Ignorability Assumption is satisfied.
# 0.9032268140507504
# The Ignorability Assumption is satisfied.
# 0.11371702673281861
# The Ignorability Assumption is satisfied.
# 0.8921944518611591
# The Ignorability Assumption is satisfied.
# 0.2946695968816113
# The Ignorability Assumption is satisfied.
# 0.7336978643820508
# The Ignorability Assumption is satisfied.
# 0.9375838910072113
# The Ignorability Assumption is satisfied.
# 0.3954430337738044
# The Ignorability Assumption is satisfied.
# 0.11040553272952065
# The Ignorability Assumption is satisfied.
# 0.9841111420430685
# The Ignorability Assumption is satisfied.
# 0.7617021545678724
# The Ignorability Assumption is satisfied.
# 0.10949658955741944
# The Ignorability Assumption is satisfied.
# 0.14535048191264666
# The Ignorability Assumption is satisfied.
# 0.514316585960398
# The Ignorability Assumption is satisfied.
# 0.6014752165823966
# The Ignorability Assumption is satisfied.
# 0.47095875157727196
# The Ignorability Assumption is satisfied.
# 0.6012695730209588
# The Ignorability Assumption is satisfied.
# 0.39607666736194896
# The Ignorability Assumption is satisfied.
# 0.36269568967666327
# The Ignorability Assumption is satisfied.
# 0.49063478539788763
# The Ignorability Assumption is satisfied.
# 0.2689354982339865
# The Ignorability Assumption is satisfied.
# 0.21357025876718896
# The Ignorability Assumption is satisfied.
# 0.3979924106737809
# The Ignorability Assumption is satisfied.
# 0.09037062217462102
# The Ignorability Assumption is satisfied.
# 0.13341356809954308
# The Ignorability Assumption is satisfied.
# 0.6238476588945885
# The Ignorability Assumption is satisfied.
# 0.8819248204822246
# The Ignorability Assumption is satisfied.
# 0.2945796342080944
# The Ignorability Assumption is satisfied.
# 0.14825955677330196
# The Ignorability Assumption is satisfied.
# 0.5302475080502945
# The Ignorability Assumption is satisfied.
# 0.23272430142179762
# The Ignorability Assumption is satisfied.
# 0.10400183777596568
# The Ignorability Assumption is satisfied.
# 0.833747451449887
# The Ignorability Assumption is satisfied.
# 0.6989024296517228
# The Ignorability Assumption is satisfied.
# 0.6708061431915533
# The Ignorability Assumption is satisfied.
# 0.7547729051568968
# The Ignorability Assumption is satisfied.
# 0.1802057946797398
# The Ignorability Assumption is satisfied.
# 0.860186571433576
# The Ignorability Assumption is satisfied.
# 0.3976342951277704
# The Ignorability Assumption is satisfied.
# 0.9263642836464921
# The Ignorability Assumption is satisfied.
# 0.5273556329757949
# The Ignorability Assumption is satisfied.
# 0.1444362189111807
# The Ignorability Assumption is satisfied.
# 0.0515474942723152
# The Ignorability Assumption is satisfied.
# 0.5376913406209347
# The Ignorability Assumption is satisfied.
# 0.31753333798378
# The Ignorability Assumption is satisfied.
# 0.10341123001814868
# The Ignorability Assumption is satisfied.
# 0.5091874905511464
# The Ignorability Assumption is satisfied.
# 0.7566363274041429
# The Ignorability Assumption is satisfied.
# 0.28209253193106787
# The Ignorability Assumption is satisfied.
# 0.9458032791872076
# The Ignorability Assumption is satisfied.
# 0.16498576985671523
# The Ignorability Assumption is satisfied.
# 0.29784542428575445
# The Ignorability Assumption is satisfied.
# 0.4148866789147865
# The Ignorability Assumption is satisfied.
# 0.6335666025425405
# The Ignorability Assumption is satisfied.
# 0.3582839977282945
# The Ignorability Assumption is satisfied.
# 0.3043730147924923
# The Ignorability Assumption is satisfied.
# 0.8947019217863847
# The Ignorability Assumption is satisfied.
# 0.699084051189086
# The Ignorability Assumption is satisfied.
# 0.8581349843850177
# The Ignorability Assumption is satisfied.
# 0.5701995662133408
# The Ignorability Assumption is satisfied.
# 0.7453941296499459
# The Ignorability Assumption is satisfied.
# 0.001977739148959872
# The Ignorability Assumption is not satisfied.
# 0.7552060728450576
# The Ignorability Assumption is satisfied.
# 0.8803754574941721
# The Ignorability Assumption is satisfied.
# 0.5951027448596935
# The Ignorability Assumption is satisfied.
# 0.5783340419768273
# The Ignorability Assumption is satisfied.
# 0.9807716017351873
# The Ignorability Assumption is satisfied.
# 0.5487481114446264
# The Ignorability Assumption is satisfied.
# 0.2291566545812051
# The Ignorability Assumption is satisfied.
# 0.3483365421012414
# The Ignorability Assumption is satisfied.
# 0.7977935178805254
# The Ignorability Assumption is satisfied.
# 0.08453047504485989
# The Ignorability Assumption is satisfied.
# 0.9212258230631152
# The Ignorability Assumption is satisfied.
# 0.4609468069690398
# The Ignorability Assumption is satisfied.
# 0.4716830881797719
# The Ignorability Assumption is satisfied.
# 0.9380817702907447
# The Ignorability Assumption is satisfied.
# 0.08735063496254741
# The Ignorability Assumption is satisfied.
# 0.7935457221440796
# The Ignorability Assumption is satisfied.
# 0.6722396321401595
# The Ignorability Assumption is satisfied.
# 0.11785831310237901
# The Ignorability Assumption is satisfied.
# 0.7572541233950877
# The Ignorability Assumption is satisfied.
# 0.6443165998873778
# The Ignorability Assumption is satisfied.
# 0.7087009911866966
# The Ignorability Assumption is satisfied.
# 0.6791903524518437
# The Ignorability Assumption is satisfied.
# 0.6232951251109806
# The Ignorability Assumption is satisfied.
# 0.16672944480154941
# The Ignorability Assumption is satisfied.
# 0.3415717795455717
# The Ignorability Assumption is satisfied.
# 0.5172484506057053
# The Ignorability Assumption is satisfied.
# 0.9613348157718864
# The Ignorability Assumption is satisfied.
# 0.8370700793535948
# The Ignorability Assumption is satisfied.
# 0.7430312867686207
# The Ignorability Assumption is satisfied.
# 0.659822609381002
# The Ignorability Assumption is satisfied.
# 0.2549161399725624
# The Ignorability Assumption is satisfied.
# 0.47548346883760906
# The Ignorability Assumption is satisfied.
# 0.056822010690232704
# The Ignorability Assumption is satisfied.
# 0.02075391397680203
# The Ignorability Assumption is not satisfied.
# 0.34079780500530543
# The Ignorability Assumption is satisfied.
# 0.4923415408381334
# The Ignorability Assumption is satisfied.
# 0.31109965208599993
# The Ignorability Assumption is satisfied.
# 0.8376166649657444
# The Ignorability Assumption is satisfied.
# 0.43393381573603484
# The Ignorability Assumption is satisfied.
# 0.9817496887498832
# The Ignorability Assumption is satisfied.
# 0.2585117957448217
# The Ignorability Assumption is satisfied.
# 0.9737472451418567
# The Ignorability Assumption is satisfied.
# 0.3936697841332256
# The Ignorability Assumption is satisfied.
# 0.2171454430387677
# The Ignorability Assumption is satisfied.
# 0.5918267127550765
# The Ignorability Assumption is satisfied.
# 0.5572824701380725
# The Ignorability Assumption is satisfied.
# 0.3084685801173517
# The Ignorability Assumption is satisfied.
# 0.33386743234443206
# The Ignorability Assumption is satisfied.
# 0.24742949589876578
# The Ignorability Assumption is satisfied.
# 0.5916138084812887
# The Ignorability Assumption is satisfied.
# 0.7890122564697394
# The Ignorability Assumption is satisfied.
# 0.40123476643492556
# The Ignorability Assumption is satisfied.
# 0.9017007887104688
# The Ignorability Assumption is satisfied.
# 0.35914680644739116
# The Ignorability Assumption is satisfied.
# 0.06253021570880582
# The Ignorability Assumption is satisfied.
# 0.944277688467971
# The Ignorability Assumption is satisfied.
# 0.8234498575800175
# The Ignorability Assumption is satisfied.
# 0.8471988537492343
# The Ignorability Assumption is satisfied.
# 0.12157520673324801
# The Ignorability Assumption is satisfied.
# 0.6045107547731479
# The Ignorability Assumption is satisfied.
# 0.03757028627768155
# The Ignorability Assumption is not satisfied.
# 0.14214460678343288
# The Ignorability Assumption is satisfied.
# 0.406389622775644
# The Ignorability Assumption is satisfied.
# 0.7570617442996912
# The Ignorability Assumption is satisfied.
# 0.8270978652096291
# The Ignorability Assumption is satisfied.
# 0.2871107309353165
# The Ignorability Assumption is satisfied.
# 0.26916133881580834
# The Ignorability Assumption is satisfied.
# 0.23056575628327405
# The Ignorability Assumption is satisfied.
# 0.7433250210573396
# The Ignorability Assumption is satisfied.
# 0.6523299799829874
# The Ignorability Assumption is satisfied.
# 0.9348173783018836
# The Ignorability Assumption is satisfied.
# 0.019887614372531413
# The Ignorability Assumption is not satisfied.
# 0.09727622851364104
# The Ignorability Assumption is satisfied.
# 0.9596555083206938
# The Ignorability Assumption is satisfied.
# 0.18915815037839928
# The Ignorability Assumption is satisfied.
# 0.894831094659226
# The Ignorability Assumption is satisfied.
# 0.7384331844251739
# The Ignorability Assumption is satisfied.
# 0.08074808221973213
# The Ignorability Assumption is satisfied.
# 0.7214360561601778
# The Ignorability Assumption is satisfied.
# 0.3676779258863596
# The Ignorability Assumption is satisfied.
# 0.005699732997630913
# The Ignorability Assumption is not satisfied.
# 0.5335317931032523
# The Ignorability Assumption is satisfied.
# 0.7253170140003943
# The Ignorability Assumption is satisfied.
# 0.00642647407203211
# The Ignorability Assumption is not satisfied.
# 0.3695856083142029
# The Ignorability Assumption is satisfied.
# 0.03160620718985975
# The Ignorability Assumption is not satisfied.
# 0.08383131512110009
# The Ignorability Assumption is satisfied.
# 0.12983916613218066
# The Ignorability Assumption is satisfied.
# 0.622692766189811
# The Ignorability Assumption is satisfied.
# 0.660076177328462
# The Ignorability Assumption is satisfied.
# 0.32161517005497375
# The Ignorability Assumption is satisfied.
# 0.2774240191209916
# The Ignorability Assumption is satisfied.
# 0.23682157167166965
# The Ignorability Assumption is satisfied.
# 0.9568828716967034
# The Ignorability Assumption is satisfied.
# 0.25684956727905134
# The Ignorability Assumption is satisfied.
# 0.6227629944810082
# The Ignorability Assumption is satisfied.
# 0.8943366397093325
# The Ignorability Assumption is satisfied.
# 0.772171371354059
# The Ignorability Assumption is satisfied.
# 0.43062758368692544
# The Ignorability Assumption is satisfied.
# 0.6945818549925916
# The Ignorability Assumption is satisfied.
# 0.8158330669497309
# The Ignorability Assumption is satisfied.
# 0.4696860467445121
# The Ignorability Assumption is satisfied.
# 0.7991506475134177
# The Ignorability Assumption is satisfied.
# 0.8549159832837345
# The Ignorability Assumption is satisfied.
# 0.20896470457310104
# The Ignorability Assumption is satisfied.
# 0.703570559336047
# The Ignorability Assumption is satisfied.
# 0.16781168264709947
# The Ignorability Assumption is satisfied.
# 0.46264061984625415
# The Ignorability Assumption is satisfied.
# 0.2948650004079759
# The Ignorability Assumption is satisfied.
# 0.9754416258660905
# The Ignorability Assumption is satisfied.
# 0.7186910261018964
# The Ignorability Assumption is satisfied.
# 0.3106895977654208
# The Ignorability Assumption is satisfied.
# 0.581131181718591
# The Ignorability Assumption is satisfied.
# 0.8838419749969646
# The Ignorability Assumption is satisfied.
# 0.4117277651810195
# The Ignorability Assumption is satisfied.
# 0.22267363139551377
# The Ignorability Assumption is satisfied.
# 0.6980405915588148
# The Ignorability Assumption is satisfied.
# 0.9563350185673998
# The Ignorability Assumption is satisfied.
# 0.45970064240115927
# The Ignorability Assumption is satisfied.
# 0.2215148881878974
# The Ignorability Assumption is satisfied.
# 0.6507619271510088
# The Ignorability Assumption is satisfied.
# 0.347075735506573
# The Ignorability Assumption is satisfied.
# 0.35982351239607635
# The Ignorability Assumption is satisfied.
# 0.4988419973661187
# The Ignorability Assumption is satisfied.
# 0.3222929223518412
# The Ignorability Assumption is satisfied.
# 0.8914202895166848
# The Ignorability Assumption is satisfied.
# 0.05352168378708292
# The Ignorability Assumption is satisfied.
# 0.23420652125401087
# The Ignorability Assumption is satisfied.
# 0.9101546897123054
# The Ignorability Assumption is satisfied.
# 0.8774388367592292
# The Ignorability Assumption is satisfied.
# 0.8440006454146203
# The Ignorability Assumption is satisfied.
# 0.48421970658900904
# The Ignorability Assumption is satisfied.
# 0.4998119596636932
# The Ignorability Assumption is satisfied.
# 0.797868352354006
# The Ignorability Assumption is satisfied.
# 0.5389564395261788
# The Ignorability Assumption is satisfied.
# 0.570185976508143
# The Ignorability Assumption is satisfied.
# 0.7088433216943529
# The Ignorability Assumption is satisfied.
# 0.0469073191706174
# The Ignorability Assumption is not satisfied.
# 0.3487624143480027
# The Ignorability Assumption is satisfied.
# 0.4949617609125405
# The Ignorability Assumption is satisfied.
# 0.5657375406576667
# The Ignorability Assumption is satisfied.
# 0.4058236188974261
# The Ignorability Assumption is satisfied.
# 0.5909202097869619
# The Ignorability Assumption is satisfied.
# 0.35524989272543617
# The Ignorability Assumption is satisfied.
# 0.3162341458087264
# The Ignorability Assumption is satisfied.
# 0.8782950079467811
# The Ignorability Assumption is satisfied.
# 0.06182397698639272
# The Ignorability Assumption is satisfied.
# 0.38227785135040315
# The Ignorability Assumption is satisfied.
# 0.058648155844996684
# The Ignorability Assumption is satisfied.
# 0.46731293796286255
# The Ignorability Assumption is satisfied.
# 0.36390306227203195
# The Ignorability Assumption is satisfied.
# 0.1773314685732396
# The Ignorability Assumption is satisfied.
# 0.6199333678463557
# The Ignorability Assumption is satisfied.
# 0.166139965313972
# The Ignorability Assumption is satisfied.
# 0.6315394507239764
# The Ignorability Assumption is satisfied.
# 0.23451222088846896
# The Ignorability Assumption is satisfied.
# 0.24947818714206083
# The Ignorability Assumption is satisfied.
# 0.2777088098096891
# The Ignorability Assumption is satisfied.
# 0.7693924096999358
# The Ignorability Assumption is satisfied.
# 0.6084198709325026
# The Ignorability Assumption is satisfied.

# %%
COUNT5
# Out:
# 43

# %%
import time
time.time()
# Out:
# 1633413010.7920482

# %%
time.time()
# Out:
# 1633413017.3669047
