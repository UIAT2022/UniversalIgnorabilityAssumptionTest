# %% [markdown]
# # Scenario 3 : square case

# %% [markdown]
# ### Notice
#
# Before you implement below codes, you should confirm that R is installed in your PC.

# %%
# !pip install packages rpy2

# %%
import uiat # it will takes some time.

# %% [markdown]
# ### parameter setting (default)

# %%
n = 1000 #changeable (sample size)
c1 = 1
c2 = 1 
c3 = 1 #changeable (the strength of confounding)
c4 = 1
c5 = 1
r1 = r2 = 1
r3 = r4 = 1 #changeable (the strength of correlation in setting 5 and 6)

import scipy.stats as stats 
import numpy as np
import pandas as pd

# %% [markdown]
# ### Simulation

# %%
#Setting 1
np.random.seed(1)

COUNT1=0 # number of rejection
for i in range(1000):

    U = np.random.normal(0,1,n) #common cause of X1 and X2
    e1 = np.random.normal(0,1,n)
    e2 = np.random.normal(0,1,n)
    ey = np.random.normal(0,1,n)
    
    X1 = r1*U+e1
    X2 = r2*U+e2
    Y = c1*X1+X1**2+ey
    
    if i==1:
        f1_cor12=stats.pearsonr(X1, X2)[0]
    
    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X2,dtype="continuous",verbose=False)
    pvalue = UIAT.test()
    if pvalue<=0.05:
        COUNT1 = COUNT1+1

# %%
#Setting 2
np.random.seed(1)

COUNT21=0 # number of rejection when confounder is considered.
COUNT22=0 # number of rejection when confounder is not considered.
for i in range(1000):
    U = np.random.normal(0,1,n) #common cause of X1 and X2
    C = np.random.normal(0,1,n) #Confounder
    e1 = np.random.normal(0,1,n)
    e2 = np.random.normal(0,1,n)
    ey = np.random.normal(0,1,n)
    
    X1 = r1*U+c2*C+e1
    X2 = r2*U+e2
    Y = c1*X1+c3*C+X1**2+C**2+ey
    
    if i==1:
        f2_cor12=stats.pearsonr(X1, X2)[0]
   
    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X2,covariates=C,dtype="continuous",verbose=False)
    pvalue1 = UIAT.test()
    if pvalue1<=0.05:
        COUNT21 = COUNT21+1
    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X2,dtype="continuous",verbose=False)
    pvalue2 = UIAT.test()
    if pvalue2<=0.05:
        COUNT22 = COUNT22+1

# %%
#Setting 3
np.random.seed(1)

COUNT31=0 # number of rejection when confounder is considered.
COUNT32=0 # number of rejection when confounder is not considered.
for i in range(1000):
    U = np.random.normal(0,1,n) #common cause of X1 and X2
    C = np.random.normal(0,1,n) #Confounder
    e1 = np.random.normal(0,1,n)
    e2 = np.random.normal(0,1,n)
    ey = np.random.normal(0,1,n)
    
    X1 = r1*U+c2*C+e1
    X2 = r2*U+e2
    Y = c3*C+C**2+ey
    
    if i==1:
        f3_cor12=stats.pearsonr(X1, X2)[0]
        
        
    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X2,covariates=C,dtype="continuous",verbose=False)
    pvalue1 = UIAT.test()
    if pvalue1<=0.05:
        COUNT31 = COUNT31+1 
    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X2,dtype="continuous",verbose=False)
    pvalue2 = UIAT.test()
    if pvalue2<=0.05:
        COUNT32 = COUNT32+1

# %%
#Setting 4 
np.random.seed(1)

COUNT41=0 # number of rejection when confounder is considered.
COUNT42=0 # number of rejection when confounder is not considered.
for i in range(1000):
    U = np.random.normal(0,1,n) #common cause of X1 and X2 and X3
    C = np.random.normal(0,1,n) #Confounder
    e1 = np.random.normal(0,1,n)
    e2 = np.random.normal(0,1,n)
    e3 = np.random.normal(0,1,n)
    ey = np.random.normal(0,1,n)
    
    X1 = r1*U+c2*C+e1
    X2 = r2*U+e2
    X3 = r3*U+e3
    Y = c1*X1+c4*X2+c3*C+X1**2+X2**2+C**2+ey
    
    if i==1:
        f4_cor13=stats.pearsonr(X1, X3)[0]
        
    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X3,covariates=np.column_stack((X2,C)),dtype="continuous",verbose=False)
    pvalue1 = UIAT.test()
    if pvalue1<=0.05:
        COUNT41 = COUNT41+1 
        
    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X3,covariates=X2,dtype="continuous",verbose=False)
    pvalue2 = UIAT.test()
    if pvalue2<=0.05:
        COUNT42 = COUNT42+1

# %%
#Setting 5
np.random.seed(1)

COUNT51=0 # number of rejection when confounder is considered. (for EV X2)
COUNT52=0 # number of rejection when confounder is not considered. (for EV X2)
COUNT53=0 # number of rejection when confounder is considered. (for EV X3)
COUNT54=0 # number of rejection when confounder is not considered. (for EV X3)
for i in range(1000):
    U = np.random.normal(0,1,n) #common cause of X1 and X2 and X3
    C = np.random.normal(0,1,n) #Confounder
    e1 = np.random.normal(0,1,n)
    e2 = np.random.normal(0,1,n)
    e3 = np.random.normal(0,1,n)
    ey = np.random.normal(0,1,n)
    
    X1 = r1*U+c2*C+e1
    X2 = r2*U+e2
    X3 = r3*U+e3
    Y = c1*X1+c3*C+X1**2+C**2+ey
    
    if i==1:
        f5_cor12=r1*r2/np.sqrt(r1**2+c2**2+1)/np.sqrt(r2**2+1)
        f5_cor13=r1*r3/np.sqrt(r1**2+c2**2+1)/np.sqrt(r3**2+1)

        
    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X2,covariates=C,dtype="continuous",verbose=False)
    pvalue1 = UIAT.test()
    if pvalue1<=0.05:
        COUNT51 = COUNT51+1 
    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X2,dtype="continuous",verbose=False)
    pvalue2 = UIAT.test()
    if pvalue2<=0.05:
        COUNT52 = COUNT52+1 
    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X3,covariates=C,dtype="continuous",verbose=False)
    pvalue3 = UIAT.test()
    if pvalue3<=0.05:
        COUNT53 = COUNT53+1 
    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X3,dtype="continuous",verbose=False)
    pvalue4 = UIAT.test()
    if pvalue4<=0.05:
        COUNT54 = COUNT54+1

# %%
#Setting 6
np.random.seed(1)

COUNT61=0 # number of rejection when confounder is considered. (for EV X2)
COUNT62=0 # number of rejection when confounder is not considered. (for EV X2)
COUNT63=0 # number of rejection when confounder is considered. (for EV X3)
COUNT64=0 # number of rejection when confounder is not considered. (for EV X3)
for i in range(1000):
    U1 = np.random.normal(0,1,n) #common cause of X1 and X2
    U2 = np.random.normal(0,1,n) #common cause of X1 and X3
    C = np.random.normal(0,1,n) #Confounder
    e1 = np.random.normal(0,1,n)
    e2 = np.random.normal(0,1,n)
    e3 = np.random.normal(0,1,n)
    ey = np.random.normal(0,1,n)
    
    X1 = r1*U1+c2*C+r3*U2+e1
    X2 = r2*U1+e2
    X3 = r4*U2+e3
    Y = c1*X1+c3*C+X1**2+C**2+ey
    
    if i==1:
        f6_cor12=r1*r2/np.sqrt(r1**2+c2**2+r3**2+1)/np.sqrt(r2**2+1)
        f6_cor13=r3*r4/np.sqrt(r1**2+c2**2+r3**2+1)/np.sqrt(r4**2+1)
            

    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X2,covariates=C,dtype="continuous",verbose=False)
    pvalue1 = UIAT.test()
    if pvalue1<=0.05:
        COUNT61 = COUNT61+1 
    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X2,dtype="continuous",verbose=False)
    pvalue2 = UIAT.test()
    if pvalue2<=0.05:
        COUNT62 = COUNT62+1 
    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X3,covariates=C,dtype="continuous",verbose=False)
    pvalue3 = UIAT.test()
    if pvalue3<=0.05:
        COUNT63 = COUNT63+1 
    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X3,dtype="continuous",verbose=False)
    pvalue4 = UIAT.test()
    if pvalue4<=0.05:
        COUNT64 = COUNT64+1

# %%
#Setting 7
np.random.seed(1)

COUNT71=0 # number of rejection when confounder is considered.
COUNT72=0 # number of rejection when confounder is not considered.
for i in range(1000):
    C = np.random.normal(0,1,n) #Confounder
    eu = np.random.normal(0,1,n)
    e1 = np.random.normal(0,1,n)
    e2 = np.random.normal(0,1,n)
    ey = np.random.normal(0,1,n)
    
    U = c2*C+eu #common cause of X1 and X2
    X1 = r1*U+e1
    X2 = r2*U+e2
    Y = c1*X1+c3*C+X1**2+C**2+ey
    
    if i==1:
        f7_cor12=stats.pearsonr(X1, X2)[0]
        
    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X2,covariates=C,dtype="continuous",verbose=False)
    pvalue1 = UIAT.test()
    if pvalue1<=0.05:
        COUNT71 = COUNT71+1 
        
    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X2,dtype="continuous",verbose=False)
    pvalue2 = UIAT.test()
    if pvalue2<=0.05:
        COUNT72 = COUNT72+1

# %%
#Setting 8
np.random.seed(1)

COUNT81=0 # number of rejection when confounder is considered.
COUNT82=0 # number of rejection when confounder is not considered.
for i in range(1000):
    C = np.random.normal(0,1,n) #Confounder, common cause of X1 and X2
    e1 = np.random.normal(0,1,n)
    e2 = np.random.normal(0,1,n)
    ey = np.random.normal(0,1,n)
    
    X1 = r1*C+e1
    X2 = r2*C+e2
    Y = c1*X1+c3*C+X1**2+C**2+ey
    
    if i==1:
        f8_cor12=stats.pearsonr(X1, X2)[0]

    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X2,covariates=C,dtype="continuous",verbose=False)
    pvalue1 = UIAT.test()
    if pvalue1<=0.05:
        COUNT81 = COUNT81+1 
        
    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X2,dtype="continuous",verbose=False)
    pvalue2 = UIAT.test()
    if pvalue2<=0.05:
        COUNT82 = COUNT82+1

# %%
#Setting 9
np.random.seed(1)

COUNT91=0 # number of rejection when confounder is considered.
COUNT92=0 # number of rejection when confounder is not considered.
for i in range(1000):
    U = np.random.normal(0,1,n) #common cause of X1 and X2
    C = np.random.normal(0,1,n) #Confounder
    e1 = np.random.normal(0,1,n)
    e2 = np.random.normal(0,1,n)
    ey = np.random.normal(0,1,n)
    
    X1 = r1*U+c2*C+e1
    X2 = r2*U+c4*C+e2
    Y = c1*X1+c3*C+X1**2+C**2+ey
    
    if i==1:
        f9_cor12=stats.pearsonr(X1, X2)[0]
        
        
    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X2,covariates=C,dtype="continuous",verbose=False)
    pvalue1 = UIAT.test()
    if pvalue1<=0.05:
        COUNT91 = COUNT91+1 
        
    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X2,dtype="continuous",verbose=False)
    pvalue2 = UIAT.test()
    if pvalue2<=0.05:
        COUNT92 = COUNT92+1

# %%
#Setting 10
np.random.seed(1)

COUNT101=0 # number of rejection when confounder is considered.
COUNT102=0 # number of rejection when confounder is not considered.
for i in range(1000):
    U = np.random.normal(0,1,n) #common cause of X1 and X2 and X3
    C = np.random.normal(0,1,n) #Confounder
    e1 = np.random.normal(0,1,n)
    e2 = np.random.normal(0,1,n)
    e3 = np.random.normal(0,1,n)
    ey = np.random.normal(0,1,n)
    
    X1 = r1*U+c2*C+e1
    X2 = r2*U+c4*C+e2
    X3 = r3*U+e3
    Y = c1*X1+c3*C+c5*X2+X1**2+X2**2+C**2+ey

    if i==1:
        f10_cor13=stats.pearsonr(X1, X3)[0]
        
        
    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X3,covariates=np.column_stack((X2,C)),dtype="continuous",verbose=False)
    pvalue1 = UIAT.test()
    if pvalue1<=0.05:
        COUNT101 = COUNT101+1 
        
    UIAT = uiat.UniversalIgnorabilityAssumptionTest(cause=X1,effect=Y,explorer=X3,covariates=X2,dtype="continuous",verbose=False)
    pvalue2 = UIAT.test()
    if pvalue2<=0.05:
        COUNT102 = COUNT102+1

# %%
table1=pd.DataFrame(np.repeat(-1,70).reshape(10,7))
table1.columns = ["Scenario3","type I error rate(X2)","power(X2)","type I error rate(X3)","power(X3)","r12","r13"]

# %%
table1["Scenario3"]=["Figure"+str(i+1) for i in range(10)]

# %%
table1["type I error rate(X2)"]=[COUNT1,COUNT21,COUNT31,COUNT41,COUNT51,COUNT61,COUNT71,COUNT81,COUNT91,COUNT101]
table1["power(X2)"]=[-1,COUNT22,COUNT32,COUNT42,COUNT52,COUNT62,COUNT72,COUNT82,COUNT92,COUNT102]
table1["type I error rate(X3)"]=[-1,-1,-1,-1,COUNT53,COUNT63,-1,-1,-1,-1]
table1["power(X3)"]=[-1,-1,-1,-1,COUNT54,COUNT64,-1,-1,-1,-1]
table1["r12"]=[f1_cor12,f2_cor12,f3_cor12,-1,f5_cor12,f6_cor12,f7_cor12,f8_cor12,f9_cor12,-1]
table1["r13"]=[-1,-1,-1,f4_cor13,f5_cor13,f6_cor13,-1,-1,-1,f10_cor13]

# %%
table1
# Out:
#   Scenario3  type I error rate(X2)  power(X2)  type I error rate(X3)  \
# 0   Figure1                     50         -1                     -1
# 1   Figure2                     57        822                     -1
# 2   Figure3                     65        967                     -1
# 3   Figure4                     64        471                     -1
# 4   Figure5                     62        800                     57
# 5   Figure6                     63        487                     68
# 6   Figure7                     58        903                     -1
# 7   Figure8                     51       1000                     -1
# 8   Figure9                     52        913                     -1
# 9  Figure10                     67        903                     -1
#
#    power(X3)       r12       r13
# 0         -1  0.507033 -1.000000
# 1         -1  0.363093 -1.000000
# 2         -1  0.363093 -1.000000
# 3         -1 -1.000000  0.401017
# 4        823  0.408248  0.408248
# ...
